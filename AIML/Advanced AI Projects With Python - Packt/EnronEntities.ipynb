# %%
import mailbox

# %%
mbox = mailbox.mbox('enron.mbox')
msgs=mbox.keys()

# %%
for msg_key in msgs[10:20]:
    message = mbox.get(msg_key)
    print(msg_key,message['Subject'],message['From'],message['Date'],sep = " / ")
    print("======================")
    print(message.get_payload())
    print("**********************************")
    print("**********************************")
# Out:
# 10 / Your Approval is Overdue: Access Request for matt.smith@enron.com / arsystem@mailman.enron.com / Tue, 1 Jan 2002 17:19:40 -0800 (PST)
# ======================
# This request has been pending your approval for  60 days.  Please click http://itcapps.corp.enron.com/srrs/auth/emailLink.asp?ID=000000000067320&Page=Approval to review and act upon this request.
#
#
#
#
#
# Request ID          : 000000000067320
# Request Create Date : 10/11/01 10:24:53 AM
# Requested For       : matt.smith@enron.com
# Resource Name       : Risk Acceptance Forms Local Admin Rights - Permanent
# Resource Type       : Applications
#
#
#
#
#
# **********************************
# **********************************
# 11 / Gas P&L by day / brad.jones@enron.com / Mon, 10 Dec 2001 14:59:55 -0800 (PST)
# ======================
# Attached is the information you have requested.
#
# Thanks,
# Brad Jones
#
#
#
# **********************************
# **********************************
# 12 / Service Agreement / hunter.williams@grandecom.com / Tue, 11 Sep 2001 10:12:32 -0700 (PDT)
# ======================
# Greg/Phillip,
#
# Attached is the Grande Communications Service Agreement.  The business
# points can be found in Exhibit C.  I Can get the Non-Disturbance agreement
# after it has been executed by you and Grande.  I will fill in the Legal
# description of the property one I have received it.  Please execute and send
# to:  Grande Communications, 401 Carlson Circle, San Marcos Texas, 78666
# Attention Hunter Williams.
#
#  <<Bishopscontract.doc>>
#
# Hunter Williams
# Grande Communications
# Wireless 512-757-2794
# 512-878-5467
#
#
#  - Bishopscontract.doc
#
# **********************************
# **********************************
# 13 / FW: Service Agreement / hunter.williams@grandecom.com / Tue, 11 Sep 2001 14:44:51 -0700 (PDT)
# ======================
# Greg/Phillip,
#
# I will need Two (2) executed copies of the agreement.
#
# Hunter Williams
# Grande Communications
# 512-878-5467
#
# >  -----Original Message-----
# > From: 	Hunter Williams
# > Sent:	Tuesday, September 11, 2001 12:13 PM
# > To:	'gthorse@keyad.com'
# > Cc:	''
# > Subject:	Service Agreement
# >
# > Greg/Phillip,
# >
# > Attached is the Grande Communications Service Agreement.  The business
# > points can be found in Exhibit C.  I Can get the Non-Disturbance agreement
# > after it has been executed by you and Grande.  I will fill in the Legal
# > description of the property one I have received it.  Please execute and
# > send to:  Grande Communications, 401 Carlson Circle, San Marcos Texas,
# > 78666 Attention Hunter Williams.
# >
# >
# >
# > Hunter Williams
# > Grande Communications
# > Wireless 512-757-2794
# > 512-878-5467
# >
#
# **********************************
# **********************************
# 14 / RE: / richard.morgan@austinenergy.com / Wed, 10 Oct 2001 09:03:56 -0700 (PDT)
# ======================
# Phillip, there are a number of alternative systems that will allow the same
# level of energy efficiency. I would wait a bit for Wink's bid though. You
# say that your panel costs are $20,000 additional. that sounds like a lot. I
# just did a panel house with a 2100 sq ft footprint and the total panel cost
# was about $25,000 with 8 inch walls and 10 inch roof. Stay in touch and we
# can discuss alternatives if that becomes necessary. If your budget is $85-90
# per sq. ft.  excluding land costs your costs will be on the low end of the
# true custom home level but should be achievable with good management.
# Richard Morgan
# Manager, Green Building Program
# Austin Energy
# 721 Barton Springs Rd.
# Austin, TX 78704-1194
# Ph. 512.505.3709
# Fax 512.505.3711
# e-mail richard.morgan@austinenergy.com
#
#
# -----Original Message-----
# From: Allen, Phillip K. [mailto:Phillip.K.Allen@ENRON.com]
# Sent: Wednesday, October 10, 2001 9:19 AM
# To: Morgan, Richard
# Subject:
#
#
# Richard,
#
# I spoke to you earlier this week with questions about building with
# SIP's.  I am planning to build a home in San Marcos as soon as I can
# decide on a builder and materials.  I already have my blueprints
# completed.  What I took from our conversation  was to use the SIP's with
# 8.5" roof panels and use a metal roof.
#
# I have been working with Johnnie Brown, a builder from San Antonio that
# is also a Creative Panel rep.  The problem is that I have a budget of
# $85-$90/sf and it does not appear that he will be able to stay within
# that budget.  I don't want to settle for a conventional stick built
# house.  I was wondering about alternatives.  Would some combination of a
# radiant barrier and non-CFC spray insulation provide close to the same
# energy savings at a lower cost than SIP's. For example, I just spoke to
# a sales rep for Demilec.  He will spray foam insulation at $1.30/sf.
# That would be approximately $10,000 compared to over $20,000 additional
# costs for the panels.  But would the foam insulation be as effective?
# Do you have any suggestions of materials or contractors that would help
# me construct the best home for the money.  I am trying to get a bid from
# Wink with Premier based on you reference.
#
# Thank you for your help.
#
# Phillip Allen
# pallen@enron.com
# 713-853-7041
#
#
# **********************************************************************
# This e-mail is the property of Enron Corp. and/or its relevant affiliate and
# may contain confidential and privileged material for the sole use of the
# intended recipient (s). Any review, use, distribution or disclosure by
# others is strictly prohibited. If you are not the intended recipient (or
# authorized to receive for the recipient), please contact the sender or reply
# to Enron Corp. at enron.messaging.administration@enron.com and delete all
# copies of the message. This e-mail (and any attachments hereto) are not
# intended to be an offer (or an acceptance) and do not create or evidence a
# binding and enforceable contract between Enron Corp. (or any of its
# affiliates) and the intended recipient or any other party, and may not be
# relied on by anyone as the basis of a contract by estoppel or otherwise.
# Thank you.
# **********************************************************************
#
# **********************************
# **********************************
# 15 / Properties for sale / jsmith@austintx.com / Tue, 23 Oct 2001 15:14:37 -0700 (PDT)
# ======================
# There are three other deals that I will fax to you.  let me know if you have
# an interest.
#
# Thanks,
#
# Jeff Smith
# The Smith Company
# 9400 Circle Drive
# Austin, Texas  78736
# 512-394-0908 office
# 512-394-0913 fax
# 512-751-9728 mobile
# jsmith@austintx.com
#
#  - Metropolitan sales sheet.xls
#  - south center oaks sales sheet.xls
#  - Treaty Oaks Sales Sheet.xls
#
# **********************************
# **********************************
# 16 / Huntley/question / wise.counsel@lpl.com / Thu, 25 Oct 2001 13:49:57 -0700 (PDT)
# ======================
#
# Phillip,
#
# Could you please do me a favor?  I would like  to read your current title policy to see what it says about easements.  You  should have received a copy during your closing.  I don't know how many  pages it will be but let me know how you want to handle getting a copy  made.  I'll be happy to make the copy, or whatever makes it easy for  you.
#
# Thanks,
#
# Bob Huntley
#
# **********************************
# **********************************
# 17 / Distribution Form / renee.ratcliff@enron.com / Thu, 25 Oct 2001 12:04:35 -0700 (PDT)
# ======================
# Phillip,
#
# Pursuant to your request, please see the attached.
#
# Thanks,
#
# Renee
#
#
#
# **********************************
# **********************************
# 18 / First Amendment to Contract - For Execution / msimpkins@winstead.com / Thu, 25 Oct 2001 13:24:44 -0700 (PDT)
# ======================
#  <<3MMP10!.DOC>>
# Phillip,
#
# Enclosed please find the First Amendment to Contract for your review and
# execution.  Please sign the Amendment at your earliest convenience and fax a
# copy to me at (512) 370-2850.  Please overnight the original to me at the
# address below.  If you have any questions or concerns, please contact me at
# (512) 370-2836.  Thanks.
#
# Michelle L. Simpkins
# Winstead Sechrest & Minick P.C.
# 100 Congress Avenue, Suite 800
# Austin, Texas  78701
# (512) 370-2836
# (512) 370-2850 Fax
# msimpkins@winstead.com
#
#
#  - 3MMP10!.DOC
#
# **********************************
# **********************************
# 19 / Blackline of First Amendment to Contract / msimpkins@winstead.com / Thu, 25 Oct 2001 13:27:50 -0700 (PDT)
# ======================
#  <<3MMPRED.DOC>>
# Phillip,
#
# Enclosed please find a blackline of the First Amendment to Contract showing
# the revisions.  I have forwarded a clean version of the Amendment to you for
# your signature.  If you have any questions or concerns, please contact me at
# (512) 370-2836.  Thanks.
#
# Michelle L. Simpkins
# Winstead Sechrest & Minick P.C.
# 100 Congress Avenue, Suite 800
# Austin, Texas  78701
# (512) 370-2836
# (512) 370-2850 Fax
# msimpkins@winstead.com
#
#
#  - 3MMPRED.DOC
#
# **********************************
# **********************************

# %%
print(mbox)
# Out:
# <mailbox.mbox object at 0x000001DAC5A4BA88>

# %%
help(mbox)
# Out:
# Help on mbox in module mailbox object:
#
# class mbox(_mboxMMDF)
#  |  mbox(path, factory=None, create=True)
#  |
#  |  A classic mbox mailbox.
#  |
#  |  Method resolution order:
#  |      mbox
#  |      _mboxMMDF
#  |      _singlefileMailbox
#  |      Mailbox
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, path, factory=None, create=True)
#  |      Initialize an mbox mailbox.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _mboxMMDF:
#  |
#  |  get_bytes(self, key, from_=False)
#  |      Return a string representation or raise a KeyError.
#  |
#  |  get_file(self, key, from_=False)
#  |      Return a file-like representation or raise a KeyError.
#  |
#  |  get_message(self, key)
#  |      Return a Message representation or raise a KeyError.
#  |
#  |  get_string(self, key, from_=False)
#  |      Return a string representation or raise a KeyError.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _singlefileMailbox:
#  |
#  |  __contains__(self, key)
#  |      Return True if the keyed message exists, False otherwise.
#  |
#  |  __len__(self)
#  |      Return a count of messages in the mailbox.
#  |
#  |  __setitem__(self, key, message)
#  |      Replace the keyed message; raise KeyError if it doesn't exist.
#  |
#  |  add(self, message)
#  |      Add message and return assigned key.
#  |
#  |  close(self)
#  |      Flush and close the mailbox.
#  |
#  |  flush(self)
#  |      Write any pending changes to disk.
#  |
#  |  iterkeys(self)
#  |      Return an iterator over keys.
#  |
#  |  lock(self)
#  |      Lock the mailbox.
#  |
#  |  remove(self, key)
#  |      Remove the keyed message; raise KeyError if it doesn't exist.
#  |
#  |  unlock(self)
#  |      Unlock the mailbox if it is locked.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Mailbox:
#  |
#  |  __delitem__(self, key)
#  |
#  |  __getitem__(self, key)
#  |      Return the keyed message; raise KeyError if it doesn't exist.
#  |
#  |  __iter__(self)
#  |
#  |  clear(self)
#  |      Delete all messages.
#  |
#  |  discard(self, key)
#  |      If the keyed message exists, remove it.
#  |
#  |  get(self, key, default=None)
#  |      Return the keyed message, or default if it doesn't exist.
#  |
#  |  items(self)
#  |      Return a list of (key, message) tuples. Memory intensive.
#  |
#  |  iteritems(self)
#  |      Return an iterator over (key, message) tuples.
#  |
#  |  itervalues(self)
#  |      Return an iterator over all messages.
#  |
#  |  keys(self)
#  |      Return a list of keys.
#  |
#  |  pop(self, key, default=None)
#  |      Delete the keyed message and return it, or default.
#  |
#  |  popitem(self)
#  |      Delete an arbitrary (key, message) pair and return it.
#  |
#  |  update(self, arg=None)
#  |      Change the messages that correspond to certain keys.
#  |
#  |  values(self)
#  |      Return a list of messages. Memory intensive.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Mailbox:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
import re
def cleanup_email(msgbody):
    regex_replies = re.compile('(\-+Original Message|\-\-+|~~+).*', re.DOTALL) # find 'Original Message...' and variants
    msgbody = re.sub(regex_replies, '', msgbody)
    msgbody = re.sub(r'=\d\d', ' ', msgbody) # remove funny email formatting issues
    msgbody = re.sub(r'\s*>.*', '', msgbody) # remove quotes
    msgbody = re.sub(r'https?://.*?\s', '', msgbody) # remove links
    bigspace = re.compile(r'\n\n\n\n\n+.*', re.DOTALL) # find large gaps
    msgbody = re.sub(bigspace, '', msgbody)
    bigindent = re.compile(r'(\t| {4,}).*', re.DOTALL) # find big indentations (i.e., a quoted document)
    msgbody = re.sub(bigindent, '', msgbody)
    emailpaste = re.compile(r'(From|Subject|To): .*', re.DOTALL) # find pasted emails
    msgbody = re.sub(emailpaste, '', msgbody)
    msgbody = re.sub(r'=(\s*)\n', '\1', msgbody) # fix broken newlines
    msgbody = re.sub(r' ,([stm])', '\'\1', msgbody) # fix funny apostrophe 's and 't and 'm
    msgbody = re.sub(r'([\?\.])\?', '\1', msgbody) # fix funny extra question marks
    msgbody = re.sub(r'\x01', ' ', msgbody) # fix odd spaces
    return msgbody.strip()

# %%
for msg_key in msgs[326:500]:
    message = mbox.get(msg_key)
    msgbody = cleanup_email(message.get_payload())
    print(msg_key, message['Subject'], message['From'],message['To'], message['Date'],sep=" / ")
    print("============")
    print(msgbody)
    print("*****")
    print("********")
# Out:
# 326 / An Inbound Message For You Has Been Quarantined / admin.enron@enron.com / eric.bass@enron.com / Tue, 22 Jan 2002 09:58:35 -0800 (PST)
# ============
# You have received this message because someone has attempted to send you an e-mail from outside of Enron with an attachment type that Enron does not allow into our messaging environment. Your e-mail has been quarantined and is being held at the MailSweeper server.
#
#
# Sender:  daphneco64@alltel.net
# Date:  Tue, 22 Jan 2002 11:52:40 -0600
# *****
# ********
# 327 / FW: Quarter Life Crisis / shanna.husser@enron.com / None / Tue, 22 Jan 2002 09:04:52 -0800 (PST)
# ============
#
# *****
# ********
# 328 / RE: Application Forms / karen.buckley@enron.com / eric.bass@enron.com / Tue, 22 Jan 2002 08:29:15 -0800 (PST)
# ============
# old one. thanks!.
# *****
# ********
# 329 / CNN Breaking News / breakingnews@mail.cnn.com / textbreakingnews@cnnimail12.cnn.com / Tue, 22 Jan 2002 06:43:02 -0800 (PST)
# ============
#
# *****
# ********
# 330 / FW: Meeting - Tuesday 10 am - rescheduled / karen.buckley@enron.com / None / Tue, 22 Jan 2002 07:24:53 -0800 (PST)
# ============
# The meeting today has been rescheduled to 11:00 am in Room : ECS 06980.
#
# Kind regards,
#
#
# Karen.
# *****
# ********
# 331 / FW: New Orleans / shanna.husser@enron.com / eric.bass@enron.com / Tue, 22 Jan 2002 05:30:08 -0800 (PST)
# ============
#
# *****
# ********
# 332 / Meeting - Tuesday 10 am / karen.buckley@enron.com / None / Mon, 21 Jan 2002 16:05:13 -0800 (PST)
# ============
# A 10:00 am meeting has be tentatively scheduled for you Tuesday, location to be confirmed, to discuss the Analyst & Associate Program as it relates to UBS.
#
#
# Kind regards,
#
#
# Karen Buckley<?xml:namespace prefix = o ns = "urn:schemas-microsoft-com:office:office" /
#
# Human Resources
#
# Tel: 713 345 4667
# *****
# ********
# 333 / Application Forms / karen.buckley@enron.com / None / Mon, 21 Jan 2002 15:23:45 -0800 (PST)
# ============
# Please come by 5C2 at your convenience tomorrow as UBS require you to complete missing information on your application form.
#
# Kind regards,
#
#
#
# Karen Buckley
#
# Human Resources
#
# Tel: 713 345 4667
# *****
# ********
# 334 / Access to UBSWenergy Production Environment / stephanie.sever@enron.com / eric.bass@enron.com / Wed, 6 Feb 2002 11:24:33 -0800 (PST)
# ============
# IMPORTANT - THE IDS BELOW WILL BE YOUR PERMANENT ACCESS TO PRODUCTION
#
# Your PRODUCTION User ID and Password has been set up on UBSWenergy.  Please follow the steps below to access the new environment:
# *****
# ********
# 335 / None / None / None / None
# ============
#
# *****
# ********
# 336 / None / None / None / None
# ============
# STACK MANAGER
# User ID: ebass
# Password: q#9M#npX
# *****
# ********
# 337 / Fundamentals of Electricity - Extended registration deadline / lana.moore@nesanet.org / None / Mon, 21 Jan 2002 08:40:15 -0800 (PST)
# ============
#
# *****
# ********
# 338 / An Inbound Message For You Has Been Quarantined / admin.enron@enron.com / eric.bass@enron.com / Mon, 21 Jan 2002 06:19:54 -0800 (PST)
# ============
# You have received this message because someone has attempted to send you an e-mail from outside of Enron with an attachment type that Enron does not allow into our messaging environment. Your e-mail has been quarantined and is being held at the MailSweeper server.
#
#
# Sender:  daphneco64@alltel.net
# Date:  Mon, 21 Jan 2002 08:13:58 -0600
# *****
# ********
# 339 / RE: TAKE A MILE AND GIVE AN INCH OR LESS??? / jbass@stdauto.com / bass'.'larry@enron.com, eric.bass@enron.com, bass.jason@enron.com,
# 	bass.k.@enron.com / Mon, 21 Jan 2002 06:32:46 -0800 (PST)
# ============
# Well I can find no mention on any of my hoax resources.  It very well may be true.
#
# Sad if it is.
# *****
# ********
# 340 /  / lwbthemarine@alltel.net / lwbthemarine@alltel.net / Sun, 20 Jan 2002 14:23:55 -0800 (PST)
# ============
# Just returned from seeing "Black Hawk Down." Strongly recommend that you see this fact based movie.
#
# It is a moving tribute to the skill, dedication, selflessness, honor and commitment of our military.
#
# Any politician in the position of being able to send our military into battle should also see this movie. Hopefully, our current political leaders realize that the military will follow their orders, to the death; and, accordingly,believe those orders should be given only if the national interest of the U.S.A. is in jeopardy.-L
# *****
# ********
# 341 / Hey can I bum a Golf Ball / lwbthemarine@alltel.net / daphneco64@alltel.net / Thu, 17 Jan 2002 15:20:11 -0800 (PST)
# ============
# See dear, sometimes you get what you ask for. Love you-L
#
#
#
#
#
#
# A bum, who obviously has seen more than his share of hard
# times, approaches a well dressed gentleman on the street.
# "Hey, Buddy, can you spare two dollars?"
#
# The well-dressed gentleman responds, "You are not going to
# spend in on liquor are you?"
#
# "No, sir, I don't drink," retorts the bum.
#
# "You are not going to throw it away in some crap game, are
#  you?" asks the gentleman.
#
# "No way, I don't gamble," answers the bum.
#
# "You wouldn't waste the money at a golf course for greens
# fees, would you?" asks the man.
#
# "Never," says the bum, "I don't play golf."
#
# The man asks the bum if he would like to come home with him
# for a home cooked meal.
#
# The bum accepts eagerly. While they are heading for the
# man's house, the bum's curiosity gets the better of him.
# "Isn't your wife going to be angry when she sees a guy like me at your table?"
#
# "Probably," says the man, "but it will be worth it. I want  her to see what happens to a guy who doesn't drink, gamble  or play golf."
# *****
# ********
# 342 / UBS issues / eric.bass@enron.com / eric.bass@enron.com / Thu, 17 Jan 2002 13:53:20 -0800 (PST)
# ============
# 1) The enforceability of my existing contract with Enron, namely section 16.  What happens to my contract with Enron and will I be forced to repay both my sign on bonus and my retention bonus to Enron?
#
# 2) Section 1(f) and the last sentence of section 1(c) seem redundant.  Will I get paid the retention bonus absent voluntary termination (i.e. for both with cause and without cause involuntary termination) ?
#
# 3) Who will be my employer?  And will all stock and stock option grants be in UBS AG stock?
#
# 4) What happens to the Restricted Stock grant referenced in Section 2 and again in Exhibit I if UBS terminates me with or without cause?  As a follow up,  if the stock is lost then what is the consideration for signing this contract (non - compete)?
#
# 5) In Section 9(a), the non - compete clause is set up for a 12 month period after my employment begins and continues regardless of termination both voluntarily and involuntarily.  What is to stop UBS from terminating me or anyone else for that matter immediately after signing this agreement?  All they are out is the Retention portion of the contract (since contract is at will).
# *****
# ********
# 343 / Re: Good Morning / daphneco64@alltel.net / eric.bass@enron.com / Thu, 17 Jan 2002 10:15:08 -0800 (PST)
# ============
# Hi Dear Son,
#
# Thank you for the invitation. It sounds like Shanna has planned a nice romantic dinner for two.  I am sure it will be lovely.   Let's all get together next week and have an informal family celebration.  Is that o.k. with you?  Love you, Mom
# *****
# ********
# 344 / FW: MOUSE / laura.vuittonet@enron.com / eric.bass@enron.com / Thu, 17 Jan 2002 09:44:53 -0800 (PST)
# ============
# Sorry, Eric.  Didn't mean to leave you out.
# *****
# ********
# 345 / Ameritrade e-News, January 2002 / ameritrade_034489@ameritrade.customer-email.com / ebass@enron.com / Thu, 17 Jan 2002 06:29:46 -0800 (PST)
# ============
# <  <January 2002
# *****
# ********
# 346 / Account Update from Capital One / service@capitalone.bfi0.com / ebass@enron.com / Thu, 17 Jan 2002 06:54:39 -0800 (PST)
# ============
# Capital One
#  - what's in your wallet? < Online Account Services <
#   <
# As a valued customer of Capital One's Online Account Services, each month you will automatically receive an e-mail notification letting you know that your current statement is available online.
#
# To view your current Capital One statement, just visit www.capitalone.com <
#
# Thank you for using Capital One's Online Account Services.
#
# Click here to login and view your online statement <
# Get more from Capital One
#
# As one of our valued customers, we also provide you with a variety of special partner offers for valuable financial products and services.
#
#
#
#   <
# *****
# ********
# 347 / YOU HAVE 48 HOURS - Message from Louise Kitchen / julie.clyatt@enron.com / darren.adamik@enron.com, p..adams@enron.com, habib.ahsan@enron.com,
# 	d.alexander@enron.com, diana.allen@enron.com, k..allen@enron.com,
# 	jason.althaus@enron.com, susan.amador@enron.com,
# 	amanullah.aman@enron.com, sherry.anastas@enron.com,
# 	dan.arellano@enron.com, ravi.arumbakkam@enron.com,
# 	chris.austin@enron.com, luis.aybar@enron.com,
# 	natalie.baker@enron.com, arun.balasundaram@enron.com,
# 	ted.ballinger@enron.com, charles.ballmer@enron.com,
# 	michael.barber@enron.com, eric.bass@enron.com, nilay.basu@enron.com,
# 	david.baumbach@enron.com, bryce.baxter@enron.com,
# 	chris.behney@enron.com, cedric.belt@enron.com, troy.beyer@enron.com,
# 	randy.bhatia@enron.com, jae.black@enron.com, gary.bode@enron.com,
# 	f..brawner@enron.com, ryan.brennan@enron.com,
# 	craig.breslau@enron.com, karen.buckley@enron.com,
# 	victor.bulbes@enron.com, simon.burgess@enron.com,
# 	janine.cashin@enron.com, michael.castillo@enron.com,
# 	john.cheng@enron.com, suzanne.christiansen@enron.com,
# 	diana.cioffi@enron.com, kristen.clause@enron.com,
# 	julie.clyatt@enron.com, frank.coles@enron.com, paige.cox@enron.com,
# 	a..cummings@enron.com, amanda.curless@enron.com,
# 	neil.davies@enron.com, roberto.deleon@enron.com,
# 	janet.devereaux@enron.com, dan.dietrich@enron.com,
# 	michael.dolan@enron.com, keith.dziadek@enron.com,
# 	clay.elliott@enron.com, frank.ermis@enron.com, j..ewing@enron.com,
# 	amy.fitzpatrick@enron.com, bryant.frihart@enron.com,
# 	l..gay@enron.com, doug.gichana@enron.com, n..gilbert@enron.com,
# 	c..giron@enron.com, c..gossett@enron.com, mike.grigsby@enron.com,
# 	marlin.gubser@enron.com, claudia.guerra@enron.com,
# 	joe.hall@enron.com, mark.hall@enron.com, j..hanson@enron.com,
# 	kimberly.hillis@enron.com, d..hogan@enron.com, keith.holst@enron.com,
# 	james.hungerford@enron.com, charles.jacobs@enron.com,
# 	matthew.james@enron.com, tammy.jaquet@enron.com,
# 	anthony.jarrett@enron.com, jamey.johnston@enron.com,
# 	brad.jones@enron.com, monte.jones@enron.com, jared.kaiser@enron.com,
# 	shivshankar.kandavelu@enron.com, kam.keiser@enron.com,
# 	bill.knox@enron.com, brian.larkin@enron.com, john.lavorato@enron.com,
# 	rick.le@enron.com, matthew.lenhart@enron.com, kathy.link@enron.com,
# 	kori.loibl@enron.com, m..love@enron.com, mike.maggi@enron.com,
# 	danielle.marcinkowski@enron.com, a..martin@enron.com,
# 	larry.may@enron.com, bob.mcauliffe@enron.com,
# 	jonathan.mckay@enron.com, errol.mclaughlin@enron.com,
# 	darren.mcnair@enron.com, jason.mcnair@enron.com,
# 	shelly.mendel@enron.com, genaro.mendoza@enron.com,
# 	stephanie.miller@enron.com, bruce.mills@enron.com, l..mims@enron.com,
# 	g..moore@enron.com, daniel.muschar@enron.com, donnie.myers@enron.com,
# 	acey.nash@enron.com, scott.neal@enron.com, john.oh@enron.com,
# 	matthew.olney@enron.com, michael.olsen@enron.com,
# 	kari.oquinn@enron.com, ryan.o'rourke@enron.com, h..otto@enron.com,
# 	david.oxley@enron.com, scott.palmer@enron.com,
# 	stephen.perich@enron.com, richard.pinion@enron.com,
# 	faheem.qavi@enron.com, dutch.quigley@enron.com, ina.rangel@enron.com,
# 	edward.ray@enron.com, jay.reitmeyer@enron.com, trey.rhodes@enron.com,
# 	andrea.ring@enron.com, tina.rode@enron.com, jenny.rub@enron.com,
# 	amanda.rybarski@enron.com, tammie.schoppe@enron.com,
# 	russ.severson@enron.com, jennifer.shipos@enron.com,
# 	scott.shishido@enron.com, s..shively@enron.com,
# 	steve.shortt@enron.com, john.shupak@enron.com,
# 	jeanie.slone@enron.com, bruce.smith@enron.com,
# 	mathew.smith@enron.com, p..south@enron.com, cathy.sprowls@enron.com,
# 	micah.staggs@enron.com, david.steiner@enron.com,
# 	geoff.storey@enron.com, patti.sullivan@enron.com,
# 	john.taylor@enron.com, joseph.taylor@enron.com,
# 	todd.thelen@enron.com, m..tholt@enron.com,
# 	benjamin.thompson@enron.com, brent.tiner@enron.com,
# 	judy.townsend@enron.com, barry.tycholiz@enron.com,
# 	carlos.uribe@enron.com, john.valdes@enron.com, leah.van@enron.com,
# 	laura.vargas@enron.com, frank.vickers@enron.com,
# 	melissa.videtto@enron.com, laura.vuittonet@enron.com,
# 	houston <.ward@enron.com>, charles.weldon@enron.com,
# 	jon.werner@enron.com, kevin.whitehurst@enron.com,
# 	trading <.williams@enron.com>, d..winfree@enron.com,
# 	ashley.worthing@enron.com, becky.young@enron.com,
# 	eddie.zhang@enron.com / Wed, 6 Feb 2002 09:18:26 -0800 (PST)
# ============
# It appears that the following email may not have been clear.  You have to copy all documents yourself.
#
# This is my cheat sheet if it helps:
#
# H Drives:
# 1.  Each person will have to move any data over personally from the old H drive (which is now Z:) drive to their new H drive.
# 2. The Z: drive (old H:) will be removed from UBS employees on Thursday night.
#
# O Drives:
# 1. For the old O or M drives go to O:\ESTATE\ O (or M ? pending location of data) and copy to the new common O.  The Estate O and M will be removed from UBS employees on Thursday night.
#
# Do not delete anything and only copy information which is complies with the policy.  Please make sure that those people who are not in the office are contacted and comply.
#
#
# Louise
#
#
#
# To:
# *****
# ********
# 348 / Good Morning / daphneco64@alltel.net / eric.bass@enron.com / Thu, 17 Jan 2002 05:57:18 -0800 (PST)
# ============
# Hi Eric,
#
# It looks like Enron employees have an enterprising spirit according to the H. Chronicle.  Ebay is saturated with Enron goodies.  This is quite amusing.
#
# Sorry about tonight and we will miss you on your birthday.  We will celebrate whenever you wish, just let us know.  If you change your mind about tomorrow, email me.  Donnita and Jason are coming over for dinner.  We would love for you to come.
#
# Have a wonderful day.  LU-M
# *****
# ********
# 349 / icruise Flash specials! / flash@icruise.com / postmaster@your.smtp.com / Wed, 16 Jan 2002 13:59:24 -0800 (PST)
# ============
# icruise.com < flashborder <Dear icruise member,
# WOW! It's the only reaction that meets the moment. Carnival Cruise Line
# offered me the pleasure of attending the inaugural of the newest fun ship,
# The Carnival Pride. Brand spanking new and the definition of FUN,
# the Pride offers you incomparable dining, entertainment and relaxation options.
#
# In honor of the occasion FLASH this week will only offer Carnival specials!
# Get on board this marvelous vessel and cruise the Caribbean for 7 days for
# only $767. FLASH also has the Pride's sister ship, the Carnival Spirit,
# cruising the cool glaciers of Alaska for 7 days and only $694. And finally,
# just perfect for a quick fun loving getaway, the Imagination stands tall.
# Enjoy it for four spectacular days and only $428. All prices include port!
#
# Alex Aliksanyan
# President/CEO
#
# PS If you had 27,000 points on your icruise credit card, that Pride sailing
# would be totally FREE!
# *****
# ********
# 350 / Winston loved his trip to Austin - Not / cweldon@houston.rr.com / eric.bass@enron.com / Wed, 16 Jan 2002 20:38:59 -0800 (PST)
# ============
# We ain't won yet but at least we've won that head to head battle for maybe only the second time this year
#
# <
# *****
# ********
# 351 / Get into the shows! / foxsportsflash_h@mailings.foxsports.com / foxsportsflash_h@mailings.foxsports.com / Wed, 16 Jan 2002 19:14:40 -0800 (PST)
# ============
# <  <  <Tired of channel surfing, looking for your favorite FOX Sports shows? FOXSports.com on Lycos has created the ultimate guide for FOX Sports and Fox Sports Net television and radio programming. Check out our new Show Pages <0116_h
#
# You can find out what's new with your favorite shows like Best Damn Sports Show Period and National Sports Report, watch the latest video clips, get the inside scoop on your favorite talent, participate in show polls, and chat back in the Fan Forums. Plus, you can find out who will be on upcoming shows and a daily schedule of when to watch.
#
# Check out the show pages now! <0116_h
#
# Show Page Index <0116_h
# NFL This Morning <4738&mailInfo 0116_h
# NFL on FOX <4904&mailInfo 0116_h
# MLB on FOX <2562&mailInfo 0116_h
# NASCAR on FOX <2048&mailInfo 0116_h
# Totally NASCAR <2090&mailInfo 0116_h
# NASCAR This Morning <2232&mailInfo 0116_h
# NASCAR Victory Lane <2110&mailInfo 0116_h
# NASCAR Tech <2204&mailInfo 0116_h
# ACC on FOX <1592&mailInfo 0116_h
# College Football Saturday <3692&mailInfo 0116_h
# National Sports Report <1336&mailInfo 0116_h
# The Last Word with Jim Rome <2438&mailInfo 0116_h
# Best Damn Sports Show <2416&mailInfo 0116_h
# Beyond the Glory <2242&mailInfo 0116_h
# You Gotta See This! <2486&mailInfo 0116_h
# FOX Sports Radio <1344&mailInfo 0116_h
#
# - The FOXSports.com on Lycos Team
#
#
# To unsubscribe from future FOXSports.com emails, click here. <mailto:FOXSportsFlash_h-unsubscribe@mailings.foxsports.com
# or send a blank email to:
# FOXSportsFlash_h-unsubscribe@mailings.foxsports.com
#
#
#
#   <NFL DIVISIONAL PLAYOFFS on FOX
#
# Saturday
# FOX NFL Sunday 3:30 p.m. <4904&mailInfo 0116_h
# Philadelphia at Chicago 4:30 p.m.
#
# Sunday
# NFL This Morning 10 a.m. <4738&mailInfo 0116_h
# FOX NFL Sunday 3:30 p.m. <4904&mailInfo 0116_h
# Green Bay at St. Louis 4:00 p.m.
#
# All times Eastern
#
#
#  <0116_h
#
#  <FOXSports.com Video of the Week:
#
# Best Damn Advice for Schottenheimer <7418&mailInfo 0116_h
#
#
# Fox Sports Net has hoops, hockey and more. Check your local listings for times and channels.
#
# NFL <0116_h
# NBA <&mailInfo 0116_h
# NHL <2&mailInfo 0116_h
# College Hoops <&mailInfo 0116_h
# AllMadden.com <0116_h
# Register at FOXSports.com <0116_h
#
#
#   <
# *****
# ********
# 352 / A friend / lwbthemarine@alltel.net / eric.bass@enron.com, bass.jason@enron.com, bass.k.@enron.com / Wed, 16 Jan 2002 16:30:00 -0800 (PST)
# ============
# A simple friend has never seen you cry.
# A real friend has shoulders soggy from your tears.
#
# A simple friend doesn't know your parents' first names.
# A real friend has their phone numbers in his address book.
#
# A simple friend brings a bottle of wine to your party.
# A real friend comes early to help you cook and stays late to help you clean.
#
# A simple friend hates it when you call after he has gone to bed.
# A real friend asks you why you took so long to call.
#
# A simple friend seeks to talk with you about your problems.
# A real friend seeks to help you with your problems.
#
# A simple friend wonders about your romantic history.
# A real friend could blackmail you with it.
#
# A simple friend, when visiting, acts like a guest.
# A real friend opens your refrigerator and helps himself.
#
# A simple friend thinks the friendship is over when you HAVE an argument.
# A real friend knows that it's not a friendship until after you've had a fight.
#
# A simple friend expects you to always be there for them.
# A real friend expects to always be there for you!
# *****
# ********
# 353 /  / lwbthemarine@alltel.net / lwbthemarine@alltel.net / Wed, 16 Jan 2002 16:28:16 -0800 (PST)
# ============
# Sometimes, we wonder why friends keep forwarding jokes to us
# without writing a word, maybe this could explain:
#
# When you are very busy, but still want to keep in touch, guess what
# you do ... you forward jokes.  When you have nothing to say, but
# still want to keep contact, you forward jokes.
#
# When you have something to say, but don't know what, and don't
# know how, you forward jokes.  And to let you know that you are
# still remembered, you are still important, you are still loved, you
# are still cared for, guess what you get?  A forwarded joke.
#
# So my friend, next time if you get a joke, don't think that you've
# been sent just another forwarded joke, but that you've been
# thought of today and your friend on the other end of your
# computer wanted to send you a smile.  =)
# *****
# ********
# 354 / NETCO Employees at Enron / announcements.enron@enron.com / dl-ga-all_ees@enron.com, dl-ga-all_enron_north_america@enron.com,
# 	dl-ga-all_enw@enron.com / Wed, 16 Jan 2002 16:15:47 -0800 (PST)
# ============
# As you are all aware, Enron and UBS have entered into an agreement for the sale of certain assets of the wholesale gas and power trading organization.  As part of that agreement, the management of UBS may speak to you over the next several days about an opportunity in that new organization.  If so, we encourage you to consider such an offer. However, if you are not employed by UBS, you remain an Enron employee.  If you have specific questions regarding your employment arrangements and job responsibilities please contact Anne Labbe in Human Resources at 5-7809, or feel free to contact either Jim Fallon or Dave Delainey directly.
# *****
# ********
# 355 / Sunshine Kids Benefit Golf Tournament - March 18th / teresa.knight@nesanet.org / None / Wed, 16 Jan 2002 14:01:07 -0800 (PST)
# ============
# Dear Members:
#
# NESA is pleased to be holding its 3rd Annual Benefit Golf Tournament on
# Monday, March 18th, 2002 at the prestigious Champions Golf Club.  Proceeds
# will again benefit The Sunshine Kids Foundation.
#
# This is your opportunity to secure a corporate ($2000) or individual ($500)
# sponsorship which includes a foursome or a single tee time, respectively for
# this outstanding tournament and great cause.  Attached are registration
# forms.
#
# NESA has been proud to donate over $50,000 in the last two years to local
# charities through this tournament, and we need your help to continue to do
# so.  If you have any questions, please feel free to email me or call me at
# 713/856-6525.
#
# Don't forget about our mixer on Thursday, January 31st at the Boaka Bar
# downtown. No cover, first drink free - can't beat it!  RSVP to me if you can
# make it.  Visit their website for directions at
# www.mercuryroom.com/boaka/boaka.html
#
# TERESA A. KNIGHT
# Vice President, Member Services
# teresa.knight@nesanet.org
# (713) 856-6525
# Fax (713)856-6199
#
#
#  <<INVITE LETTER - INDIVIDUAL REGISTRATION FORM.doc
# SPONSOR REGISTRATION FORM.doc
# *****
# ********
# 356 / Get RealOne Music - Download your favorite songs! / news@real-net.net / ebass@ect.enron.com / Wed, 16 Jan 2002 13:52:34 -0800 (PST)
# ============
# (For e-mailing list removal information see bottom of e-mail.)
# *****
# ********
# 357 / CNN Breaking News / breakingnews@mail.cnn.com / textbreakingnews@cnnimail12.cnn.com / Wed, 16 Jan 2002 11:45:02 -0800 (PST)
# ============
#
# *****
# ********
# 358 / Photos / daphneco64@alltel.net / eric.bass@enron.com / Wed, 6 Feb 2002 07:26:48 -0800 (PST)
# ============
# Hi Eric,
#
# Please send me the wedding photos when you get a chance.
#
# Have a wonderful day.  LU-M
# *****
# ********
# 359 / Save 30% on "See No Evil: The True Story of a Ground Soldier in the
#  CIA's Counterterrorism Wars" by Robert Baer / book-news@amazon.com / ebass@enron.com / Wed, 16 Jan 2002 10:02:45 -0800 (PST)
# ============
# <
# *****
# ********
# 360 / January Public Training / abaker@skippingstone.com / ebass@enron.com / Wed, 16 Jan 2002 11:59:43 -0800 (PST)
# ============
# <energy training <
# *****
# ********
# 361 / Re: Birthday / daphneco64@alltel.net / eric.bass@enron.com / Wed, 16 Jan 2002 09:45:33 -0800 (PST)
# ============
# Something to do with Bob Hebert's finance committee.  LU-M
# *****
# ********
# 362 / RE: Happy Birthday / bdeck62@yahoo.com / eric.bass@enron.com / Wed, 16 Jan 2002 09:27:18 -0800 (PST)
# ============
# Hi Eric
#
# I told your Mom we would decide on my visit after all the wedding festivities are overwith.  I'm sorry I can't make it to the wedding but I have a few loose ends to clear up since my last day of work here is January 31.  I'll spend time with all of you when I visit.  I'm looking forward to it.
#
# The weather here is cold and blustery.  We had 14" of snow on January 6 but most of that is gone now.  We are to get snow showers over night but they only predict around an inch for the morning.
#
# Hi to Shanna and keep in touch.
#
# Love  Aunt Bonnie
#
#   "Bass, Eric" <Eric.Bass@ENRON.com
#
# Hi Aunt Bonnie,
#
# It is great to hear from you.  We really missed the fact that your trip was delayed because of 9/11.  Things will be pretty hectic this weekend with Jason's bachelor party and my birthday.  We are going to dinner tomorrow night for my birthday to a restaurant that I have never tried. It should be good.
#
# On Saturday, we will be celebrating Jason's bachelor party.  We are going on a casino cruise out of Galveston.  I am looking forward to it.
#
# When do you think that you are going to make it down for a visit?  How is the weather treating you up there?
#
# It was nice to hear from you.
#
# Love,
#
# Eric
# *****
# ********
# 363 / : Happy Birthday / lwbthemarine@alltel.net / eric.bass@enron.com, bass.jason@enron.com, bass.k.@enron.com / Wed, 16 Jan 2002 08:41:59 -0800 (PST)
# ============
# Original Message
# *****
# ********
# 364 / New Stock Symbol / chairman.enron@enron.com / dl-ga-all_enron_worldwide1@enron.com / Wed, 16 Jan 2002 06:45:32 -0800 (PST)
# ============
# Enron announced today that its common stock will now be traded as an Over-the-Counter (OTC) equity security under the symbol "ENRNQ."  This follows a decision by the New York Stock Exchange (NYSE) to file an application to delist Enron's common stock, which means that Enron's common stock and related securities are suspended from trading on the NYSE.  Enron is considering whether to appeal the NYSE's decision.
#
# The NYSE has standard criteria for listing stocks, which can be found on their website at www.nyse.com.  Enron recently fell below the following listing criteria: average closing price of a security less than $1.00 over a consecutive 30 trading-day period.  Quotation service for Enron's stock will now be provided by the National Quotation Bureau, LLC "Pink Sheets."
# *****
# ********
# 365 / Birthday / daphneco64@alltel.net / eric.bass@enron.com / Wed, 16 Jan 2002 04:33:53 -0800 (PST)
# ============
# Hi Eric,
#
# Sorry but Dad can't make it Thursday night.  Would dinner here on Friday be o.k. with you?  Dad suggested games, etc., and I wanted to bake a birthday cake.  We can either order in or I would love to cook anything you would like.  It's up to you.  Let me know.
#
# Have a great day.
#
# Love, Mom
# *****
# ********
# 366 / Happy Birthday / bdeck62@yahoo.com / eric.bass@enron.com / Tue, 15 Jan 2002 15:46:18 -0800 (PST)
# ============
# Hi Eric,
#
# I know this weekend will be a busy one for you but I just wanted to wish you an early Happy Birthday.  Hope all is well with you and Shanna.  I hope to see you in a few months.
#
# Love   Aunt Bonnie
#
#
#
#   _____
#
# Do You Yahoo!?
# Send FREE video <
# *****
# ********
# 367 / New York / timothy.blanchard@enron.com / eric.bass@enron.com / Tue, 15 Jan 2002 11:23:18 -0800 (PST)
# ============
# Just wanted to let you know that I saw the Crowne Plaza on special on this website.  If you haven't paid for the room, you might want to check it out; could save you about $50.
# *****
# ********
# 368 / NetcoOnline Launch Plans / david.forster@enron.com / orig.dl-eol@enron.com / Fri, 11 Jan 2002 16:03:53 -0800 (PST)
# ============
# We are getting ready for the launch of "NetcoOnline" and have been preparing new documentation, a refreshed site design and cleaned products to reflect our Gas and Power focus.
#
# The following timetable could change, but the general sequence should apply in any case:
#
# Week of Jan 14:
#
# Upon approval by the new buyer of the PA and ETA formats, we will contact the Master Users at our Top 50 customers and send them copies of the final PA and ETA forms with our new buyer's name filled in. During this week, we will be working hard to get as many of the PA's returned as possible. Once we have an approved PA, we can send the customer their new User ID, which will allow them to start trading on the day we launch "NetCoOnline".
#
# A Splash page will be available within two business days of knowing our new company name, on a web page reached via an automatic redirect from www.enrononline.com. This page will tell customers about the pending launch of "NetCoOnline" and provide links to the PA and Registration screens and also to the User Admin screens, which will allow customer Master Users to start setting up their Sub users.
#
# The Splash page will look something like the following:
#
#
#
#
# A Press Release will be issued which will include the planned launch date of "NetcoOnline"
#
# Week of Jan. 21:
#
# If all goes well, "NetcoOnline" will be launched on Tuesday, January 22, with at least financial products (timing for gas physical and power physical to be determined according to regulatory issues).
#
# We will send out a mass mailing to approx. 3,000 individuals at 450 companies inviting them to sign up for NetcoOnline. Included in the package will be a simple brochure, copies of the PA and ETA, key messages and a list of Frequently Asked Questions.
#
# General Terms and Conditions (GTC's) will be available online and must be accepted online before a company can start to trade a particular commodity.
# *****
# ********
# 369 / Hit the Beach ... with a Hot-Fare! / thehotwire@hotwire.m0.net / ebass@enron.com / Wed, 6 Feb 2002 05:15:40 -0800 (PST)
# ============
# Hotwire <  < <  < <  < <  <  <  <  <
#
#   <from:
# *****
# ********
# 370 / Re: What's Up / bthoskins@hotmail.com / eric.bass@enron.com / Fri, 11 Jan 2002 11:29:30 -0800 (PST)
# ============
# Eric,
#
# Thanks for the news on our friends.  It sounds like everyone's getting along pretty well, all things considered.  I saw Enron on NBC Nightly News last night.  Tom Brokaw had a long special on the Congressional inquiry, and they had some footage of people leaving the building.  I also saw a shot of the trading floor on CNN yesterday from last year.  I saw Dick Jenkins, but couldn't see if there was anyone else I knew.  It's amusing to see how the media reports so many half-truths and misleading information.
#
# I got a call from Hector the other day but haven't had a chance to talk to him.  He recently got a job with the Clinton group in NYC, so he's pretty excited about that.  That's great that your brother's wedding is coming up.  Tell him congratulations for me.  Are you the best man?
#
# Hope the bidding turns out well.  Happy surfing in the meantime!
#
# Brian
# *****
# ********
# 371 / BMW Owners' Rewards / bmwna@bmwna.rgc2.net / ebass@enron.com / Thu, 10 Jan 2002 10:39:58 -0800 (PST)
# ============
# <  <
# *****
# ********
# 372 / Re: Deferred Annuity / lwbthemarine@alltel.net / eric.bass@enron.com / Thu, 10 Jan 2002 09:47:28 -0800 (PST)
# ============
# Good morning. Yes, I did look at the annuity link. It looks good to me. It
# is run by an insurance company. Thus, I assume there will be not only the
# standard fees charged by whatever mutual fund in which you invest, but some
# charge made by the ins. co. Thus, you should make certain those charges are
# reasonable and defined. Additional, if the your money is actually paid by
# you to the ins. co.( verses directly to the specific mutual funds) to be
# invested, which I suspect is the case, then you must select a financially
# strong ins.co. Do not want an Enron fiasco with this type of retirement
# investment. Let me know if you have any questions. Love-Dad
# *****
# ********
# 373 / FW: Customers / charles.weldon@enron.com / eric.bass@enron.com, david.baumbach@enron.com / Fri, 4 Jan 2002 08:46:05 -0800 (PST)
# ============
#
# *****
# ********
# 374 / USAA Electronic Delivery Notification / usaa.electronic.documents@eddmail.usaa.com / eric.bass@enron.com / Fri, 28 Dec 2001 12:38:13 -0800 (PST)
# ============
# New electronic document(s) have been delivered and are available for you to read under your
# personal account at usaa.com.
#
# To access your documents:
#
# -   Go to .
# -   Enter your USAA number and password and click "Log On".
# -   Click on "Documents" in the upper right corner.  You will then be
# *****
# ********
# 375 / Read the Bible through in a year / david.baumbach@enron.com / eric.bass@enron.com / Thu, 27 Dec 2001 07:06:20 -0800 (PST)
# ============
# Eric,
#
# Thought you may be interested in trying to do this.
#
# Dave
# *****
# ********
# 376 / Honeymoon Itinerary / jbass1@houston.rr.com / eric.bass@enron.com / Wed, 26 Dec 2001 13:17:23 -0800 (PST)
# ============
# Attached is the path to the honeymoon package we chose.
#
# Let me know if you need anything else.  Thanks again for doing this...it means a great deal to us both.
#
# Jason
# *****
# ********
# 377 / Let the Games Begin! Rockets Tip Off Tomorrow / eblastoff@rocketball.com / ebass@enron.com / Mon, 29 Oct 2001 19:20:31 -0800 (PST)
# ============
# Dear eric,
# *****
# ********
# 378 / Lexis-Nexis Training: Houston & Worldwide / Dow Jones Training / no.address@enron.com / None / Mon, 29 Oct 2001 19:06:37 -0800 (PST)
# ============
# eSource Presents Lexis-Nexis Training
#
# Basic
#
# Lexis-Nexis Basic is geared to the novice or prospective user.  You will learn the basics of getting around Nexis.com.
#  We will talk about news and company information available on Lexis-Nexis.
#
# Attend our Lexis-Nexis Basics Clinic:
# *****
# ********
# 379 / Rescheduled Dates for PROS 9th Annual Pricing & Revenue
#  Optimization Conference / annualconference@prosrm.com / ebass@enron.com / Mon, 29 Oct 2001 17:13:15 -0800 (PST)
# ============
# World events and resulting airline-industry actions have led us to reconsider the timing of our annual forum. To allow participants to focus on what needs to be done in the recovery from September 11, and to avoid distraction, we have decided to reschedule our Annual Pricing and Revenue Optimization Conference
# *****
# ********
# 380 / Get your favorite golfers to play for YOU! / noreply@ccomad3.uu.commissioner.com / eric.bass@enron.com / Wed, 6 Feb 2002 01:10:19 -0800 (PST)
# ============
# What if five of the PGA Tour's best golfers teamed up with
# YOU? Sound like fantasy? Well, it is fantasy -
# CBS SportsLine.com's Fantasy Golf!
#
# It's so simple to play. Just spend $1 Million of fantasy
# money on the five golfers you think will top the
# leaderboard at each PGA Tour tournament.
#
# Sign up now to pick your golfers for the Buick Invitational.
# Fantasy Golf is FREE to play!
#
# Fantasy golf is broken up into three separate segments.
# Finish among the top three scorers during any segment and
# you can win cash prizes!
# *****
# ********
# 381 / CNN Breaking News / breakingnews@cnn.com / textbreakingnews@cnnimail4.cnn.com / Mon, 29 Oct 2001 14:05:02 -0800 (PST)
# ============
# BREAKING NEWS from CNN.com
# *****
# ********
# 382 / FW: gas & power interviewers Trading Track / karen.buckley@enron.com / kevin.ruscitti@enron.com, f..keavey@enron.com, eric.bass@enron.com / Mon, 29 Oct 2001 13:44:15 -0800 (PST)
# ============
# Kevin/Peter/Eric
#
# We are holding 32 interviews for the ENA Trading Track this Thursday, November 1st from 2.30 pm onwards.   Your names have been passed to me by Hunter Shively.
# *****
# ********
# 383 / Online CFA Program Registration / aimr2001@bbh1.viamedialinq.com / ebass@enron.com / Wed, 24 Oct 2001 16:12:32 -0700 (PDT)
# ============
# If you have not yet had the opportunity to enroll for the 2002 CFA exam, AIMR is pleased to announce that you now can do so electronically through the AIMR Web site at
# The next enrollment deadline is 3 December 2001 and, as a reminder, this year AIMR must RECEIVE your enrollment form and payment by the deadline date.
#
# Many CFA candidates have inquired about the status of the New York Society, which had its office in the World Trade Center. We are happy to report that all NYSSA staff escaped safely on 11 September, that the organization is relocating to midtown Manhattan, and that is up and running with a full slate of educational programs. Visit for information about NYSSA's Fall and Spring continuing education and CFA review courses, and seminars.
# *****
# ********
# 384 / New Link for All-Employee Meeting / no.address@enron.com / None / Mon, 22 Oct 2001 21:00:26 -0700 (PDT)
# ============
# Attached is a new link for employees unable to attend the all-employee meeting today at 10 a.m. (CDT) at the Hyatt Regency Houston, Imperial Ballroom. If you are located in London, Calgary, Toronto, Omaha, New York, Portland (ENA) or Houston, you can access the live event at
# *****
# ********
# 385 / To: All Domestic Employees who Participate in the Enron Corp
#  Savings Plan / no.address@enron.com / None / Mon, 22 Oct 2001 20:28:00 -0700 (PDT)
# ============
# October 26 is fast approaching!
#
# Mark your calendar
# *****
# ********
# 386 / [Footballguys] Update # 131  Week 7 Upgrade - Downgrade / bryant@cheatsheets.net / cheatsheets@yahoogroups.com / Mon, 22 Oct 2001 18:19:21 -0700 (PDT)
# ============
# Hi Folks,
#
# Another wild week in the NFL.   We've got Footballguy Scott Luebke's Week 7
# Upgrade - Downgrade - Waiver Wire Picks.
#
# Before we get to that though, let me throw out something I posted today on
# our message boards regarding owners who beat themselves up second guessing
# themselves.   This season has been as tough to predict as any in recent
# memory and I thought this might be something some of you might need to hear.
# *****
# ********
# 387 / None / None / None / None
# ============
# One of our message board members was (justifiably) frustrated with watching
# Trung Canidate blow up on his bench while Ahman Green and Ricky Williams
# fared less well as his starters.
#
# My reply to him:
#
# Don't be down on yourself.   That's the nature of the game.   There is no
# way you bench Ricky Williams or Ahman Green for Canidate when Canidate was
# such a question mark last week.   You did what just about every one of us
# would have done I'm guessing.
#
# It's part of the game.   Is it frustrating?   Sure it is.   But it's still
# part of the game.   In my local league last week, I took a chance again on
# Antonio Freeman after starting him for the first few weeks (but not week 5 -
# Aargh... )   Did it play out?   No, it didn't.   I had guys on my bench who
# outscored him.   But looking back on everything I knew with Minnesota and
# Billy Schroeder, it was the right call for me.
#
# I learned a long time ago the secret to Fantasy Football.   You just have to
# take the best info you can assemble, make your call and let the players do
# the rest.   Just like a real GM.   You can only do so much.
#
# If you got beat because you didn't know Terry Glenn was out and you started
# him, well, that's your bad.   But if you got beat because Trung Canidate
# decided to play the game of his life, and proven RBs Williams and Green did
# not, well, that's not your fault.
#
# I promise you, if you can predict things to that degree, you need to quit
# your job and head to Vegas.
#
# Control what you can control.   Bust your butt to know all you can know.
# Make the best decisions you can make and be comfortable you've done all you
# can do.   After that, just enjoy the games.   Trust me, you'll be a better
# owner because of it.
#
# Ok, let's jump to Scott's report for this week.
#
# Have a great week, everyone.
#
# Joe
#
# /**/**/**/**/**/**/**/**/**/**/**/**/**/**/**/**/
#
#
# Upgrades
#
#
# QB - Tom Brady (Waiver Wire) - 5 touchdown passes in the last 2 weeks
# deserves an upgrade in my book.  More importantly, Brady has yet to throw an
# interception this season.  When Bledsoe returns from injury, the Patriots'
# coaching staff will have a very difficult decision to make.   There's even
# some talk that Bledsoe might not return this season.   Right now, Brady
# deserves a pickup by any fantasy team needing a quarterback.
#
# QB - Tim Couch - The yardage numbers won't win any awards, but the 4
# touchdowns in the last 2 games is impressive.  Couch is starting to show
# signs of becoming a very good quarterback in this league.  Keep in mind, a
# tough schedule looms ahead for Couch.  However, with the Browns offense
# improving, he should be considered a top quarterback for teams in a keeper
# league looking towards the future.
#
# QB - Doug Flutie - The Flutie magic continues to strike.  He's not the best
# fantasy quarterback, but numerous fantasy teams can be aided by inserting
# Flutie into the lineup.  With Curtis Conway and Jeff Graham staying healthy,
# Flutie should be considered a top 15 quarterback this season.  With a strong
# rushing game keeping defenses honest, look for Flutie to post numbers
# similar to Sunday on occasion.  280 passing yards and 2 scores is
# respectable against a tough Denver defense.
#
# RB - Anthony Thomas -The A-Train continues to ride into fantasy starting
# lineups.  We've been hyping him for weeks and it appears he'll be named the
# official starter in Chicago shortly.  With 188 yards and a touchdown on
# Sunday, can the Bears afford to keep him out of the lineup?  I think not.
#
# RB - Trung Canidate - Faulk owners need not worry about using Canidate as a
# filler.  232 total yards and 2 touchdowns...WOW!   At the very least he'll
# see more action even when Faulk is back.
#
# RB - Jerome Bettis - Bettis has rolled to 4 consecutive 100-yard games.
# Look for this trend to continue.  With the Steelers defense playing
# excellent and Kordell Stewart limiting turnovers, look for Bettis to have
# more good games as the season progresses.
#
# RB - Michael Pittman - We told you to jump off the Thomas Jones bandwagon
# and hop on the Pittman express earlier in the season.   With Pittman seeing
# 80% of the carries and more importantly producing, all looks good for
# Pittman owners.  I've never been an advocate of starting Cardinals' running
# backs though.  After his 137 total yards and a touchdown performance, now
# may be the time to deal Pittman.
#
# RB - Jason Brookins (Waiver Wire) - Terry Allen's ankle sprain may be all
# Brookins needs to become the team's starting running back.  He's looked good
# running behind a pretty solid offensive line, but his carries have been
# limited due to Allen's presence.  Keep in mind, the Ravens are contacting
# other teams about trading for another back prior to the trade deadline.
# Right now, Brookins is a solid waiver wire choice.
#
# WR - David Patten (Waiver Wire) - Anyone who rushes, passes and receives for
# a touchdown in the same game deserves an upgrade.  With Terry Glenn being
# bothered by a hamstring injury, Patten made the most of his opportunity.  He
# has looked good over the last few weeks and has shown the ability to make
# plays, which is needed in the Patriots offense.  Grab him, if you are in
# need of a receiver.
#
# WR - David Terrell (Waiver Wire) - Terrell had a breakout game on Sunday
# with 7 catches for 91 yards.  More importantly for his fantasy value, Marcus
# Robinson suffered a serious knee injury and is lost for the season.  The
# Robinson injury makes way for Terrell to enter the Bears' starting lineup.
# If you're in need of a receiver, Terrell is the best option in the free
# agent market, if he is still available.
#
# WR - Keyshawn Johnson - Johnson has yet to score a touchdown this season,
# but he is doing everything else.  Johnson is averaging 8 catches/game and
# appears unstoppable at times.  However, he did suffer a hip flexor injury
# late in the game and appears questionable for this week's game.
#
# WR - Johnnie Morton - Morton continues to impress this season.  He has
# surpassed the 100-yard mark 3 times this season and scored 3 touchdowns.
# With Germane Crowell and Herman Moore out for the season, Morton becomes the
# team's #1 wide receiver.  Morton owners should be happy.
#
# WR - David Boston - Plain and simple, Boston is bigger, faster and better
# than any defensive back on the field.  In his first 5 games, Boston is
# averaging 96 receiving yards/game.  Keep him in your lineup every week.
#
# WR - Jeff Graham - With the San Diego running game and LaDainian Tomlinson
# garnering a lot of attention, the receiving corps is able to see plenty of
# open spaces downfield.  Graham scored his first two touchdowns of the season
# and gained 107 yards on Sunday.  With defenses focusing on Tomlinson, look
# for Flutie to find Graham for 5-6 more touchdown passes this season.
#
# WR - Rod Gardner (Waiver Wire) - While Michael Westbrook appears invisible,
# Gardner is impressing on the other side of the field.  208 yards and a
# touchdown (with another score called back), Gardner is starting to claim the
# title of "best rookie receiver".  Grab him, if he is available in your
# league.  Gardner is the lone bright spot in the Redskins passing game.
#
# TE - Bubba Franks - Franks has been diagnosed with Cris Carter disease
# because "All he does is catch touchdowns".  6 touchdowns in 6 games.  If
# only he can start picking up yardage points.
#
# TE - Cam Cleeland - Cleeland scored another touchdown on Sunday to increase
# the total to 4 scores this season.  With Aaron Brooks struggling to find his
# wide receivers in the red zone, Cleeland's value should remain high for a
# little while longer.
#
#
# /**/**/**/**/**/**/**/**/**/**/**/**/**/**/**/**/
#
#
# Downgrades
#
#
# QB - Aaron Brooks - Brooks has been struggling trying to find his receivers,
# especially in the red zone.  With just 4 touchdowns in his last 4 games,
# Brooks is in a minor slump.  There's no need to jump off his bandwagon.  On
# the flip side, an upturn in production is possible over the next 4 weeks as
# New Orleans faces: St. Louis, NY Jets, San Francisco and Indianapolis.  But
# for now, we're a little worried and Brooks needs to be downgraded with our
# fingers crossed to see him upgraded starting next week.
#
# QB - Elvis Grbac - Two injuries in two weeks have Grbac downgraded once
# again this week.  Without a consistent running game, look for Grbac's
# struggles to continue.  For now, Grbac is expected to be listed as
# questionable for this week's game against Jacksonville.
#
# QB - Charlie Batch - With 338 yards and 3 touchdowns, many would think that
# Batch deserves an upgrade.  Well, if the box scores were the only thing
# studied, this would be the case.  However, the season ending injury to
# Batch's #1 receiving option, Germane Crowell, gives Batch a downgrade in my
# book.  With both Crowell and Herman Moore out for the season, Batch must
# rely on Johnnie Morton and Larry Foster as his starting receivers...not a
# good sign.
#
# QB - Vinny Testaverde - Testaverde was unable to get anything going against
# the Rams on Sunday.  With the Rams leading by a significant margin,
# Testaverde was benched in order to get Chad Pennington some playing time.
# All in all, not a good sign for Testaverde owners.  Testaverde's yardage
# numbers are poor this season.  However, he has thrown for multiple
# touchdowns in 3 of his 6 games this season.
#
# RB - Warrick Dunn - Dunn suffered a hamstring strain on Sunday against the
# Steelers.  Look for Dunn to be listed as questionable on the injury report
# this week.  With the Vikings mediocre defense coming to town, Dunn's owners
# can't be very happy with this recent turn of events.  Joe's email updates
# will keep you posted on the latest Dunn news.
#
# RB - Michael Bennett - Chapman was able to rush for 90 yards on 22 carries
# during Sunday's game versus Green Bay.  This is bad news for the
# unproductive, injured Bennett.  With Bennett failing to clear the 60-yard
# mark this season, his starting job is in jeopardy.  Keep an eye on this
# situation.
#
# RB - James Stewart - Stewart suffered an ankle sprain in Sunday's loss to
# the Titans.  He was limited to 17 yards on 9 carries before leaving the
# game.  Expect him to be listed as questionable for this week's game.  As
# more of a straight ahead runner, Stewart may be able to play on the injury
# and be somewhat effective.  With this week's game on astroturf, the Lions
# may decide to rest Stewart and get him back to 100% health.  Regardless, any
# kind of injury to an often injured player deserves a downgrade.
#
# RB - Tim Biakabatuka - Biakabatuka suffered a broken foot and is lost for
# the season.
#
# RB - Terry Allen - Allen was limited to 12 yards on 3 carries after
# suffering an ankle injury on Sunday.  Backup Jason Brookins replaced Allen
# and looked decent.  If Allen misses any action, Brookins may replace him as
# the team's starter with one good performance.  The Ravens are exploring
# trade options for another running back prior to the trade deadline, so the
# Ravens RB situation is cloudy at the current time.
#
# RB - James Allen - We've been hyping Anthony Thomas for weeks and it appears
# he will soon be named the official starting RB in Chicago.  Plain and
# simple, Allen has been horrible this season.  With Thomas gaining 188 yards
# on 22 carries, Allen will be relegated to spot duty.
#
# RB - LaDainian Tomlinson - Tomlinson was limited to 58 yards on 25 carries
# and 0 touchdowns against a stingy Broncos defense.  It was bound to happen
# ...
# ypc) against a tough Buc team.   It'll be much easier this week against the
# swiss cheese Vikings ranked # 30 in Rushing Yards Allowed per Game over the
# last 4 weeks.   Although, these Vikings did shut down Ahman Green last week.
# For the year, they rank # 31 in Fantasy Points Allowed to RBs.
#
#
# Denver's Terrell Davis vs Indianapolis Defense
#
# Terrell Davis looked good again rushing for 89 yards on 18 carries (4.9 ypc)
# It's been a tough year and you can bet he'll want to finish strong.   The
# Colts rank # 23 in Rushing Yards Allowed per Game over the last 4 weeks.
# For the year, they rank # 29 in Fantasy Points Allowed to RBs.
#
#
# New England's Antowain Smith vs Carolina Defense
#
# A rested Antowain Smith faces the soft Carolina defense that's ranked # 31
# in Rushing Yards Allowed per Game over the last 4 weeks.   For the year,
# they rank # 20 in Fantasy Points Allowed to RBs.   Great matchup.
#
#
# Pittsburgh's Chris Fuamatu-Ma'afala / Jerome Bettis vs Cleveland Defense
#
# Fuamatu-Ma'afala was a workhorse on the ground Sunday but didn't have a lot
# to show for it.   He ran 25 times for 55 yards (2.2 ypc)   He did score on a
# receiving TD.   He'll face a weak Cleveland defense ranked # 29 in Rushing
# Yards Allowed per Game over the last 4 weeks.   For the year, they rank # 20
# in Fantasy Points Allowed to RBs.
#
#
# Washington's Stephen Davis vs Arizona Defense
#
# Stephen Davis looked great rushing for 111 yards on 21 carries (5.3 ypc) and
# the score.   He left with a knee tweak but it doesn't look to be serious.
# Ki-Jana Carter played great after Davis left.   The Cardinals rank # 21 in
# Rushing Yards Allowed per Game over the last 4 weeks.   For the year, they
# rank # 22 in Fantasy Points Allowed to RBs.
#
#
# /**/**/**/**/**/**/**/**/**/**/**/**/**/**/**/**/
#
#
# Prime Matchups:  These games feature Defenses that haven't been strong
# lately.
#
#
# Buffalo's Shawn Bryson / Travis Henry / Sammy Morris vs Miami Defense
#
# Bryson ran wild again rushing 28 times for 107 yards (3.8 ypc).   Sammy
# Morris spelled him for a few carries and looked good too but it seems Bryson
# is clearly the man here.   It's possible Henry could see action so keep an
# eye on this one through the week.   The Dolphins have fallen down to # 28 in
# Rushing Yards Allowed per Game over the last 4 weeks.   For the year, they
# rank # 17 in Fantasy Points Allowed to RBs.
#
#
# Dallas' Emmitt Smith vs Detroit Defense
#
# Emmitt looked very solid again rushing for 126 yards on 26 carries (4.8 ypc)
# although he failed to score.   He needs a little over 60 yards to get 1,000
# for the season so you can bet he'll be gunning for that.   The Lions rank #
# 18 in Rushing Yards Allowed per Game over the last 4 weeks and # 24 in
# Fantasy Points Allowed to RBs.
#
#
# New York Giants' Tiki Barber / Ron Dayne vs Green Bay Defense
#
# Barber saw more action with 16 carries and 71 yards (4.4 ypc) but it was
# Dayne who scored with 59 yards on 8 carries (7.4 ypc)   Barber was very
# active again in the passing game.   The Packers let Michael Bennett run well
# Sunday and have slipped to # 27 in Rushing Yards Allowed per Game over the
# last 4 weeks.   For the year, they rank # 13 in Fantasy Points Allowed to
# RBs.
#
#
# New York Jet's Curtis Martin vs Oakland Defense
#
# Martin put in another Martin Like day with 115 yards on 19 carries (6.1 ypc)
# The Jets may have problems, but Martin isn't one.   He'll face an Oakland
# defense ranked # 19 in Rushing Yards Allowed per Game over the last 4 weeks.
# For the year, they rank # 21 in Fantasy Points Allowed to RBs.
#
#
# Oakland's Charlie Garner vs New York Jets Defense
#
# The Raiders don't look nearly as strong as they did.   Garner only had 9
# carries Sunday for 23 yards (2.6 ypc)   Tyrone Wheatley only had 5 carries.
# This week they've got a nice matchup as they'll face the Jets ranked # 26 in
# Rushing Yards Allowed per Game over the last 4 weeks.   For the year, they
# rank # 27 in Fantasy Points Allowed to RBs.
#
#
# Seattle's Shaun Alexander vs Kansas City Defense
#
# Alexander didn't do much Sunday rushing 23 times for 59 yards (2.6 ypc)   He
# 'll be ok though and gets to face a Chief defense ranked # 22 in Rushing
# Yards Allowed per Game over the last 4 weeks.   For the year, they rank # 23
# in Fantasy Points Allowed to RBs.
#
#
# St. Louis' Marshall Faulk vs Atlanta Defense
#
# Start Faulk.   The question will be of course how much he plays but it was
# pretty obvious Sunday that Mike Martz lets his guys play.   Trung Canidate
# could have really used the work but he warmed the bench while Faulk went
# nuts.   I'd say you'll get at least a half, maybe much more out of Faulk and
# half of Faulk is worth more than most backs.   The Falcons rank # 24 in
# Rushing Yards Allowed per Game over the last 4 weeks and # 28 in Fantasy
# Points Allowed to RBs.
# *****
# ********
# 496 / Inside The Rockets - December 31, 2001 / eblastoff@rocketball.com / ebass@enron.com / Mon, 31 Dec 2001 12:19:39 -0800 (PST)
# ============
# <html
# <body
# <!
# *****
# ********
# 497 / Start the New Year with These Specials, January 1, 2002 / no-reply@mail.southwest.com / ebass@enron.com / Tue, 1 Jan 2002 01:02:06 -0800 (PST)
# ============
# ================================================================ SOUTHWEST AIRLINES' CLICK 'N SAVE E-MAIL UPDATE
# January 1, 2002
# ================================================================ THE FIRST DAY OF 2002!
#
# Horns are blowing.
# We're making a toast.
#
# To the greatest Customers, Coast to Coast:
#
# Here's to a New Year of LUV
# That comes from the heart
# We wish you prosperity,
# on this brand new start.
#
# Happy New Year!
#
# ================================================================ IMPORTANT TRAVEL INFORMATION
# ================================================================ For updated travel information, please visit:
#
# ================================================================ THIS WEEK'S SPECIALS
# ================================================================ 1. southwest.com Specials for purchase through January 3, 2002
# 2. Subscriber Information
#
# ================================================================ CLICK 'N SAVE SPECIALS
# ================================================================ Albany, NY
#  $77 one-way, to/from Jacksonville, FL
#  $68 one-way, to/from Louisville, KY
#
# Albuquerque, NM
#  $99 one-way, to/from Kansas City, MO
#  $41 one-way, to/from Tucson, AZ
#
# Amarillo, TX
#  $99 one-way, to/from New Orleans, LA
#  $63 one-way, to/from San Antonio, TX
#
# Austin, TX
#  $42 one-way, to/from Midland/Odessa, TX
#  $99 one-way, to/from Phoenix, AZ
#
# Baltimore Washington Int'l, MD
#  $52 one-way, to/from Chicago Midway, IL
#  $35 one-way, to/from Cleveland, OH
#
# Birmingham, AL
#  $62 one-way, to/from Chicago Midway, IL
#  $54 one-way, to/from St. Louis, MO
#
# Boise, ID
#  $37 one-way, to/from Reno/Tahoe, NV
#  $34 one-way, to/from Spokane, WA
#
# Buffalo/Niagara Falls, NY
#  $48 one-way, to/from Norfolk, VA/Southern Virginia
#  $70 one-way, to/from Tampa Bay, FL
#
# Burbank, CA
#  $35 one-way, to/from Las Vegas, NV
#  $99 one-way, to/from Portland, OR
#
# Chicago Midway, IL
#  $52 one-way, to/from Baltimore Washington Int'l, MD
#  $62 one-way, to/from Birmingham, AL
#
# Cleveland, OH
#  $35 one-way, to/from Baltimore Washington Int'l, MD
#  $99 one-way, to/from New Orleans, LA
#
# Columbus, OH
#  $99 one-way, to/from Ft. Lauderdale/Hollywood, FL
#  $64 one-way, to/from Tampa Bay, FL
#
# Corpus Christi, TX
#  $48 one-way, to/from Dallas Love Field, TX
#  $65 one-way, to/from Little Rock, AR
#
# Dallas Love Field, TX
#  $48 one-way, to/from Corpus Christi, TX
#  $36 one-way, to/from Tulsa, OK
#
# Detroit, MI
#  $63 one-way, to/from Omaha, NE
#  $52 one-way, to/from Raleigh-Durham, NC
#
# El Paso, TX
#  $99 one-way, to/from Houston Bush Intercontinental, TX
#  $99 one-way, to/from Houston Hobby, TX
#  $79 one-way, to/from Los Angeles, CA
#
# Ft. Lauderdale/Hollywood, FL
#  $99 one-way, to/from Columbus, OH
#  $34 one-way, to/from Orlando, FL
#
# Harlingen/South Padre Island, TX
#  $89 one-way, to/from Oklahoma City, OK
#  $38 one-way, to/from San Antonio, TX
#
# Hartford, CT/Springfield, MA
#  $99 one-way, to/from Jackson, MS
#  $50 one-way, to/from Raleigh-Durham, NC
#
# Houston Bush Intercontinental, TX
#  $99 one-way, to/from El Paso, TX
#  $55 one-way, to/from Little Rock, AR
#  $55 one-way, to/from Oklahoma City, OK
#
# Houston Hobby, TX
#  $99 one-way, to/from El Paso, TX
#  $55 one-way, to/from Little Rock, AR
#  $55 one-way, to/from Oklahoma City, OK
#
# Indianapolis, IN
#  $99 one-way, to/from Manchester, NH
#  $99 one-way, to/from Providence, RI
#
# Jackson, MS
#  $99 one-way, to/from Hartford, CT/Springfield, MA
#  $99 one-way, to/from Phoenix, AZ
#
# Jacksonville, FL
#  $77 one-way, to/from Albany, NY
#  $40 one-way, to/from Norfolk, VA/Southern Virginia
#
# Kansas City, MO
#  $99 one-way, to/from Albuquerque, NM
#  $99 one-way, to/from Midland/Odessa, TX
#
# Las Vegas, NV
#  $35 one-way, to/from Burbank, CA
#  $48 one-way, to/from Oakland, CA
#  $36 one-way, to/from Phoenix, AZ
#  $40 one-way, to/from San Diego, CA
#
# Little Rock, AR
#  $65 one-way, to/from Corpus Christi, TX
#  $55 one-way, to/from Houston Bush Intercontinental, TX
#  $55 one-way, to/from Houston Hobby, TX
#
# Long Island/Islip, NY
#  $34 one-way, to/from Providence, RI
#  $79 one-way, to/from West Palm Beach, FL
#
# Los Angeles, CA
#  $79 one-way, to/from El Paso, TX
#  $46 one-way, to/from Reno/Tahoe, NV
#  $99 one-way, to/from Seattle/Tacoma, WA
#
# Louisville, KY
#  $68 one-way, to/from Albany, NY
#  $69 one-way, to/from Orlando, FL
#
# Lubbock, TX
#  $99 one-way, to/from St. Louis, MO
#  $61 one-way, to/from Tulsa, OK
#
# Manchester, NH
#  $99 one-way, to/from Indianapolis, IN
#  $89 one-way, to/from Nashville, TN
#
# Midland/Odessa, TX
#  $42 one-way, to/from Austin, TX
#  $99 one-way, to/from Kansas City, MO
#
# Nashville, TN
#  $89 one-way, to/from Manchester, NH
#  $66 one-way, to/from West Palm Beach, FL
#
# New Orleans, LA
#  $99 one-way, to/from Amarillo, TX
#  $99 one-way, to/from Cleveland, OH
#
# Norfolk, VA/Southern Virginia
#  $48 one-way, to/from Buffalo/Niagara Falls, NY
#  $40 one-way, to/from Jacksonville, FL
#
# Oakland, CA
#  $48 one-way, to/from Las Vegas, NV
#  $49 one-way, to/from Seattle/Tacoma, WA
#
# Oklahoma City, OK
#  $89 one-way, to/from Harlingen/South Padre Island, TX
#  $55 one-way, to/from Houston Bush Intercontinental, TX
#  $55 one-way, to/from Houston Hobby, TX
#
# Omaha, NE
#  $63 one-way, to/from Detroit, MI
#  $99 one-way, to/from Sacramento, CA
#
# Ontario, CA
#  $34 one-way, to/from Phoenix, AZ
#  $38 one-way, to/from San Jose, CA
#
# Orlando, FL
#  $34 one-way, to/from Ft. Lauderdale/Hollywood, FL
#  $69 one-way, to/from Louisville, KY
#
# Phoenix, AZ
#  $99 one-way, to/from Austin, TX
#  $99 one-way, to/from Jackson, MS
#  $36 one-way, to/from Las Vegas, NV
#  $34 one-way, to/from Ontario, CA
#
# Portland, OR
#  $99 one-way, to/from Burbank, CA
#  $94 one-way, to/from Tucson, AZ
#
# Providence, RI
#  $99 one-way, to/from Indianapolis, IN
#  $34 one-way, to/from Long Island/Islip, NY
#
# Raleigh-Durham, NC
#  $52 one-way, to/from Detroit, MI
#  $50 one-way, to/from Hartford, CT/Springfield, MA
#
# Reno/Tahoe, NV
#  $37 one-way, to/from Boise, ID
#  $46 one-way, to/from Los Angeles, CA
#
# Sacramento, CA
#  $99 one-way, to/from Omaha, NE
#  $42 one-way, to/from San Diego, CA
#
# Salt Lake City, UT
#  $50 one-way, to/from San Jose, CA
#  $49 one-way, to/from Spokane, WA
#
# San Antonio, TX
#  $63 one-way, to/from Amarillo, TX
#  $38 one-way, to/from Harlingen/South Padre Island, TX
#
# San Diego, CA
#  $40 one-way, to/from Las Vegas, NV
#  $42 one-way, to/from Sacramento, CA
#
# San Jose, CA
#  $38 one-way, to/from Ontario, CA
#  $50 one-way, to/from Salt Lake City, UT
#
# Seattle/Tacoma, WA
#  $99 one-way, to/from Los Angeles, CA
#  $49 one-way, to/from Oakland, CA
#
# Spokane, WA
#  $34 one-way, to/from Boise, ID
#  $49 one-way, to/from Salt Lake City, UT
#
# St. Louis, MO
#  $54 one-way, to/from Birmingham, AL
#  $99 one-way, to/from Lubbock, TX
#
# Tampa Bay, FL
#  $70 one-way, to/from Buffalo/Niagara Falls, NY
#  $64 one-way, to/from Columbus, OH
#
# Tucson, AZ
#  $41 one-way, to/from Albuquerque, NM
#  $94 one-way, to/from Portland, OR
#
# Tulsa, OK
#  $36 one-way, to/from Dallas Love Field, TX
#  $61 one-way, to/from Lubbock, TX
#
# West Palm Beach, FL
#  $79 one-way, to/from Long Island/Islip, NY
#  $66 one-way, to/from Nashville, TN
#
# ================================================================ IMPORTANT DETAILS
# ================================================================ *Available only on southwest.com.
# *21-day advance purchase required.
# *Available on published, scheduled service.
# *Fares shown are one-way and do not include federal
#  excise tax of up to $3.00 for each flight segment.
#  (a segment is defined as a takeoff and landing)
# *Fares do not include airport-assessed passenger
#  facility charges (PFC) of up to $9 one-way.
# *Fares do not include security fee.
# *Fares are nonrefundable, but (except for tickets
#  purchased through our Group Tickets Program)
#  may be applied toward future travel on Southwest Airlines.
# *Travel January 21, 2002 through end of schedule,
#  except May 24, and 27, 2002.
# *Purchase through January 3, 2002,  midnight Pacific Time.
# *Fares are available one-way or can be combined
#  with other fare types.  Most restrictive rules of combined
#  fares will apply.
# *Penalty applies to any changes made after purchasing
#  Southwest Internet Specials.
#
# For more details, please visit us at:
#
# ================================================================ ADDITIONAL INFORMATION
# ================================================================ Additional information you need to know about all of our
# air fare specials:
#
# *Changes to any portion of the reservation
#  (flight, dates, cities, and/or names of passengers),
#  once purchased, will result in the cancellation of
#  the ENTIRE reservation and rebooking at the lowest
#  fare available which could result in a fare increase.
# *Southwest specials are nonchangeable
#  and nonrefundable.
# *Ticketless Travel may be purchased online using
#  either a credit card or by utilizing funds from a
#  previously unused or cancelled Ticketless
#  Travel reservation(s).  Funds from up to four cancelled
#  or unused Ticketless Travel reservation records can
#  be combined to purchase a new Ticketless Travel
#  reservation record.  Southwest Airlines travel credit
#  (e.g., travel voucher, gift certificate, discount coupon)
#  may not be used as forms of payment for
#  Ticketless Travel Online.
# *Unused funds may be applied toward future travel on
#  Southwest Airlines within one year of the original purchase date.
# *Seats are limited and won't be available on some
#  flights that operate during very busy travel times
#  and holiday periods such as Presidents Day and Memorial Day.
# *Standby travel requires an upgrade to the
#  full unrestricted fare.
#
# ================================================================ SUBSCRIBER INFORMATION
# ================================================================ Please pass this great news on to your friends.
# To subscribe to Southwest Airlines Click 'n Save E-mail
# Updates, visit:
#
# Remember, if you change your Internet service provider,
# you will need to unsubscribe and resubscribe in order
# to continue receiving Click 'n Save E-mail Updates.
# For administration on your e-mail subscription, please visit:
#
# ================================================================ You may retrieve and print a copy of your Southwest
# Airlines Ticketless Travel at:
#
# Questions about your flight arrival or departure time?
# Please visit us at:
#
# ================================================================ This is a post only mailing from Southwest Airlines.
# Please do not attempt to respond to this message.
#
# Copyright 2002 Southwest Airlines Co. All Rights Reserved.
# *****
# ********
# 498 / Ring in the New Year with Pizza Hut / exclusive_offers@sportsline.com / eric.bass@enron.com / Mon, 31 Dec 2001 15:52:49 -0800 (PST)
# ============
# <!
# *****
# ********
# 499 / Commissioner.COM E-Reports for The Perfect League 1/1/02 / noreply@ccomad3.uu.commissioner.com / ebass@enron.com / Tue, 1 Jan 2002 07:25:34 -0800 (PST)
# ============
# <!doctype html public "-//w3c//dtd html 4.0 transitional//en"
# <!
# *****
# ********

# %%
def check_good_tofrom(msg):
    return (re.match(r'.*(admin|newsletter|list|announce|all[\._]|everyone[\.\_]).*',msg['From'],re.IGNORECASE) is None and
    msg['To'] is not None and
    re.match(r'.*(admin|newsletter|list|announce|all[\._]|everyone[\.\_]).*',msg['To'],re.IGNORECASE) is None and
    re.match(r'.*@enron\.com',msg['From'],re.IGNORECASE) and
    len(msg['To'].split())<=3)

# %%
for msg_key in msgs[15000:15500]:
    message = mbox.get(msg_key)
    if check_good_tofrom(message):
        msgbody = cleanup_email(message.get_payload())
        if len(msgbody)>0:
                print(msg_key, message['Subject'], message['From'],message['To'], message['Date'],sep=" / ")
                print("============")
                print(msgbody)
                print("*****")
                print("********")
# Out:
# 15000 / RE: Design Agency for EnronOnline / mark.greenberg@enron.com / heather.alon@enron.com / Thu, 18 Oct 2001 07:10:42 -0700 (PDT)
# ============
# Heather -
#
# Thanks for the information.  At this time, we prefer to use our form documents.  I understand that Tana is currently working on the NDA for this company, based upon information Erica provided.  As to the form of agreement, I can probably have something by the end of the day tomorrow for 2Advanced.com to look at.  Please let me know what the "agressive" schedule is.
#
# Thanks.
#
# Mark
# *****
# ********
# 15002 / FW: Design Agency for EnronOnline / mark.greenberg@enron.com / tana.jones@enron.com / Thu, 18 Oct 2001 07:11:27 -0700 (PDT)
# ============
# Tana -
#
# Please let me know where this NDA stands.  I want to get it out to 2Advanced this morning so they can look it over.
#
# Thanks.
#
# Mark
# *****
# ********
# 15003 / FW: Design Agency for EnronOnline / heather.alon@enron.com / mark.greenberg@enron.com, tana.jones@enron.com / Thu, 18 Oct 2001 07:21:05 -0700 (PDT)
# ============
# Hi Mark,
# *****
# ********
# 15004 / RE: EOL and Clickpaper Approvals for 10-17-01 / leslie.hansen@enron.com / tana.jones@enron.com / Thu, 18 Oct 2001 07:33:13 -0700 (PDT)
# ============
# Ditto credit
# *****
# ********
# 15005 / RE: EOL and Clickpaper Approvals for 10-16-01 / leslie.hansen@enron.com / tana.jones@enron.com, tracy.ngo@enron.com / Thu, 18 Oct 2001 07:39:07 -0700 (PDT)
# ============
# Ditto credit
# *****
# ********
# 15007 / RE: Design Agency for EnronOnline / kay.young@enron.com / tana.jones@enron.com / Thu, 18 Oct 2001 08:06:06 -0700 (PDT)
# ============
# Nothing with or pertaining to 2Advanced Studios to the best of my knowledge.
# K
#
# Kay Young
# Legal Specialist
# Enron North America Corp.
# Ph:   713-853-6794
# Fax: 713-646-3393
# *****
# ********
# 15008 / RE: 2002 IT Budgets / legal <.taylor@enron.com> / mark.greenberg@enron.com / Thu, 18 Oct 2001 08:28:07 -0700 (PDT)
# ============
# To the extent you need my authorization or approval regarding the trading database, you've got it.  If you have any questions, Tana can probably help.
# *****
# ********
# 15011 / RE: NDA - 2Advanced Studios / heather.alon@enron.com / tana.jones@enron.com / Thu, 18 Oct 2001 08:48:17 -0700 (PDT)
# ============
# Thanks you, Tana.
# *****
# ********
# 15012 / Data Room Index / angela.davis@enron.com / tana.jones@enron.com / Tue, 11 Dec 2001 05:12:02 -0800 (PST)
# ============
# Please distribute the revised index to the above persons and to me.  Thanks.  Also, could you assist me in getting clean copies of the licenses from Laine Borgman.  We redacted the copies she sent and need unredacted forms now.
#
# Angela D. Davis
# Enron North America Corp.
# 1400 Smith Street, EB3817
# Houston, Texas 77019
# Tel: (713) 345-8347
# Fax: (713) 646-3393
# e-mail: angela.davis@enron.com
# *****
# ********
# 15014 / FW: EnronOnLine / mark.greenberg@enron.com / tana.jones@enron.com / Thu, 18 Oct 2001 11:05:41 -0700 (PDT)
# ============
# Tana -
#
# FYI
#
# Mark
# *****
# ********
# 15016 / RE: Seminole Electric Cooperative, Inc. / stephanie.sever@enron.com / tana.jones@enron.com, claudia.clark@enron.com / Thu, 18 Oct 2001 13:26:25 -0700 (PDT)
# ============
# Tana,
#
# We have inactivated this counterparty - so should be removed from work queue.
#
# Thanks,
# Stephanie
# *****
# ********
# 15022 / FW: Riskmantra vs. EGM / patrick.mulvany@enron.com / tana.jones@enron.com / Thu, 18 Oct 2001 15:51:45 -0700 (PDT)
# ============
# Tana,
#
# I was just following about these trades.
# *****
# ********
# 15023 / FW: Need Approval to transact / carol.st.@enron.com / brent.hendry@enron.com / Tue, 11 Dec 2001 07:13:10 -0800 (PST)
# ============
# Brent:
# Please handle this per my voice mail message
#
# Carol St. Clair
# EB 4539
# 713-853-3989 (phone)
# 713-646-3393 (fax)
# 281-382-1943 (cell phone)
# 8774545506 (pager)
# 281-890-8862 (home fax)
# carol.st.clair@enron.com
# *****
# ********
# 15025 / RE: Riskmantra vs. EGM / s..bradford@enron.com / tana.jones@enron.com / Fri, 19 Oct 2001 05:43:04 -0700 (PDT)
# ============
# I know nothing.   This does not even make sense to me.
#
# Bill
# *****
# ********
# 15026 / 2Adavnced Studios / mark.greenberg@enron.com / heather.alon@enron.com / Fri, 19 Oct 2001 06:50:35 -0700 (PDT)
# ============
# Heather -
#
# Attached is the form Project Services Agreement that we use for consultants such as 2Advanced.  Please forward at your leasiure and have reps of 2Advanced call me with any comments or questions.
#
# Please let me know if you should need anything further.
#
# Mark
# *****
# ********
# 15028 / RE: EOL and Clickpaper Approvals for 10-18-01 / leslie.hansen@enron.com / tana.jones@enron.com / Fri, 19 Oct 2001 07:12:34 -0700 (PDT)
# ============
# Puget Sound Energy, Inc. is NOT approved to trade US East power products.
#
# We trade West power under the WSPP Agreement, but we will not trade East under this agreement and do not want to trade East and West under separate contracts.
#
# Leslie
# *****
# ********
# 15032 / Edison Mission Marketing & Trading, Inc. - Amendment / tom.moran@enron.com / stephanie.sever@enron.com / Fri, 19 Oct 2001 11:43:30 -0700 (PDT)
# ============
# Edison Mission Marketing & Trading, Inc. has provided Enron with a letter of credit through January 31, 2002 and Wendy is now comfortable in amending their EOL profile.  We will open their access to trade US East and US West Physical Power with a 2 month tenor.  When we enter the calendar month of November this tenor will be decreased to 1 month and when we enter the calendar month of December this tenor will be decreased to 0 months.
#
# If possible, could we please have this amended for trading - beginning of the day on Monday.  I have made the requisite credit changes in Profile Manager.
#
# Thanks in advance!
# tm
# *****
# ********
# 15034 / FW: Cross Oil / carol.st.@enron.com / pinto.leite@enron.com / Tue, 11 Dec 2001 07:14:11 -0800 (PST)
# ============
# Francisco:
# Please handle per my voice mail message
#
# Carol St. Clair
# EB 4539
# 713-853-3989 (phone)
# 713-646-3393 (fax)
# 281-382-1943 (cell phone)
# 8774545506 (pager)
# 281-890-8862 (home fax)
# carol.st.clair@enron.com
# *****
# ********
# 15038 / RE: Riskmantra vs. EGM / s..bradford@enron.com / patrick.mulvany@enron.com, tana.jones@enron.com, r..brackett@enron.com / Fri, 19 Oct 2001 13:57:48 -0700 (PDT)
# ============
# I think this refers to gas daily trades between Risk Management and Trade (which is an Enron entity set up for state tax reasons) and EGM (which may be a company code for Enron North America Corp. formerly known as Enron Gas Marketing, Inc.).  If this is the case, we should document them under the Master between ENA and RMT.  However, this is up to Legal.
#
# Bill
# *****
# ********
# 15042 / RE: EOL and Clickpaper Approvals for 10-19-01 / leslie.hansen@enron.com / tana.jones@enron.com / Sun, 21 Oct 2001 18:42:23 -0700 (PDT)
# ============
# ditto credit - no power CPs.
#
# Leslie
# *****
# ********
# 15046 / RE: NDA with Experian / mark.greenberg@enron.com / kim.detiveaux@enron.com / Mon, 22 Oct 2001 06:14:14 -0700 (PDT)
# ============
# Kim -
#
# Please provide me with the full name and address for Experian.  Also, we can forward the agreement on your behalf if you provide us with an e-mail address and contact name.  Finally, please give me some indication of the exact nature of the discussions, if there is any need to make the NDA specific vs. general.
#
# If you provide these items today, we should be able to get our language out later this afternoon, tomorrow moring at the latest.
#
# Mark
# *****
# ********
# 15047 / VMAC NDA / mark.greenberg@enron.com / marc.eichmann@enron.com / Mon, 22 Oct 2001 06:34:03 -0700 (PDT)
# ============
# Mark -
#
# Pursuant to your voice mail message, attached is a copy of the NDA I prepared for VMAC with CL.  If you need a document of this nature for EOL, please let me know and our office can prepare it and forward it for your use.  The Legal Dept. prepares and forwards NDA's so that we can track them and ensure terms are legally acceptable.
#
# Mark
# *****
# ********
# 15049 / Delivery Status Notification (Relay) / postmaster@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 08:03:41 -0700 (PDT)
# ============
# This is an automatically generated Delivery Status Notification.
#
# Your message has been successfully relayed to the following recipients, but the requested delivery status notifications may not be generated by the destination.
# *****
# ********
# 15050 / RE: VMAC NDA / mark.greenberg@enron.com / marc.eichmann@enron.com / Mon, 22 Oct 2001 08:32:08 -0700 (PDT)
# ============
# Marc -
#
# Please provide me with a brief description of the project or work that is going to be discussed with VMAC and a contact name/e-mail address.  We will do the necessary conflict check and send the agreement to VMAC directly.
#
# Thanks.
#
# Mark
# *****
# ********
# 15051 / RE: Requests for NDAs / kim.detiveaux@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 08:38:35 -0700 (PDT)
# ============
# Tana:
#
# Thanks for clarifying the process.  Do you have what you need to expedite the NDA with Experian?
#
# Kim Detiveaux
# *****
# ********
# 15053 / FW: VMAC NDA / mark.greenberg@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 10:46:51 -0700 (PDT)
# ============
# Tana -
#
# Please see the below.  The VMAC agreement we did for CommodityLogic, if you do not already have it in your files, is in my O drive in CommodityLogic under Confidentiality Agreements.  I password protected it.  The password is "cllegal".
#
# Mark
# *****
# ********
# 15055 / Constellation / f..calger@enron.com / edward.sacks@enron.com / Tue, 11 Dec 2001 09:10:06 -0800 (PST)
# ============
# Ed,
#
# Can you get Tana a copy of the Constellation termination agreement.  Also, have the other pre-petition deals been booked?
#
# Regards,
#
# Chris Calger
# 503-464-3735
# *****
# ********
# 15056 / Delivery Status Notification (Relay) / postmaster@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 11:28:31 -0700 (PDT)
# ============
# This is an automatically generated Delivery Status Notification.
#
# Your message has been successfully relayed to the following recipients, but the requested delivery status notifications may not be generated by the destination.
# *****
# ********
# 15058 / RE: BASF / jennifer.mcquade@enron.com / wendi.lebrocq@enron.com, stephanie.sever@enron.com, tana.jones@enron.com / Mon, 22 Oct 2001 12:06:28 -0700 (PDT)
# ============
# Hey guys-
# BASF is still not showing up as legal reviewing even thought Wendi approved on 10/16. Please make sure that this gets on to Tana, so that we can get this ID out ASAP.
#
# Thanks!
# Jen
# *****
# ********
# 15060 / RE: NDA with Experian / kim.detiveaux@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 12:11:24 -0700 (PDT)
# ============
# Tana:
#
# Legal Name and Address:
# *****
# ********
# 15063 / RE: NDA with Experian / kay.young@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 13:13:06 -0700 (PDT)
# ============
# Nothing with or pertaining to Experian to the best of my knowledge.
# K
#
# Kay Young
# Legal Specialist
# Enron North America Corp.
# Ph:   713-853-6794
# Fax: 713-646-3393
# *****
# ********
# 15064 / RE: VMAC NDA / kay.young@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 13:15:06 -0700 (PDT)
# ============
# Nothing with or pertaining tp Virtual Markets Assurance Corporation either .
# K
#
# Kay Young
# Legal Specialist
# Enron North America Corp.
# Ph:   713-853-6794
# Fax: 713-646-3393
# *****
# ********
# 15068 / RE: NDA - Experian Inc. / kim.detiveaux@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 14:02:35 -0700 (PDT)
# ============
# Tana:
#
# My thanks to You and Mark for the quick response!
#
# Kim Detiveaux
# *****
# ********
# 15069 / FW: Product Type Approval Needed (US PlasticHDPE Fin Swap) / stephanie.sever@enron.com / tana.jones@enron.com, businesses.global@enron.com / Mon, 22 Oct 2001 14:38:38 -0700 (PDT)
# ============
# The product long description below will fall under the new product types:
# *****
# ********
# 15070 / RE: Product Type Approval Needed (US PlasticHDPE Fin Swap) / stephanie.sever@enron.com / tana.jones@enron.com / Mon, 22 Oct 2001 14:39:40 -0700 (PDT)
# ============
# Thanks Tana
# *****
# ********
# 15073 / FW: Sigma request (CAN Gas Phy Fwd East Spd < or = 1Mo) / stephanie.sever@enron.com / tana.jones@enron.com, businesses.global@enron.com / Mon, 22 Oct 2001 15:38:41 -0700 (PDT)
# ============
# The product long description below will fall under the new product types:
#
#  CAN Gas Phy Fwd East Spd < or =3D 1 Mo
#
# Credit (Tom Moran/Wendi Lebrocq) have approved copying the profiles for the  new product type from the following:
#
#  CAN Gas Phy Index Firm East < or =3D 1 Mo
#
# Please respond no later than 10am, Wednesday, October 23.
#
# Thank you.
# *****
# ********
# 15077 / FW: Copy of Enron Credit ISDA Schedule and other docs with
#  Mitsui-Marine / nony.flores@enron.com / tana.jones@enron.com / Tue, 23 Oct 2001 06:52:31 -0700 (PDT)
# ============
# Tana,
#
# Are you familiar with the above?  If so, is it possible to provide soft copies to Jane McBride?
#
# Thanks.
# Nony
# *****
# ********
# 15078 / Delivery Status Notification (Relay) / postmaster@enron.com / tana.jones@enron.com / Tue, 11 Dec 2001 15:20:28 -0800 (PST)
# ============
# This is an automatically generated Delivery Status Notification.
#
# Your message has been successfully relayed to the following recipients, but the requested delivery status notifications may not be generated by the destination.
# *****
# ********
# 15079 / RE: EOL and Clickpaper Approvals for 10-22-01 / leslie.hansen@enron.com / tana.jones@enron.com / Tue, 23 Oct 2001 06:53:04 -0700 (PDT)
# ============
# Ditto credit
# *****
# ********
# 15080 / RE: ? re: Bankers Trust/ Deutsche Bank / diane.anderson@enron.com / tana.jones@enron.com / Tue, 23 Oct 2001 09:12:12 -0700 (PDT)
# ============
# Hey Tana.
#
# I got a call this morning from someone in the DB offices in London who seems to think that the issues between us, relating to
# EOL I guess, are all settled - and she'd like to know where we'll be signing their assignment agreement.  Can you give her
# a call:
#
# 011 44 207 547 0883
#
# I think her name is Sara - but I listened to her messege 4 times, and can't really make out what she said her name was.
#
# Thanks,
# Diane
# *****
# ********
# 15081 / RE: Copy of Enron Credit ISDA Schedule and other docs with
#  Mitsui-Marine / nony.flores@enron.com / tana.jones@enron.com / Tue, 23 Oct 2001 10:20:43 -0700 (PDT)
# ============
# Thanks Tana.  I've referred her to Matt Dawson.
#
# Nony
# *****
# ********
# 15082 / RE: US East and West Phy Power Audit / leslie.hansen@enron.com / stephanie.sever@enron.com / Tue, 23 Oct 2001 10:59:25 -0700 (PDT)
# ============
# Stephanie:
#
# None of the counterparties listed below should have access to US physical power products except:
#
# those listed below as (West only) are okay for West power
# Transcanada Power Mktg, Ltd.
# Wisconsin Public Power Inc.
#
# (If either NStar Companies or Wisconsin Power and Light Company have executed any power trades, let me know, otherwise, turn them off.)
#
# Thanks,
#
# Leslie
# *****
# ********
# 15084 / RE: Riskmantra vs. EGM / patrick.mulvany@enron.com / tana.jones@enron.com / Tue, 23 Oct 2001 12:46:55 -0700 (PDT)
# ============
# Tana,
#
# These deals are purely for storage.  They used tagg to capture the value of storing the physical gas.  Pat Ryder in Risk Management put these deals in and has told me they are used for value and should be "Not to be Confirmed."  If you see no issue, I will simply change their status to "Not to be Confirmed."  If their status of being under EGM is still a problem, Pat said you could call him at 5-3313.
#
#
# Thanks,
#
# Patrick
# *****
# ********
# 15091 / RE: Riskmantra vs. EGM / frank.sayre@enron.com / tana.jones@enron.com / Wed, 24 Oct 2001 06:00:08 -0700 (PDT)
# ============
# I have no problem with you going ahead as planned.
# *****
# ********
# 15092 / RE: EnronOnLine / mark.greenberg@enron.com / annette.rosario@db.com / Wed, 24 Oct 2001 06:26:35 -0700 (PDT)
# ============
# Annette -
#
# You can forward them to my attention c/o Enron Corp., 1400 Smith Street, Houston, Texas 77002.
#
# Thanks.
#
# Mark
# *****
# ********
# 15093 / TECO EnergySource Inc. / mark.greenberg@enron.com / tana.jones@enron.com / Wed, 24 Oct 2001 06:35:48 -0700 (PDT)
# ============
# Tana -
#
# When you have the ETA amendment letter ready for TECO to see, could you please e-mail it to Pat Castoro at TECO (pacastoro@tecoenergy.com) and also forward a copy to their counsel - Brian Harms (brian.harms@troutmansanders.com).
#
# The legal name  that needs to be on this letter is TECO EnergySource, Inc.  There will also be a second letter amendment for a partnership that is being formed by TECO under the name TECO-Panda Generating Company, LP.
#
# Thanks.
#
# Mark
# *****
# ********
# 15094 / FW: Assignment Draft / bob.shults@enron.com / mark.greenberg@enron.com / Wed, 24 Oct 2001 07:03:27 -0700 (PDT)
# ============
# Mark,
#
# This new company was created for tax purposes.  Do you see any problem with the assignment.  The letter of credit will need to change.
# *****
# ********
# 15095 / FW: Assignment Draft / mark.greenberg@enron.com / tana.jones@enron.com / Wed, 24 Oct 2001 07:09:32 -0700 (PDT)
# ============
# Tana -
#
# I do have some issues with the attached docuement, but am more concerned about the move from APB Energy Inc. to an new LLC from a credit perspective.  Who is our contact in Credit on APB or BrokerClient?  Please let me know when you get a chance.
#
# Thanks.
#
# Mark
# *****
# ********
# 15102 / FW:  Emissions Broker / bob.shults@enron.com / mark.greenberg@enron.com / Wed, 24 Oct 2001 13:33:17 -0700 (PDT)
# ============
# It would help if I copied you guys on this.
# *****
# ********
# 15108 / RE: Looking for signed NDAs / kay.young@enron.com / tana.jones@enron.com / Thu, 25 Oct 2001 07:44:11 -0700 (PDT)
# ============
# Kay Young
# Legal Specialist
# Enron North America Corp.
# Ph:   713-853-6794
# Fax: 713-646-3393
# *****
# ********
# 15110 / RE: EOL and Clickpaper Approvals for 10-24-01 / leslie.hansen@enron.com / tana.jones@enron.com / Thu, 25 Oct 2001 08:54:13 -0700 (PDT)
# ============
# ditto credit.
#
# Leslie
# *****
# ********
# 15112 / Williams Gas Pipelines / daniel.diamond@enron.com / tana.jones@enron.com / Thu, 25 Oct 2001 09:02:24 -0700 (PDT)
# ============
# Tana,
# Please send me an NDA that covers both "Market Manager" and selling a "Private E-Market Place" for Williams Gas Pipeline Companies.
# It is for:
#
# Allison G. Bridges
# Senior Vice President, Strategic Marketing
# 2800 Post Oak Blvd.
# Houston, Texas 77251
#
# This NDA should cover all of Williams' e-Commerce effofts as well as all of their pipeline companies.
#
# -Dan
# *****
# ********
# 15113 / RE: EOL and Clickpaper Approvals for 10-23-01 / leslie.hansen@enron.com / tana.jones@enron.com / Thu, 25 Oct 2001 09:15:56 -0700 (PDT)
# ============
# ditto credit - no power CPs.
#
# Leslie
# *****
# ********
# 15115 / FW: This is hilarious!! / marie.heard@enron.com / tana.jones@enron.com / Thu, 25 Oct 2001 12:08:45 -0700 (PDT)
# ============
# This is cute.
# *****
# ********
# 15117 / Ummmmmm / paul.radous@enron.com / marie.heard@enron.com, tana.jones@enron.com / Thu, 25 Oct 2001 13:44:19 -0700 (PDT)
# ============
# Thanks for the treat this afternoon.  We appreciate it!
# *****
# ********
# 15118 / FW: Ummmmmm / marie.heard@enron.com / paul.radous@enron.com / Thu, 25 Oct 2001 13:51:03 -0700 (PDT)
# ============
# My sentiments exactly!
# *****
# ********
# 15119 / FW: / marie.heard@enron.com / tana.jones@enron.com / Thu, 25 Oct 2001 14:04:52 -0700 (PDT)
# ============
# Did I send this to you already?
# *****
# ********
# 15120 / RE: Need Approval to transact / sheetal.patel@enron.com / carol.st.@enron.com, brent.hendry@enron.com / Wed, 12 Dec 2001 09:40:15 -0800 (PST)
# ============
# Carol/Brent:
#
# AirCanada is ready to do this deal.
# Can we complete this transaction?
#
# Thanks,
# Sheetal
# *****
# ********
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-06e8b808b467> in <module>
#       1 for msg_key in msgs[15000:15500]:
#       2     message = mbox.get(msg_key)
# ----> 3     if check_good_tofrom(message):
#       4         msgbody = cleanup_email(message.get_payload())
#       5         if len(msgbody)>0:
#
# <ipython-input-8-82a1580a7f87> in check_good_tofrom(msg)
#       1 def check_good_tofrom(msg):
# ----> 2     return (re.match(r'.*(admin|newsletter|list|announce|all[\._]|everyone[\.\_]).*',msg['From'],re.IGNORECASE) is None and
#       3     msg['To'] is not None and
#       4     re.match(r'.*(admin|newsletter|list|announce|all[\._]|everyone[\.\_]).*',msg['To'],re.IGNORECASE) is None and
#       5     re.match(r'.*@enron\.com',msg['From'],re.IGNORECASE) and
#
# C:\Anaconda3\lib\re.py in match(pattern, string, flags)
#     171     """Try to apply the pattern at the start of the string, returning
#     172     a Match object, or None if no match was found."""
# --> 173     return _compile(pattern, flags).match(string)
#     174
#     175 def fullmatch(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
import spacy
nlp=spacy.load('en')

# %%
for token in nlp(u"I want to buy stock."):
    print(token.text,token.lemma_,token.pos_,token.tag_,token.is_alpha,token.is_stop,sep = " / ")
# Out:
# I / -PRON- / PRON / PRP / True / True
# want / want / VERB / VBP / True / False
# to / to / PART / TO / True / True
# buy / buy / VERB / VB / True / False
# stock / stock / NOUN / NN / True / False
# . / . / PUNCT / . / False / False

# %%
for token in nlp("Bob says he knows about the scam"):
    print(token.text,token.lemma_,token.pos_,token.tag_,token.is_alpha,token.is_stop,sep = " / ")
# Out:
# Bob / Bob / PROPN / NNP / True / False
# says / say / VERB / VBZ / True / False
# he / -PRON- / PRON / PRP / True / True
# knows / know / VERB / VBZ / True / False
# about / about / ADP / IN / True / True
# the / the / DET / DT / True / True
# scam / scam / NOUN / NN / True / False

# %%
from spacy import displacy

# %%
displacy.render(nlp("I want to buy stock."),style = "dep",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="494a397ea4fd4cc39b9b806767e38f81-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">want</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">buy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">stock.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-494a397ea4fd4cc39b9b806767e38f81-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-494a397ea4fd4cc39b9b806767e38f81-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-494a397ea4fd4cc39b9b806767e38f81-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-494a397ea4fd4cc39b9b806767e38f81-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-494a397ea4fd4cc39b9b806767e38f81-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-494a397ea4fd4cc39b9b806767e38f81-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-494a397ea4fd4cc39b9b806767e38f81-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-494a397ea4fd4cc39b9b806767e38f81-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
displacy.render(nlp("I want to buy stock."),style = "dep",jupyter=False)
# Out:
# '<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6694f595657c4291aff30cb1e0af82e0-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">\n    <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">\n    <tspan class="displacy-word" fill="currentColor" x="225">want</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">\n    <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">\n    <tspan class="displacy-word" fill="currentColor" x="575">buy</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">\n    <tspan class="displacy-word" fill="currentColor" x="750">stock.</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>\n</text>\n\n<g class="displacy-arrow">\n    <path class="displacy-arc" id="arrow-6694f595657c4291aff30cb1e0af82e0-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>\n    <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">\n        <textPath xlink:href="#arrow-6694f595657c4291aff30cb1e0af82e0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>\n    </text>\n    <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>\n</g>\n\n<g class="displacy-arrow">\n    <path class="displacy-arc" id="arrow-6694f595657c4291aff30cb1e0af82e0-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>\n    <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">\n        <textPath xlink:href="#arrow-6694f595657c4291aff30cb1e0af82e0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>\n    </text>\n    <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>\n</g>\n\n<g class="displacy-arrow">\n    <path class="displacy-arc" id="arrow-6694f595657c4291aff30cb1e0af82e0-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>\n    <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">\n        <textPath xlink:href="#arrow-6694f595657c4291aff30cb1e0af82e0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>\n    </text>\n    <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>\n</g>\n\n<g class="displacy-arrow">\n    <path class="displacy-arc" id="arrow-6694f595657c4291aff30cb1e0af82e0-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>\n    <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">\n        <textPath xlink:href="#arrow-6694f595657c4291aff30cb1e0af82e0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>\n    </text>\n    <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>\n</g>\n</svg>'

# %%
displacy.render(nlp("I want to buy stock."),style = "dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5823b51b72374c83ba1797014e78a355-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">want</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">buy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">stock.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5823b51b72374c83ba1797014e78a355-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5823b51b72374c83ba1797014e78a355-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5823b51b72374c83ba1797014e78a355-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5823b51b72374c83ba1797014e78a355-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5823b51b72374c83ba1797014e78a355-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5823b51b72374c83ba1797014e78a355-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5823b51b72374c83ba1797014e78a355-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5823b51b72374c83ba1797014e78a355-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
displacy.render(nlp("Bob said he knows about the scam."),style = "dep",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="831993bde9ea4743a8ca5c055b78a00b-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Bob</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">knows</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">scam.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-831993bde9ea4743a8ca5c055b78a00b-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-831993bde9ea4743a8ca5c055b78a00b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-831993bde9ea4743a8ca5c055b78a00b-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-831993bde9ea4743a8ca5c055b78a00b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-831993bde9ea4743a8ca5c055b78a00b-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-831993bde9ea4743a8ca5c055b78a00b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-831993bde9ea4743a8ca5c055b78a00b-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-831993bde9ea4743a8ca5c055b78a00b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-831993bde9ea4743a8ca5c055b78a00b-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-831993bde9ea4743a8ca5c055b78a00b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-831993bde9ea4743a8ca5c055b78a00b-0-5" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-831993bde9ea4743a8ca5c055b78a00b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
from spacy.symbols import nsubj, xcomp, dobj, pobj, prep, attr,VERB, PRON, NOUN,PROPN, PUNCT
def extract_relationships(doc):
    relationships = []
    for possible_subject in doc:
        if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
            subj = possible_subject
            verb = possible_subject.head
            print(subj, verb)
            for vr in verb.rights:
                if vr.dep == xcomp:
                    for vc in vr.children:
                        if vc.dep == dobj and vc.pos == NOUN:
                            relationships.append((subj,verb,vr,vc))
                if vr.dep == prep:
                    for vc in vr.children:
                        if vc.dep == pobj and vc.pos == NOUN:
                            relationships.append((subj,verb,vr,vc)) 
                if vr.dep == dobj and vr.pos == NOUN:
                    relationships.append((subj,verb,vr))
                print(vr, vr.dep_,vr.pos_)
    return relationships

# %%
extract_relationships(nlp("I want to buy stock."))
# Out:
# I want
# buy xcomp VERB
# . punct PUNCT
# [(I, want, buy, stock)]

# %%
extract_relationships(nlp("Bob said he knows about the scam."))
# Out:
# Bob said
# knows ccomp VERB
# . punct PUNCT
# he knows
# about prep ADP
# [(he, knows, about, scam)]

# %%
extract_relationships(nlp("I bought stock."))
# Out:
# I bought
# stock dobj NOUN
# . punct PUNCT
# [(I, bought, stock)]

# %%
extract_relationships(nlp("Jane said Bob knows about the scam."))
# Out:
# Jane said
# knows ccomp VERB
# . punct PUNCT
# Bob knows
# about prep ADP
# [(Bob, knows, about, scam)]

# %%
#simple method for anaphora? resolution
def find_referent(doc, pronoun, msgfrom, msgto):
    if pronoun.text.lower() in ['i','myself','me','we']:
        return msgfrom
    elif pronoun.text.lower() in ['you','your']:
        return msgto
    else:
        w = pronoun
        while w.head != w:
            w = w.head
        for c in w.children:
            if c.dep == nsubj:
                return c.text
        return None

# %%
doc = nlp('Bob said he knows about the scam.')
rels = extract_relationships(doc)
for rel in rels:
    for w in rel:
        if w.pos == PRON:
            print(find_referent(doc, w, 'meme','youyou'))
# Out:
# Bob said
# knows ccomp VERB
# . punct PUNCT
# he knows
# about prep ADP
# Bob

# %%
def extract_relationships2(doc,msgfrom,msgto):
    relationships = []
    for possible_subject in doc:
        if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
            subj = possible_subject
            verb = possible_subject.head
            if subj.pos == PRON or subj.pos ==PROPN:
                if subj.pos == PRON:
                    ref = find_referent(doc,subj,msgfrom,msgto)
                    if ref is not None:
                        subj = ref
                    else:
                        subj = subj.text
                else:
                    subj = subj.text
            if subj.lower() in ['they','it']:
                continue
            print(subj, verb)
            
            for vr in verb.rights:
                if vr.dep_ == xcomp:
                    for vc in vr.children:
                        if vc.dep_ == dobj and vc.pos_ == NOUN:
                            if vr.idx < vc.idx:
                                relationships.append((subj,verb.lemma_,vr.lemma_+" "+vc.lemma_))
                            else:
                                relationships.append((subj,verb.lemma_,vc.lemma_+" "+vr.lemma_))
                elif vr.dep_ == prep:
                    for vc in vr.children:
                        if vc.dep_ == pobj and vc.pos_ == NOUN:
                            relationships.append((subj,verb.lemma_,vc.lemma_)) 
                elif vr.dep_ == dobj and (vr.pos_ == NOUN or vr.pos_ == PROPN):
                    has_compound = False
                    for vc in vr.children:
                        if vc.dep_ == 'compound' and vc.pos_ == NOUN:
                            has_compound = True
                            if vr.idx < vc.idx:
                                relationships.append((subj,verb.lemma_,vr.lemma_+" "+vc.lemma_))
                            else:
                                relationships.append((subj,verb.lemma_,vc.lemma_+" "+vr.lemma_))
                        if not has_compound:
                            relationships.append((subj,verb.lemma_,vr.lemma_))
                elif vr.dep_ == attr:
                    relationships.append((subj,verb.lemma_,vr.lemma_))
                print(vr.dep_,vr.pos_,vr.idx,vr.lemma_,relationships)
    return relationships

# %%
def extract_relationships2(doc, msgfrom, msgto):
    #print(doc)
    relationships = []
    for possible_subject in doc:
        if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
            subj = possible_subject
            verb = possible_subject.head
            
            if subj.pos == PRON or subj.pos == PROPN:
                if subj.pos == PRON:
                    ref = find_referent(doc, subj, msgfrom, msgto)
                    if ref is not None:
                        subj = ref
                    else:
                        subj = subj.text
                else:
                    subj = subj.text
                
                # ignore worthless subjects
                if subj.lower() in ['they', 'it']:
                    continue
                    
                for vr in verb.rights:
                    if vr.dep == xcomp:
                        for vc in vr.children:
                            if vc.dep == dobj and vc.pos == NOUN:
                                if vr.idx < vc.idx:
                                    relationships.append((subj, verb.lemma_, vr.lemma_ + " " + vc.lemma_))
                                else:
                                    relationships.append((subj, verb.lemma_, vc.lemma_ + " " + vr.lemma_))
                    elif vr.dep == prep:
                        for vc in vr.children:
                            if vc.dep == pobj and vc.pos == NOUN:
                                relationships.append((subj, verb.lemma_, vc.lemma_))
                    elif vr.dep == dobj and (vr.pos == NOUN or vr.pos == PROPN):
                        has_compound = False
                        for vc in vr.children:
                            if vc.dep_ == 'compound' and vc.pos == NOUN:
                                has_compound = True
                                if vr.idx < vc.idx:
                                    relationships.append((subj, verb.lemma_, vr.lemma_ + " " + vc.lemma_))
                                else:
                                    relationships.append((subj, verb.lemma_, vc.lemma_ + " " + vr.lemma_))
                        if not has_compound:
                            relationships.append((subj, verb.lemma_, vr.lemma_))
                    elif vr.dep == attr:
                        relationships.append((subj, verb.lemma_, vr.lemma_))
    return relationships

# %%
print(extract_relationships2(nlp('I want to buy stock.'),'me@example','you@example')
,extract_relationships2(nlp('Jane said Bob knows about the scam'),'me@example','you@example')
,extract_relationships2(nlp('Bob knows about the scam.'),'me@example','you@example')
,extract_relationships2(nlp('You bought stock.'),'me@example','you@example'),sep ="\n")
# Out:
# [('me@example', 'want', 'buy stock')]
# [('Bob', 'know', 'scam')]
# [('Bob', 'know', 'scam')]
# [('you@example', 'buy', 'stock')]

# %%
def extract_email_relationships(mbox, msg_key):
    message = mbox.get(msg_key)
    if message['From'] is not None and message['To'] is not None:
        try:
            msgnlp = nlp(cleanup_email(message.get_payload()))
            return extract_relationships2(msgnlp,message['From'],message['To'].split(', ')[0])
        except :
            return []
    else:
        return []

# %%
extract_email_relationships(mbox, 15000)
# Out:
# [('mark.greenberg@enron.com', 'prefer', 'use document'),
#  ('Tana', 'work', 'company')]

# %%
import rdflib
from rdflib import Graph, Literal, RDF
from rdflib.namespace import FOAF

# %%
g=Graph()

# %%
g.add((Literal('mark.greenberg@enron.com'),RDF.type, FOAF.Person))
g.add((Literal('mark.greenberg@enron.com'),Literal('requested'),Literal('copy')))

# %%
for s, p, o in g:
    print(s, p, o)
# Out:
# mark.greenberg@enron.com http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/Person
# mark.greenberg@enron.com requested copy

# %%
for person in g.subjects(RDF.type, FOAF.Person):
    print(person)
# Out:
# mark.greenberg@enron.com

# %%
qres = g.query('SELECT ?s ?o where { ?s ?p ?o . }',initBindings = {'p':Literal('requested')})

for row in qres:
    print("%s -> %s" % row)
# Out:
# mark.greenberg@enron.com -> copy

# %%
def create_graph_from_email_relationships(mbox):
    g = Graph()
    msg_key_idx = {}
    msg_key_idx_reverse = {}
    for msg_key in msgs[15000:15500]:
        rels = extract_email_relationships(mbox, msg_key)
        for (s, p, o) in rels:
            r=(Literal(s),Literal(p),Literal(o))
            g.add(r)
            if r in msg_key_idx:
                msg_key_idx[r].append(msg_key)
            else:
                msg_key_idx[r] = [msg_key]
                
            if msg_key in msg_key_idx_reverse:
                msg_key_idx_reverse[msg_key].append(r)
            else:
                msg_key_idx_reverse[msg_key] = [r]
    return (g, msg_key_idx, msg_key_idx_reverse)

# %%
(g, msg_key_idx,msg_key_idx_reverse) = create_graph_from_email_relationships(mbox)

# %%
for s, p, o in g:
    print((s,p,o))
# Out:
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('ask'), rdflib.term.Literal('attorney'))
# (rdflib.term.Literal('susan.bailey@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('morning'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('foundation'))
# (rdflib.term.Literal('greg.johnston@enron.com'), rdflib.term.Literal('delete'), rdflib.term.Literal('reference'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('party'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('see draft'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('return'), rdflib.term.Literal('work'))
# (rdflib.term.Literal('somebody'), rdflib.term.Literal('go'), rdflib.term.Literal('provide list'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('order'), rdflib.term.Literal('item'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('plan'), rdflib.term.Literal('address request'))
# (rdflib.term.Literal('craigvasquezjones@hotmail.com'), rdflib.term.Literal('know'), rdflib.term.Literal('arrival time'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('circulate'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('carol.st.@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('default notice'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('Agreement'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('retain'), rdflib.term.Literal('concept'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('master agreement'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('work'), rdflib.term.Literal('extraction'))
# (rdflib.term.Literal('becky.spencer@enron.com'), rdflib.term.Literal('help'), rdflib.term.Literal('work table'))
# (rdflib.term.Literal('Marketing'), rdflib.term.Literal('provide'), rdflib.term.Literal('Enron'))
# (rdflib.term.Literal('amber.ebow@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('spreadsheet'))
# (rdflib.term.Literal('ross.mesquita@enron.com'), rdflib.term.Literal('move'), rdflib.term.Literal('stage'))
# (rdflib.term.Literal('Reed'), rdflib.term.Literal('look'), rdflib.term.Literal('update'))
# (rdflib.term.Literal('who'), rdflib.term.Literal('execute'), rdflib.term.Literal('trade'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('point'))
# (rdflib.term.Literal('stephanie.sever@enron.com'), rdflib.term.Literal('inactivate'), rdflib.term.Literal('counterparty'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('enter'), rdflib.term.Literal('database'))
# (rdflib.term.Literal('Caminus'), rdflib.term.Literal('take'), rdflib.term.Literal('reference'))
# (rdflib.term.Literal('legal <.taylor@enron.com>'), rdflib.term.Literal('need'), rdflib.term.Literal('have lot'))
# (rdflib.term.Literal('User'), rdflib.term.Literal('read'), rdflib.term.Literal('message'))
# (rdflib.term.Literal('sarah.dietrich@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('template'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('put'), rdflib.term.Literal('document'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('execution original'))
# (rdflib.term.Literal('amber.ebow@enron.com'), rdflib.term.Literal('wait'), rdflib.term.Literal('confirmation'))
# (rdflib.term.Literal('leslie.hansen@enron.com'), rdflib.term.Literal('trade'), rdflib.term.Literal('East'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('retain'), rdflib.term.Literal('term'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('phone'))
# (rdflib.term.Literal('l..denton@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('one'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('hold'), rdflib.term.Literal('discussion'))
# (rdflib.term.Literal('date'), rdflib.term.Literal('own'), rdflib.term.Literal('seat'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('fax'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('portal'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('ross.mesquita@enron.com'), rdflib.term.Literal('request'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('listen'), rdflib.term.Literal('messege'))
# (rdflib.term.Literal('steve.van@enron.com'), rdflib.term.Literal('review'), rdflib.term.Literal('draft'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('consultant'))
# (rdflib.term.Literal('rep'), rdflib.term.Literal('help'), rdflib.term.Literal('process'))
# (rdflib.term.Literal('hkjii@erols.com'), rdflib.term.Literal('get'), rdflib.term.Literal('Emails'))
# (rdflib.term.Literal('becky.spencer@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('Sales'), rdflib.term.Literal('trade'), rdflib.term.Literal('lpg'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('Agreement'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('waive'), rdflib.term.Literal('right'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('join'), rdflib.term.Literal('Program'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('initial letter'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('begin'), rdflib.term.Literal('pull contract'))
# (rdflib.term.Literal('ross.mesquita@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('info'))
# (rdflib.term.Literal('georgi.landau@enron.com'), rdflib.term.Literal('wait'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('log'), rdflib.term.Literal('password'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('finalize'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('outline'), rdflib.term.Literal('work'))
# (rdflib.term.Literal('jeannine.ford@experian.com'), rdflib.term.Literal('see'), rdflib.term.Literal('message'))
# (rdflib.term.Literal('Bob'), rdflib.term.Literal('ask'), rdflib.term.Literal('forward amendment'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('update'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('distribute'), rdflib.term.Literal('process memo'))
# (rdflib.term.Literal('Haedicke'), rdflib.term.Literal('hold'), rdflib.term.Literal('floor meeting'))
# (rdflib.term.Literal('NDA'), rdflib.term.Literal('relate'), rdflib.term.Literal('sale'))
# (rdflib.term.Literal('susan.bailey@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('difficulty'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('prepare'), rdflib.term.Literal('letter agreement'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('forward'), rdflib.term.Literal('original'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('form'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('termination letter'))
# (rdflib.term.Literal('susan.bailey@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('assistance'))
# (rdflib.term.Literal('Mark'), rdflib.term.Literal('request'), rdflib.term.Literal('change'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('call'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('consider'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('c..koehler@enron.com'), rdflib.term.Literal('draft'), rdflib.term.Literal('paragraph'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('request'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('sign'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('purchase'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('Haedicke'), rdflib.term.Literal('office'), rdflib.term.Literal('building'))
# (rdflib.term.Literal('Tana'), rdflib.term.Literal('work'), rdflib.term.Literal('company'))
# (rdflib.term.Literal('Robert'), rdflib.term.Literal('approve'), rdflib.term.Literal('Description'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('assist'), rdflib.term.Literal('status'))
# (rdflib.term.Literal('Jeff'), rdflib.term.Literal('send'), rdflib.term.Literal('sample'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('modification'))
# (rdflib.term.Literal('craig.chaney@enron.com'), rdflib.term.Literal('follow'), rdflib.term.Literal('procedure'))
# (rdflib.term.Literal('Peter'), rdflib.term.Literal('look'), rdflib.term.Literal('morning'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('document'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('Cheryl'), rdflib.term.Literal('feel'), rdflib.term.Literal('weather'))
# (rdflib.term.Literal('georgi.landau@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('contract number'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('establish'), rdflib.term.Literal('rapport'))
# (rdflib.term.Literal('bob.shults@enron.com'), rdflib.term.Literal('copy'), rdflib.term.Literal('guy'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('make document'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('know'), rdflib.term.Literal('thought'))
# (rdflib.term.Literal('deb.korkmas@enron.com'), rdflib.term.Literal('find'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('Marcus'), rdflib.term.Literal('proceed'), rdflib.term.Literal('document'))
# (rdflib.term.Literal("you'all"), rdflib.term.Literal('send'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('ross.mesquita@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('take approach'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('confirm'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('agree'), rdflib.term.Literal('revision'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('sign'), rdflib.term.Literal('confidentiality agreement'))
# (rdflib.term.Literal('someone'), rdflib.term.Literal('call'), rdflib.term.Literal('Redd'))
# (rdflib.term.Literal('tom.moran@enron.com'), rdflib.term.Literal('enter'), rdflib.term.Literal('calendar month'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('leslie.hansen@enron.com'), rdflib.term.Literal('trade'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('Transaction'), rdflib.term.Literal('purchase'), rdflib.term.Literal('quantity'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('event'))
# (rdflib.term.Literal('annette.rosario@db.com'), rdflib.term.Literal('forward'), rdflib.term.Literal('c'))
# (rdflib.term.Literal('rick.antonoff@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('call'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('provide feedback'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('implement'), rdflib.term.Literal('language'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('keep'), rdflib.term.Literal('lunch meeting'))
# (rdflib.term.Literal('stacy.fitzgerald@enron.com'), rdflib.term.Literal('find'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('keep'), rdflib.term.Literal('track'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('put'), rdflib.term.Literal('user note'))
# (rdflib.term.Literal('Lebrocq'), rdflib.term.Literal('approve'), rdflib.term.Literal('copy profile'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('office'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('retain'), rdflib.term.Literal('termination'))
# (rdflib.term.Literal('sarah.dietrich@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('annex template'))
# (rdflib.term.Literal('I'), rdflib.term.Literal('find'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('change'), rdflib.term.Literal('mind'))
# (rdflib.term.Literal('carol.st.@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('Companies'), rdflib.term.Literal('execute'), rdflib.term.Literal('power trade'))
# (rdflib.term.Literal('r..brackett@enron.com'), rdflib.term.Literal('know'), rdflib.term.Literal('answer question'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('attention'))
# (rdflib.term.Literal('KY'), rdflib.term.Literal('re'), rdflib.term.Literal('transaction'))
# (rdflib.term.Literal('This'), rdflib.term.Literal('elevate'), rdflib.term.Literal('default'))
# (rdflib.term.Literal('keegan.farrell@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('call'))
# (rdflib.term.Literal('anyone'), rdflib.term.Literal('see'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('authorization'))
# (rdflib.term.Literal('tom.moran@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('credit change'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('someone'), rdflib.term.Literal('call'), rdflib.term.Literal('start process'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('travel'), rdflib.term.Literal('funeral'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('finalize'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('Agreement'), rdflib.term.Literal('fax'), rdflib.term.Literal('attention'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('matter'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('one'))
# (rdflib.term.Literal('alan.aronowitz@enron.com'), rdflib.term.Literal('act'), rdflib.term.Literal('resource'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('share'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('past'))
# (rdflib.term.Literal('Haedicke'), rdflib.term.Literal('hold'), rdflib.term.Literal('p.m.'))
# (rdflib.term.Literal('chinn@millercanfield.com'), rdflib.term.Literal('review'), rdflib.term.Literal('document'))
# (rdflib.term.Literal('tara.sweitzer@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('call'))
# (rdflib.term.Literal('steve.van@enron.com'), rdflib.term.Literal('know'), rdflib.term.Literal('answer'))
# (rdflib.term.Literal('us'), rdflib.term.Literal('send'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('prefer'), rdflib.term.Literal('use document'))
# (rdflib.term.Literal('BASF'), rdflib.term.Literal('show'), rdflib.term.Literal('reviewing'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('marc.eichmann@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('release datum'))
# (rdflib.term.Literal('sheri.luong@enron.com'), rdflib.term.Literal('work'), rdflib.term.Literal('model'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('remove'), rdflib.term.Literal('Brewer'))
# (rdflib.term.Literal('kevin.montagne@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('care'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('modify'), rdflib.term.Literal('EnronOnline'))
# (rdflib.term.Literal('Bank'), rdflib.term.Literal('succeed'), rdflib.term.Literal('right'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('draft'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('Number'))
# (rdflib.term.Literal('Exchange'), rdflib.term.Literal('charge'), rdflib.term.Literal('transaction'))
# (rdflib.term.Literal('karen.lambert@enron.com'), rdflib.term.Literal('meet'), rdflib.term.Literal('a.m.'))
# (rdflib.term.Literal('WATERWAYS'), rdflib.term.Literal('return'), rdflib.term.Literal('operation'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('stay'), rdflib.term.Literal('touch'))
# (rdflib.term.Literal('Heard'), rdflib.term.Literal('deliver'), rdflib.term.Literal('draft'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('arrive'), rdflib.term.Literal('package'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('understand'), rdflib.term.Literal('business purpose'))
# (rdflib.term.Literal('legal <.taylor@enron.com>'), rdflib.term.Literal('make'), rdflib.term.Literal('change'))
# (rdflib.term.Literal('t..hodge@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('problem'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('email'))
# (rdflib.term.Literal('Tana'), rdflib.term.Literal('see'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('peter.keohane@enron.com'), rdflib.term.Literal('review'), rdflib.term.Literal('eye'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('correction'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('error'))
# (rdflib.term.Literal('c..koehler@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('change'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('forward'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('Marketing'), rdflib.term.Literal('provide'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('click'), rdflib.term.Literal('logout link'))
# (rdflib.term.Literal('rep'), rdflib.term.Literal('help'), rdflib.term.Literal('cadwalader'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('email'), rdflib.term.Literal('company'))
# (rdflib.term.Literal('steve.van@enron.com'), rdflib.term.Literal('appreciate'), rdflib.term.Literal('hear thought'))
# (rdflib.term.Literal('Williams'), rdflib.term.Literal('evaluate'), rdflib.term.Literal('product'))
# (rdflib.term.Literal('SunGard'), rdflib.term.Literal('perform'), rdflib.term.Literal('onset'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('email'), rdflib.term.Literal('nda'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('include'), rdflib.term.Literal('provision'))
# (rdflib.term.Literal('Joanne'), rdflib.term.Literal('prepare'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('x37541'), rdflib.term.Literal('thank'), rdflib.term.Literal('assistance'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('issue'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('execute'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('john.allario@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('NDA'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('remove'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('NDA'))
# (rdflib.term.Literal('leslie.hansen@enron.com'), rdflib.term.Literal('trade'), rdflib.term.Literal('power'))
# (rdflib.term.Literal('kevin.montagne@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('resurrect agreement'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('go'), rdflib.term.Literal('day'))
# (rdflib.term.Literal('Elaine'), rdflib.term.Literal('respond'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('monitor'), rdflib.term.Literal('progress'))
# (rdflib.term.Literal('athena.alexander@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('kill limitation'))
# (rdflib.term.Literal('sharon.crawford@enron.com'), rdflib.term.Literal('go'), rdflib.term.Literal('fax guarantee'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('assignment'))
# (rdflib.term.Literal('john.allario@enron.com'), rdflib.term.Literal('target'), rdflib.term.Literal('company'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('change'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('B'))
# (rdflib.term.Literal('Ryder'), rdflib.term.Literal('put'), rdflib.term.Literal('deal'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('Agreement'))
# (rdflib.term.Literal('rick.antonoff@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('morning'))
# (rdflib.term.Literal('t..hodge@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('chance'))
# (rdflib.term.Literal('holly.keiser@enron.com'), rdflib.term.Literal('know'), rdflib.term.Literal('exception time'))
# (rdflib.term.Literal('credit <.williams@enron.com>'), rdflib.term.Literal('provide'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('chance'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('keep'), rdflib.term.Literal('original'))
# (rdflib.term.Literal('Jay'), rdflib.term.Literal('provide'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('forward'), rdflib.term.Literal('version'))
# (rdflib.term.Literal('Gray'), rdflib.term.Literal('coordinate'), rdflib.term.Literal('release'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('portal'))
# (rdflib.term.Literal('Agreement'), rdflib.term.Literal('amend'), rdflib.term.Literal('notice provision'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('review'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('john.allario@enron.com'), rdflib.term.Literal('enjoy'), rdflib.term.Literal('year'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('gather'), rdflib.term.Literal('fact'))
# (rdflib.term.Literal('Exchange'), rdflib.term.Literal('attempt'), rdflib.term.Literal('make statement'))
# (rdflib.term.Literal('kabarrie@hotmail.com'), rdflib.term.Literal('return'), rdflib.term.Literal('favor'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('database'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('one'))
# (rdflib.term.Literal('elaine.overturf@enron.com'), rdflib.term.Literal('respond'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('Korkmas'), rdflib.term.Literal('pursue'), rdflib.term.Literal('obtaining'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('give'), rdflib.term.Literal('day'))
# (rdflib.term.Literal('Dupont'), rdflib.term.Literal('go'), rdflib.term.Literal('call'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('change'))
# (rdflib.term.Literal('change'), rdflib.term.Literal('reinsert'), rdflib.term.Literal('schedule c'))
# (rdflib.term.Literal('travis.mccullough@enron.com'), rdflib.term.Literal('try'), rdflib.term.Literal('locate file'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('communication'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('am'), rdflib.term.Literal('sorry'))
# (rdflib.term.Literal('you'), rdflib.term.Literal('show'), rdflib.term.Literal('desk'))
# (rdflib.term.Literal('who'), rdflib.term.Literal('clear'), rdflib.term.Literal('firm trade'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('incorporate'), rdflib.term.Literal('portion'))
# (rdflib.term.Literal('WATERWAYS'), rdflib.term.Literal('return'), rdflib.term.Literal('route'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('prepare'), rdflib.term.Literal('form'))
# (rdflib.term.Literal('steve.van@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('review'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('incorporate'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('Johnston'), rdflib.term.Literal('review'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('peter.keohane@enron.com'), rdflib.term.Literal('review'), rdflib.term.Literal('Agreement'))
# (rdflib.term.Literal('amber.ebow@enron.com'), rdflib.term.Literal('confirm'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('john.allario@enron.com'), rdflib.term.Literal('accommodate'), rdflib.term.Literal('wish'))
# (rdflib.term.Literal('Peyer'), rdflib.term.Literal('see'), rdflib.term.Literal('email address'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('product description'))
# (rdflib.term.Literal('Joanne'), rdflib.term.Literal('prepare'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('patrick.mulvany@enron.com'), rdflib.term.Literal('change'), rdflib.term.Literal('status'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('message'))
# (rdflib.term.Literal('athena.alexander@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('language'))
# (rdflib.term.Literal('Gulf'), rdflib.term.Literal('request'), rdflib.term.Literal('change'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('state'), rdflib.term.Literal('Project'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('description item'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('work'), rdflib.term.Literal('company'))
# (rdflib.term.Literal('kabarrie@hotmail.com'), rdflib.term.Literal('get'), rdflib.term.Literal('issue'))
# (rdflib.term.Literal('lorie.hernandez@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('pricing'))
# (rdflib.term.Literal('akurzer@tfsbrokers.com'), rdflib.term.Literal('find'), rdflib.term.Literal('BETA'))
# (rdflib.term.Literal('counterparty'), rdflib.term.Literal('provide'), rdflib.term.Literal('guarantee'))
# (rdflib.term.Literal('Tana'), rdflib.term.Literal('send'), rdflib.term.Literal('NDA'))
# (rdflib.term.Literal('angela.davis@enron.com'), rdflib.term.Literal('redact'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('own'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('carol.st.@enron.com'), rdflib.term.Literal('approach'), rdflib.term.Literal('group'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('announce'), rdflib.term.Literal('plan'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('assignment'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('documentation'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('original'))
# (rdflib.term.Literal('kim.detiveaux@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('item'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('part'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('matter'))
# (rdflib.term.Literal('ross.mesquita@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('get draft'))
# (rdflib.term.Literal('patrick.mulvany@enron.com'), rdflib.term.Literal('follow'), rdflib.term.Literal('trade'))
# (rdflib.term.Literal('rick.antonoff@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('counterparty contact'))
# (rdflib.term.Literal('kevin.montagne@enron.com'), rdflib.term.Literal('sign'), rdflib.term.Literal('side'))
# (rdflib.term.Literal('renee.alfaro@enron.com'), rdflib.term.Literal('log'), rdflib.term.Literal('portal'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('talk'), rdflib.term.Literal('group'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('problem'))
# (rdflib.term.Literal('holly.keiser@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('book'))
# (rdflib.term.Literal('samantha.boyd@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('appointment'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('Amendment'))
# (rdflib.term.Literal('Bradford'), rdflib.term.Literal('sign'), rdflib.term.Literal('behalf'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('delete'), rdflib.term.Literal('Paragraph'))
# (rdflib.term.Literal('tom.moran@enron.com'), rdflib.term.Literal('open'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('patrick.mulvany@enron.com'), rdflib.term.Literal('move'), rdflib.term.Literal('deal'))
# (rdflib.term.Literal('morris.clark@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('form'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('master agreement'))
# (rdflib.term.Literal('TransAlta'), rdflib.term.Literal('sleeve'), rdflib.term.Literal('deal'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('one'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('lance.jameson@enron.com'), rdflib.term.Literal('let'), rdflib.term.Literal('bit'))
# (rdflib.term.Literal('lisa.scully@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('Marie'), rdflib.term.Literal('send'), rdflib.term.Literal('template'))
# (rdflib.term.Literal('georgi.landau@enron.com'), rdflib.term.Literal('set'), rdflib.term.Literal('contract number'))
# (rdflib.term.Literal('Lech'), rdflib.term.Literal('prepare'), rdflib.term.Literal('statement filing'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('version'))
# (rdflib.term.Literal('athena.alexander@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('doc'))
# (rdflib.term.Literal('steve.van@enron.com'), rdflib.term.Literal('revise'), rdflib.term.Literal('input'))
# (rdflib.term.Literal('NDA'), rdflib.term.Literal('cover'), rdflib.term.Literal('matter'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('provision'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('sign'), rdflib.term.Literal('assignment agreement'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('approve'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('kim.detiveaux@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('address'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('release'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('give'), rdflib.term.Literal('lot'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('finalize'), rdflib.term.Literal('LOI'))
# (rdflib.term.Literal('marc.eichmann@enron.com'), rdflib.term.Literal('agree'), rdflib.term.Literal('text'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('fax'), rdflib.term.Literal('NDA'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('ask'), rdflib.term.Literal('forward draft'))
# (rdflib.term.Literal('susan.bailey@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('pm'))
# (rdflib.term.Literal('chairman.ken@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('payment'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('enter'), rdflib.term.Literal('ISDA'))
# (rdflib.term.Literal('susan.bailey@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('Agreement'))
# (rdflib.term.Literal('l..denton@enron.com'), rdflib.term.Literal('consider'), rdflib.term.Literal('disclaimer'))
# (rdflib.term.Literal('Stephanie'), rdflib.term.Literal('update'), rdflib.term.Literal('Notes'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('give'), rdflib.term.Literal('ring'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('work'), rdflib.term.Literal('form'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('take vacation'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('check'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('sheri.luong@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('homepage'))
# (rdflib.term.Literal('georgi.landau@enron.com'), rdflib.term.Literal('expect'), rdflib.term.Literal('receive document'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('contact'), rdflib.term.Literal('counterpartie'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('chance'))
# (rdflib.term.Literal('BP'), rdflib.term.Literal('execute'), rdflib.term.Literal('amendment'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('include'), rdflib.term.Literal('example'))
# (rdflib.term.Literal('members'), rdflib.term.Literal('lease'), rdflib.term.Literal('seat'))
# (rdflib.term.Literal('we'), rdflib.term.Literal('reference'), rdflib.term.Literal('deal number'))
# (rdflib.term.Literal('amber.ebow@enron.com'), rdflib.term.Literal('verify'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('diane.anderson@enron.com'), rdflib.term.Literal('miss'), rdflib.term.Literal('part'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('provision'))
# (rdflib.term.Literal('geordie_hochbaum@transalta.com'), rdflib.term.Literal('follow'), rdflib.term.Literal('issue'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('fax'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('reach'), rdflib.term.Literal('resolution'))
# (rdflib.term.Literal('greeniem@houston.rr.com'), rdflib.term.Literal('advise'), rdflib.term.Literal('Tana'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('address'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('anna.fox@enron.com'), rdflib.term.Literal('put'), rdflib.term.Literal('database isda'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('forward'), rdflib.term.Literal('address'))
# (rdflib.term.Literal('keegan.farrell@enron.com'), rdflib.term.Literal('forward'), rdflib.term.Literal('phone number'))
# (rdflib.term.Literal('kayla.heitmeyer@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('assistance'))
# (rdflib.term.Literal('Clark'), rdflib.term.Literal('request'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('master agreement'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('incorporate'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('mary.cook@enron.com'), rdflib.term.Literal('include'), rdflib.term.Literal('version'))
# (rdflib.term.Literal('amber.ebow@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('amendment'))
# (rdflib.term.Literal('Global'), rdflib.term.Literal('address'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('stephanie.panus@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('trader'), rdflib.term.Literal('govern'), rdflib.term.Literal('trade'))
# (rdflib.term.Literal('greeniem@houston.rr.com'), rdflib.term.Literal('advise'), rdflib.term.Literal('initial document'))
# (rdflib.term.Literal('marc.eichmann@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('document'))
# (rdflib.term.Literal('marie.heard@enron.com'), rdflib.term.Literal('fax'), rdflib.term.Literal('state'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('give'), rdflib.term.Literal('call'))
# (rdflib.term.Literal('NYSE'), rdflib.term.Literal('suspend'), rdflib.term.Literal('trading'))
# (rdflib.term.Literal('mark.greenberg@enron.com'), rdflib.term.Literal('call'), rdflib.term.Literal('Bonner'))
# (rdflib.term.Literal('Allario'), rdflib.term.Literal('forward'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('this'), rdflib.term.Literal('free'), rdflib.term.Literal('cash'))
# (rdflib.term.Literal('sheetal.patel@enron.com'), rdflib.term.Literal('complete'), rdflib.term.Literal('transaction'))
# (rdflib.term.Literal('tana.jones@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('I'), rdflib.term.Literal('develop'), rdflib.term.Literal('database'))

# %%
predicates = set()
for s, p, o in g:
    predicates.add(p)

# %%
predicates
# Out:
# {rdflib.term.Literal('accommodate'),
#  rdflib.term.Literal('act'),
#  rdflib.term.Literal('add'),
#  rdflib.term.Literal('address'),
#  rdflib.term.Literal('advise'),
#  rdflib.term.Literal('agree'),
#  rdflib.term.Literal('am'),
#  rdflib.term.Literal('amend'),
#  rdflib.term.Literal('announce'),
#  rdflib.term.Literal('appreciate'),
#  rdflib.term.Literal('approach'),
#  rdflib.term.Literal('approve'),
#  rdflib.term.Literal('arrive'),
#  rdflib.term.Literal('ask'),
#  rdflib.term.Literal('assist'),
#  rdflib.term.Literal('attach'),
#  rdflib.term.Literal('attempt'),
#  rdflib.term.Literal('begin'),
#  rdflib.term.Literal('call'),
#  rdflib.term.Literal('change'),
#  rdflib.term.Literal('charge'),
#  rdflib.term.Literal('check'),
#  rdflib.term.Literal('circulate'),
#  rdflib.term.Literal('clear'),
#  rdflib.term.Literal('click'),
#  rdflib.term.Literal('complete'),
#  rdflib.term.Literal('confirm'),
#  rdflib.term.Literal('consider'),
#  rdflib.term.Literal('contact'),
#  rdflib.term.Literal('coordinate'),
#  rdflib.term.Literal('copy'),
#  rdflib.term.Literal('cover'),
#  rdflib.term.Literal('delete'),
#  rdflib.term.Literal('deliver'),
#  rdflib.term.Literal('develop'),
#  rdflib.term.Literal('discuss'),
#  rdflib.term.Literal('distribute'),
#  rdflib.term.Literal('draft'),
#  rdflib.term.Literal('elevate'),
#  rdflib.term.Literal('email'),
#  rdflib.term.Literal('enjoy'),
#  rdflib.term.Literal('enter'),
#  rdflib.term.Literal('establish'),
#  rdflib.term.Literal('evaluate'),
#  rdflib.term.Literal('execute'),
#  rdflib.term.Literal('expect'),
#  rdflib.term.Literal('fax'),
#  rdflib.term.Literal('feel'),
#  rdflib.term.Literal('finalize'),
#  rdflib.term.Literal('find'),
#  rdflib.term.Literal('follow'),
#  rdflib.term.Literal('forward'),
#  rdflib.term.Literal('free'),
#  rdflib.term.Literal('gather'),
#  rdflib.term.Literal('get'),
#  rdflib.term.Literal('give'),
#  rdflib.term.Literal('go'),
#  rdflib.term.Literal('govern'),
#  rdflib.term.Literal('have'),
#  rdflib.term.Literal('help'),
#  rdflib.term.Literal('hold'),
#  rdflib.term.Literal('implement'),
#  rdflib.term.Literal('inactivate'),
#  rdflib.term.Literal('include'),
#  rdflib.term.Literal('incorporate'),
#  rdflib.term.Literal('join'),
#  rdflib.term.Literal('keep'),
#  rdflib.term.Literal('know'),
#  rdflib.term.Literal('lease'),
#  rdflib.term.Literal('leave'),
#  rdflib.term.Literal('let'),
#  rdflib.term.Literal('like'),
#  rdflib.term.Literal('listen'),
#  rdflib.term.Literal('log'),
#  rdflib.term.Literal('look'),
#  rdflib.term.Literal('make'),
#  rdflib.term.Literal('meet'),
#  rdflib.term.Literal('miss'),
#  rdflib.term.Literal('modify'),
#  rdflib.term.Literal('monitor'),
#  rdflib.term.Literal('move'),
#  rdflib.term.Literal('need'),
#  rdflib.term.Literal('office'),
#  rdflib.term.Literal('open'),
#  rdflib.term.Literal('order'),
#  rdflib.term.Literal('outline'),
#  rdflib.term.Literal('own'),
#  rdflib.term.Literal('perform'),
#  rdflib.term.Literal('plan'),
#  rdflib.term.Literal('prefer'),
#  rdflib.term.Literal('prepare'),
#  rdflib.term.Literal('proceed'),
#  rdflib.term.Literal('provide'),
#  rdflib.term.Literal('purchase'),
#  rdflib.term.Literal('pursue'),
#  rdflib.term.Literal('put'),
#  rdflib.term.Literal('re'),
#  rdflib.term.Literal('reach'),
#  rdflib.term.Literal('read'),
#  rdflib.term.Literal('receive'),
#  rdflib.term.Literal('redact'),
#  rdflib.term.Literal('reference'),
#  rdflib.term.Literal('reinsert'),
#  rdflib.term.Literal('relate'),
#  rdflib.term.Literal('release'),
#  rdflib.term.Literal('remove'),
#  rdflib.term.Literal('request'),
#  rdflib.term.Literal('respond'),
#  rdflib.term.Literal('retain'),
#  rdflib.term.Literal('return'),
#  rdflib.term.Literal('review'),
#  rdflib.term.Literal('revise'),
#  rdflib.term.Literal('see'),
#  rdflib.term.Literal('send'),
#  rdflib.term.Literal('set'),
#  rdflib.term.Literal('share'),
#  rdflib.term.Literal('show'),
#  rdflib.term.Literal('sign'),
#  rdflib.term.Literal('sleeve'),
#  rdflib.term.Literal('state'),
#  rdflib.term.Literal('stay'),
#  rdflib.term.Literal('succeed'),
#  rdflib.term.Literal('suspend'),
#  rdflib.term.Literal('take'),
#  rdflib.term.Literal('talk'),
#  rdflib.term.Literal('target'),
#  rdflib.term.Literal('thank'),
#  rdflib.term.Literal('trade'),
#  rdflib.term.Literal('travel'),
#  rdflib.term.Literal('try'),
#  rdflib.term.Literal('understand'),
#  rdflib.term.Literal('update'),
#  rdflib.term.Literal('use'),
#  rdflib.term.Literal('verify'),
#  rdflib.term.Literal('wait'),
#  rdflib.term.Literal('waive'),
#  rdflib.term.Literal('want'),
#  rdflib.term.Literal('work')}

# %%
qres = g.query('SELECT ?s ?o where { ?s ?p ?o . }',initBindings = {'p':Literal('remove')})

for row in qres:
    print("%s -> %s"%row)
# Out:
# tana.jones@enron.com -> Brewer
# tana.jones@enron.com -> list

# %%
msg_key_idx
# Out:
# {(rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('prefer'),
#   rdflib.term.Literal('use document')): [15000],
#  (rdflib.term.Literal('Tana'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('company')): [15000],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('authorization')): [15008],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('database')): [15008],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('return'),
#   rdflib.term.Literal('work')): [15009],
#  (rdflib.term.Literal('Dupont'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('call')): [15010],
#  (rdflib.term.Literal('angela.davis@enron.com'),
#   rdflib.term.Literal('redact'),
#   rdflib.term.Literal('copy')): [15012],
#  (rdflib.term.Literal('amber.ebow@enron.com'),
#   rdflib.term.Literal('confirm'),
#   rdflib.term.Literal('information')): [15015],
#  (rdflib.term.Literal('amber.ebow@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('spreadsheet')): [15015],
#  (rdflib.term.Literal('stephanie.sever@enron.com'),
#   rdflib.term.Literal('inactivate'),
#   rdflib.term.Literal('counterparty')): [15016],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('B')): [15018],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('confirm')): [15018],
#  (rdflib.term.Literal('we'),
#   rdflib.term.Literal('reference'),
#   rdflib.term.Literal('deal number')): [15018],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('miss'),
#   rdflib.term.Literal('part')): [15018],
#  (rdflib.term.Literal('sheri.luong@enron.com'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('model')): [15019],
#  (rdflib.term.Literal('I'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('agreement')): [15019],
#  (rdflib.term.Literal('patrick.mulvany@enron.com'),
#   rdflib.term.Literal('follow'),
#   rdflib.term.Literal('trade')): [15022],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('consultant')): [15026],
#  (rdflib.term.Literal('leslie.hansen@enron.com'),
#   rdflib.term.Literal('trade'),
#   rdflib.term.Literal('power')): [15028],
#  (rdflib.term.Literal('leslie.hansen@enron.com'),
#   rdflib.term.Literal('trade'),
#   rdflib.term.Literal('East')): [15028],
#  (rdflib.term.Literal('leslie.hansen@enron.com'),
#   rdflib.term.Literal('trade'),
#   rdflib.term.Literal('agreement')): [15028],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('assignment')): [15030],
#  (rdflib.term.Literal('Marketing'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('Enron')): [15032],
#  (rdflib.term.Literal('Marketing'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('letter')): [15032],
#  (rdflib.term.Literal('tom.moran@enron.com'),
#   rdflib.term.Literal('open'),
#   rdflib.term.Literal('access')): [15032],
#  (rdflib.term.Literal('tom.moran@enron.com'),
#   rdflib.term.Literal('enter'),
#   rdflib.term.Literal('calendar month')): [15032, 15032],
#  (rdflib.term.Literal('tom.moran@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('credit change')): [15032],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('master agreement')): [15033,
#   15054,
#   15061,
#   15478,
#   15481],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('Amendment')): [15036, 15083],
#  (rdflib.term.Literal('georgi.landau@enron.com'),
#   rdflib.term.Literal('update'),
#   rdflib.term.Literal('contract number')): [15037, 15062, 15137, 15209, 15210],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('agreement')): [15046],
#  (rdflib.term.Literal('kim.detiveaux@enron.com'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('address')): [15046],
#  (rdflib.term.Literal('kim.detiveaux@enron.com'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('item')): [15046],
#  (rdflib.term.Literal('marc.eichmann@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('document')): [15047],
#  (rdflib.term.Literal('susan.bailey@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('Agreement')): [15057, 15206],
#  (rdflib.term.Literal('BASF'),
#   rdflib.term.Literal('show'),
#   rdflib.term.Literal('reviewing')): [15058],
#  (rdflib.term.Literal('Lebrocq'),
#   rdflib.term.Literal('approve'),
#   rdflib.term.Literal('copy profile')): [15073],
#  (rdflib.term.Literal('craig.chaney@enron.com'),
#   rdflib.term.Literal('follow'),
#   rdflib.term.Literal('procedure')): [15075],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('call')): [15080],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('assignment agreement')): [15080],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('give'),
#   rdflib.term.Literal('call')): [15080, 15190],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('listen'),
#   rdflib.term.Literal('messege')): [15080],
#  (rdflib.term.Literal('Companies'),
#   rdflib.term.Literal('execute'),
#   rdflib.term.Literal('power trade')): [15082],
#  (rdflib.term.Literal('Ryder'),
#   rdflib.term.Literal('put'),
#   rdflib.term.Literal('deal')): [15084],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('issue')): [15084],
#  (rdflib.term.Literal('patrick.mulvany@enron.com'),
#   rdflib.term.Literal('change'),
#   rdflib.term.Literal('status')): [15084],
#  (rdflib.term.Literal('annette.rosario@db.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('c')): [15092],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('problem')): [15094],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('chance')): [15095, 15143],
#  (rdflib.term.Literal('geordie_hochbaum@transalta.com'),
#   rdflib.term.Literal('follow'),
#   rdflib.term.Literal('issue')): [15098],
#  (rdflib.term.Literal('TransAlta'),
#   rdflib.term.Literal('sleeve'),
#   rdflib.term.Literal('deal')): [15098],
#  (rdflib.term.Literal('kabarrie@hotmail.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('issue')): [15100],
#  (rdflib.term.Literal('kabarrie@hotmail.com'),
#   rdflib.term.Literal('return'),
#   rdflib.term.Literal('favor')): [15100],
#  (rdflib.term.Literal('bob.shults@enron.com'),
#   rdflib.term.Literal('copy'),
#   rdflib.term.Literal('guy')): [15102],
#  (rdflib.term.Literal('greeniem@houston.rr.com'),
#   rdflib.term.Literal('advise'),
#   rdflib.term.Literal('Tana')): [15107],
#  (rdflib.term.Literal('greeniem@houston.rr.com'),
#   rdflib.term.Literal('advise'),
#   rdflib.term.Literal('initial document')): [15107],
#  (rdflib.term.Literal('Tana'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('NDA')): [15112],
#  (rdflib.term.Literal('sheetal.patel@enron.com'),
#   rdflib.term.Literal('complete'),
#   rdflib.term.Literal('transaction')): [15120],
#  (rdflib.term.Literal('Robert'),
#   rdflib.term.Literal('approve'),
#   rdflib.term.Literal('Description')): [15121],
#  (rdflib.term.Literal('Transaction'),
#   rdflib.term.Literal('purchase'),
#   rdflib.term.Literal('quantity')): [15121],
#  (rdflib.term.Literal('hkjii@erols.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('Emails')): [15126],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('modify'),
#   rdflib.term.Literal('EnronOnline')): [15128],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('master agreement')): [15129, 15131],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('modification')): [15130],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('document')): [15130],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('understand'),
#   rdflib.term.Literal('business purpose')): [15130],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('want'),
#   rdflib.term.Literal('make document')): [15130],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('implement'),
#   rdflib.term.Literal('language')): [15130],
#  (rdflib.term.Literal('Mark'),
#   rdflib.term.Literal('request'),
#   rdflib.term.Literal('change')): [15133],
#  (rdflib.term.Literal('Gulf'),
#   rdflib.term.Literal('request'),
#   rdflib.term.Literal('change')): [15133],
#  (rdflib.term.Literal('marc.eichmann@enron.com'),
#   rdflib.term.Literal('agree'),
#   rdflib.term.Literal('text')): [15134],
#  (rdflib.term.Literal('marc.eichmann@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('release datum')): [15134],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('agreement')): [15134],
#  (rdflib.term.Literal('this'),
#   rdflib.term.Literal('free'),
#   rdflib.term.Literal('cash')): [15134],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('matter')): [15135],
#  (rdflib.term.Literal('KY'),
#   rdflib.term.Literal('re'),
#   rdflib.term.Literal('transaction')): [15138],
#  (rdflib.term.Literal('Bradford'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('behalf')): [15146],
#  (rdflib.term.Literal('georgi.landau@enron.com'),
#   rdflib.term.Literal('expect'),
#   rdflib.term.Literal('receive document')): [15154],
#  (rdflib.term.Literal('georgi.landau@enron.com'),
#   rdflib.term.Literal('wait'),
#   rdflib.term.Literal('agreement')): [15155],
#  (rdflib.term.Literal('georgi.landau@enron.com'),
#   rdflib.term.Literal('set'),
#   rdflib.term.Literal('contract number')): [15155],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('one')): [15158],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('copy')): [15161],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('thought')): [15161,
#   15237,
#   15259,
#   15264,
#   15295,
#   15428,
#   15462],
#  (rdflib.term.Literal('BP'),
#   rdflib.term.Literal('execute'),
#   rdflib.term.Literal('amendment')): [15171],
#  (rdflib.term.Literal('sharon.crawford@enron.com'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('fax guarantee')): [15171],
#  (rdflib.term.Literal('stacy.fitzgerald@enron.com'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('file')): [15173],
#  (rdflib.term.Literal('john.allario@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('NDA')): [15174],
#  (rdflib.term.Literal('john.allario@enron.com'),
#   rdflib.term.Literal('target'),
#   rdflib.term.Literal('company')): [15174],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('termination letter')): [15175],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('keep'),
#   rdflib.term.Literal('original')): [15175],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('want'),
#   rdflib.term.Literal('copy')): [15177],
#  (rdflib.term.Literal('tara.sweitzer@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('call')): [15190],
#  (rdflib.term.Literal('john.allario@enron.com'),
#   rdflib.term.Literal('enjoy'),
#   rdflib.term.Literal('year')): [15191],
#  (rdflib.term.Literal('patrick.mulvany@enron.com'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('deal')): [15193],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('office')): [15195, 15195],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('appointment')): [15195],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('time')): [15195],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('travel'),
#   rdflib.term.Literal('funeral')): [15195],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('list')): [15196],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('own'),
#   rdflib.term.Literal('%')): [15196],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('agreement')): [15198],
#  (rdflib.term.Literal('Johnston'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('list')): [15200],
#  (rdflib.term.Literal('legal <.taylor@enron.com>'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('have lot')): [15201],
#  (rdflib.term.Literal('greg.johnston@enron.com'),
#   rdflib.term.Literal('delete'),
#   rdflib.term.Literal('reference')): [15202],
#  (rdflib.term.Literal('morris.clark@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('form')): [15204],
#  (rdflib.term.Literal('Jay'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('name')): [15207],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('copy')): [15211],
#  (rdflib.term.Literal('credit <.williams@enron.com>'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('name')): [15212],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('pull contract')): [15212],
#  (rdflib.term.Literal('Tana'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('comment')): [15214],
#  (rdflib.term.Literal('akurzer@tfsbrokers.com'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('BETA')): [15215],
#  (rdflib.term.Literal('carol.st.@enron.com'),
#   rdflib.term.Literal('approach'),
#   rdflib.term.Literal('group')): [15219],
#  (rdflib.term.Literal('trader'),
#   rdflib.term.Literal('govern'),
#   rdflib.term.Literal('trade')): [15225],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('check'),
#   rdflib.term.Literal('file')): [15226],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('circulate'),
#   rdflib.term.Literal('list')): [15229],
#  (rdflib.term.Literal('rick.antonoff@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('call')): [15231],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('Agreement')): [15234, 15239, 15253, 15282],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('prepare'),
#   rdflib.term.Literal('letter agreement')): [15237],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('prepare'),
#   rdflib.term.Literal('form')): [15237],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('party')): [15238],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('form')): [15240],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('one')): [15243],
#  (rdflib.term.Literal('Elaine'),
#   rdflib.term.Literal('respond'),
#   rdflib.term.Literal('question')): [15245],
#  (rdflib.term.Literal('elaine.overturf@enron.com'),
#   rdflib.term.Literal('respond'),
#   rdflib.term.Literal('question')): [15245],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('change'),
#   rdflib.term.Literal('mind')): [15250],
#  (rdflib.term.Literal('Exchange'),
#   rdflib.term.Literal('charge'),
#   rdflib.term.Literal('transaction')): [15251],
#  (rdflib.term.Literal('Exchange'),
#   rdflib.term.Literal('attempt'),
#   rdflib.term.Literal('make statement')): [15251],
#  (rdflib.term.Literal('travis.mccullough@enron.com'),
#   rdflib.term.Literal('try'),
#   rdflib.term.Literal('locate file')): [15252],
#  (rdflib.term.Literal('Agreement'),
#   rdflib.term.Literal('amend'),
#   rdflib.term.Literal('notice provision')): [15253],
#  (rdflib.term.Literal('NDA'),
#   rdflib.term.Literal('cover'),
#   rdflib.term.Literal('matter')): [15255],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('call'),
#   rdflib.term.Literal('Bonner')): [15255],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('agreement')): [15255, 15357],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('outline'),
#   rdflib.term.Literal('work')): [15255],
#  (rdflib.term.Literal('SunGard'),
#   rdflib.term.Literal('perform'),
#   rdflib.term.Literal('onset')): [15255],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('day')): [15255],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('correction')): [15256],
#  (rdflib.term.Literal('jeannine.ford@experian.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('message')): [15259],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('change')): [15259, 15267],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('version')): [15259, 15443, 15466],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('incorporate'),
#   rdflib.term.Literal('portion')): [15259],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('original')): [15259, 15269],
#  (rdflib.term.Literal("you'all"),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('time')): [15262],
#  (rdflib.term.Literal('becky.spencer@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('copy')): [15262],
#  (rdflib.term.Literal('deb.korkmas@enron.com'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('copy')): [15263],
#  (rdflib.term.Literal('Allario'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('comment')): [15264],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('agree'),
#   rdflib.term.Literal('revision')): [15264],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('state'),
#   rdflib.term.Literal('Project')): [15264],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('incorporate'),
#   rdflib.term.Literal('agreement')): [15264],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('incorporate'),
#   rdflib.term.Literal('comment')): [15264],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('include'),
#   rdflib.term.Literal('version')): [15268],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('distribute'),
#   rdflib.term.Literal('process memo')): [15268],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('update')): [15269],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('address')): [15269],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('NDA')): [15270],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('comment')): [15270],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('event')): [15270],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('version')): [15270],
#  (rdflib.term.Literal('Cheryl'),
#   rdflib.term.Literal('feel'),
#   rdflib.term.Literal('weather')): [15271],
#  (rdflib.term.Literal('kayla.heitmeyer@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('assistance')): [15271, 15497],
#  (rdflib.term.Literal('x37541'),
#   rdflib.term.Literal('thank'),
#   rdflib.term.Literal('assistance')): [15276],
#  (rdflib.term.Literal('ross.mesquita@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('get draft')): [15277],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('email'),
#   rdflib.term.Literal('nda')): [15277],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('email'),
#   rdflib.term.Literal('company')): [15277],
#  (rdflib.term.Literal('ross.mesquita@enron.com'),
#   rdflib.term.Literal('want'),
#   rdflib.term.Literal('take approach')): [15277],
#  (rdflib.term.Literal('ross.mesquita@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('info')): [15277],
#  (rdflib.term.Literal('ross.mesquita@enron.com'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('stage')): [15277],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('information')): [15277],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('extraction')): [15278],
#  (rdflib.term.Literal('sheri.luong@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('homepage')): [15279],
#  (rdflib.term.Literal('l..denton@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('one')): [15279],
#  (rdflib.term.Literal('l..denton@enron.com'),
#   rdflib.term.Literal('consider'),
#   rdflib.term.Literal('disclaimer')): [15279],
#  (rdflib.term.Literal('Bank'),
#   rdflib.term.Literal('succeed'),
#   rdflib.term.Literal('right')): [15282],
#  (rdflib.term.Literal('NDA'),
#   rdflib.term.Literal('relate'),
#   rdflib.term.Literal('sale')): [15283],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('NDA')): [15283],
#  (rdflib.term.Literal('WATERWAYS'),
#   rdflib.term.Literal('return'),
#   rdflib.term.Literal('route')): [15284],
#  (rdflib.term.Literal('WATERWAYS'),
#   rdflib.term.Literal('return'),
#   rdflib.term.Literal('operation')): [15284],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('address'),
#   rdflib.term.Literal('time')): [15292],
#  (rdflib.term.Literal('rick.antonoff@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('counterparty contact')): [15293],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('gather'),
#   rdflib.term.Literal('fact')): [15293],
#  (rdflib.term.Literal('rick.antonoff@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('morning')): [15294],
#  (rdflib.term.Literal('Gray'),
#   rdflib.term.Literal('coordinate'),
#   rdflib.term.Literal('release')): [15294],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('execute'),
#   rdflib.term.Literal('agreement')): [15294],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('agreement')): [15294],
#  (rdflib.term.Literal('carol.st.@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('copy')): [15296],
#  (rdflib.term.Literal('carol.st.@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('default notice')): [15296],
#  (rdflib.term.Literal('lance.jameson@enron.com'),
#   rdflib.term.Literal('let'),
#   rdflib.term.Literal('bit')): [15297],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('remove'),
#   rdflib.term.Literal('Brewer')): [15299],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('remove'),
#   rdflib.term.Literal('list')): [15299],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('finalize'),
#   rdflib.term.Literal('agreement')): [15305],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('execution original')): [15305],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('attention')): [15305],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('chance')): [15306],
#  (rdflib.term.Literal('steve.van@enron.com'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('draft')): [15309],
#  (rdflib.term.Literal('change'),
#   rdflib.term.Literal('reinsert'),
#   rdflib.term.Literal('schedule c')): [15309],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('contact'),
#   rdflib.term.Literal('counterpartie')): [15310],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('am'),
#   rdflib.term.Literal('sorry')): [15313],
#  (rdflib.term.Literal('Marcus'),
#   rdflib.term.Literal('proceed'),
#   rdflib.term.Literal('document')): [15314],
#  (rdflib.term.Literal('Korkmas'),
#   rdflib.term.Literal('pursue'),
#   rdflib.term.Literal('obtaining')): [15314],
#  (rdflib.term.Literal('steve.van@enron.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('answer')): [15314],
#  (rdflib.term.Literal('steve.van@enron.com'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('review')): [15316],
#  (rdflib.term.Literal('t..hodge@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('chance')): [15316],
#  (rdflib.term.Literal('steve.van@enron.com'),
#   rdflib.term.Literal('revise'),
#   rdflib.term.Literal('input')): [15317],
#  (rdflib.term.Literal('Jeff'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('sample')): [15317],
#  (rdflib.term.Literal('keegan.farrell@enron.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('phone number')): [15318],
#  (rdflib.term.Literal('Bob'),
#   rdflib.term.Literal('ask'),
#   rdflib.term.Literal('forward amendment')): [15320],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('consider'),
#   rdflib.term.Literal('access')): [15320],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('see draft')): [15321],
#  (rdflib.term.Literal('c..koehler@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('change')): [15325],
#  (rdflib.term.Literal('peter.keohane@enron.com'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('Agreement')): [15326],
#  (rdflib.term.Literal('peter.keohane@enron.com'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('eye')): [15326],
#  (rdflib.term.Literal('somebody'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('provide list')): [15326],
#  (rdflib.term.Literal('c..koehler@enron.com'),
#   rdflib.term.Literal('draft'),
#   rdflib.term.Literal('paragraph')): [15327],
#  (rdflib.term.Literal('steve.van@enron.com'),
#   rdflib.term.Literal('appreciate'),
#   rdflib.term.Literal('hear thought')): [15331],
#  (rdflib.term.Literal('counterparty'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('guarantee')): [15332],
#  (rdflib.term.Literal('susan.bailey@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('difficulty')): [15333],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('keep'),
#   rdflib.term.Literal('lunch meeting')): [15333],
#  (rdflib.term.Literal('t..hodge@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('problem')): [15334],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('arrive'),
#   rdflib.term.Literal('package')): [15336],
#  (rdflib.term.Literal('r..brackett@enron.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('answer question')): [15337],
#  (rdflib.term.Literal('becky.spencer@enron.com'),
#   rdflib.term.Literal('help'),
#   rdflib.term.Literal('work table')): [15338],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('list')): [15340],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('company')): [15344],
#  (rdflib.term.Literal('kevin.montagne@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('side')): [15344],
#  (rdflib.term.Literal('kevin.montagne@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('resurrect agreement')): [15344],
#  (rdflib.term.Literal('kevin.montagne@enron.com'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('care')): [15344],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('enter'),
#   rdflib.term.Literal('ISDA')): [15348],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('enter'),
#   rdflib.term.Literal('database')): [15348],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('include'),
#   rdflib.term.Literal('example')): [15348],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('include'),
#   rdflib.term.Literal('provision')): [15348],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('plan'),
#   rdflib.term.Literal('address request')): [15356],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('talk'),
#   rdflib.term.Literal('group')): [15357],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('email')): [15358],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('monitor'),
#   rdflib.term.Literal('progress')): [15358],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('purchase'),
#   rdflib.term.Literal('system')): [15358],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('Number')): [15358],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('order'),
#   rdflib.term.Literal('item')): [15358],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('ask'),
#   rdflib.term.Literal('attorney')): [15359],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('ask'),
#   rdflib.term.Literal('forward draft')): [15359],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('copy')): [15359],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('state')): [15359],
#  (rdflib.term.Literal('Lech'),
#   rdflib.term.Literal('prepare'),
#   rdflib.term.Literal('statement filing')): [15360],
#  (rdflib.term.Literal('Heard'),
#   rdflib.term.Literal('deliver'),
#   rdflib.term.Literal('draft')): [15367],
#  (rdflib.term.Literal('alan.aronowitz@enron.com'),
#   rdflib.term.Literal('act'),
#   rdflib.term.Literal('resource')): [15372],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('list')): [15372],
#  (rdflib.term.Literal('anyone'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('file')): [15374],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('change')): [15377],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('put'),
#   rdflib.term.Literal('user note')): [15377],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('put'),
#   rdflib.term.Literal('document')): [15377],
#  (rdflib.term.Literal('Peter'),
#   rdflib.term.Literal('look'),
#   rdflib.term.Literal('morning')): [15379],
#  (rdflib.term.Literal('you'),
#   rdflib.term.Literal('show'),
#   rdflib.term.Literal('desk')): [15379],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('message')): [15379, 15382, 15420],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('error')): [15379, 15382, 15420, 15432],
#  (rdflib.term.Literal('Peyer'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('email address')): [15383],
#  (rdflib.term.Literal('This'),
#   rdflib.term.Literal('elevate'),
#   rdflib.term.Literal('default')): [15386],
#  (rdflib.term.Literal('athena.alexander@enron.com'),
#   rdflib.term.Literal('want'),
#   rdflib.term.Literal('kill limitation')): [15386],
#  (rdflib.term.Literal('athena.alexander@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('language')): [15386],
#  (rdflib.term.Literal('athena.alexander@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('doc')): [15386],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('master agreement')): [15387],
#  (rdflib.term.Literal('holly.keiser@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('book')): [15398],
#  (rdflib.term.Literal('chinn@millercanfield.com'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('document')): [15400],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('Agreement')): [15409],
#  (rdflib.term.Literal('Joanne'),
#   rdflib.term.Literal('prepare'),
#   rdflib.term.Literal('file')): [15410],
#  (rdflib.term.Literal('Joanne'),
#   rdflib.term.Literal('prepare'),
#   rdflib.term.Literal('copy')): [15410],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('confidentiality agreement')): [15413],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('keep'),
#   rdflib.term.Literal('track')): [15413],
#  (rdflib.term.Literal('ross.mesquita@enron.com'),
#   rdflib.term.Literal('request'),
#   rdflib.term.Literal('letter')): [15413],
#  (rdflib.term.Literal('stephanie.panus@enron.com'),
#   rdflib.term.Literal('finalize'),
#   rdflib.term.Literal('letter')): [15414],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('original')): [15414],
#  (rdflib.term.Literal('date'),
#   rdflib.term.Literal('own'),
#   rdflib.term.Literal('seat')): [15416],
#  (rdflib.term.Literal('members'),
#   rdflib.term.Literal('lease'),
#   rdflib.term.Literal('seat')): [15416],
#  (rdflib.term.Literal('who'),
#   rdflib.term.Literal('clear'),
#   rdflib.term.Literal('firm trade')): [15416],
#  (rdflib.term.Literal('who'),
#   rdflib.term.Literal('execute'),
#   rdflib.term.Literal('trade')): [15416],
#  (rdflib.term.Literal('lisa.scully@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('name')): [15419],
#  (rdflib.term.Literal('I'),
#   rdflib.term.Literal('develop'),
#   rdflib.term.Literal('database')): [15419],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('approve'),
#   rdflib.term.Literal('access')): [15419],
#  (rdflib.term.Literal('Clark'),
#   rdflib.term.Literal('request'),
#   rdflib.term.Literal('access')): [15419],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('assist'),
#   rdflib.term.Literal('status')): [15421],
#  (rdflib.term.Literal('susan.bailey@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('assistance')): [15422],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('discussion')): [15423],
#  (rdflib.term.Literal('NYSE'),
#   rdflib.term.Literal('suspend'),
#   rdflib.term.Literal('trading')): [15423],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('share'),
#   rdflib.term.Literal('time')): [15423],
#  (rdflib.term.Literal('susan.bailey@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('pm')): [15427],
#  (rdflib.term.Literal('susan.bailey@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('morning')): [15427],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('provision')): [15428],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('pricing')): [15430],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('comment')): [15430],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('phone')): [15430],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('letter')): [15430],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('establish'),
#   rdflib.term.Literal('rapport')): [15430],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('copy')): [15432],
#  (rdflib.term.Literal('Agreement'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('attention')): [15432],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('communication')): [15432],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('release'),
#   rdflib.term.Literal('information')): [15433],
#  (rdflib.term.Literal('craigvasquezjones@hotmail.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('arrival time')): [15436],
#  (rdflib.term.Literal('User'),
#   rdflib.term.Literal('read'),
#   rdflib.term.Literal('message')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('portal')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('log'),
#   rdflib.term.Literal('portal')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('log'),
#   rdflib.term.Literal('password')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('portal')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('past')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('click'),
#   rdflib.term.Literal('logout link')): [15437],
#  (rdflib.term.Literal('renee.alfaro@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('provide feedback')): [15437],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('put'),
#   rdflib.term.Literal('database isda')): [15439],
#  (rdflib.term.Literal('anna.fox@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('one')): [15439],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('point')): [15441],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('look'),
#   rdflib.term.Literal('form')): [15443],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('retain'),
#   rdflib.term.Literal('concept')): [15443],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('retain'),
#   rdflib.term.Literal('term')): [15443],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('retain'),
#   rdflib.term.Literal('termination')): [15443],
#  (rdflib.term.Literal('Williams'),
#   rdflib.term.Literal('evaluate'),
#   rdflib.term.Literal('product')): [15443],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('reach'),
#   rdflib.term.Literal('resolution')): [15443],
#  (rdflib.term.Literal('legal <.taylor@enron.com>'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('change')): [15445],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('Program')): [15448],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('take vacation')): [15448],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('draft')): [15450],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('product description')): [15450],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('finalize'),
#   rdflib.term.Literal('LOI')): [15450],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('announce'),
#   rdflib.term.Literal('plan')): [15452],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('stay'),
#   rdflib.term.Literal('touch')): [15453],
#  (rdflib.term.Literal('us'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('letter')): [15456],
#  (rdflib.term.Literal('rep'),
#   rdflib.term.Literal('help'),
#   rdflib.term.Literal('cadwalader')): [15457],
#  (rdflib.term.Literal('rep'),
#   rdflib.term.Literal('help'),
#   rdflib.term.Literal('process')): [15457],
#  (rdflib.term.Literal('marie.heard@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('Agreement')): [15459, 15460],
#  (rdflib.term.Literal('Caminus'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('reference')): [15461],
#  (rdflib.term.Literal('john.allario@enron.com'),
#   rdflib.term.Literal('accommodate'),
#   rdflib.term.Literal('wish')): [15461],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('matter')): [15462],
#  (rdflib.term.Literal('Haedicke'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('floor meeting')): [15463],
#  (rdflib.term.Literal('Haedicke'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('p.m.')): [15463],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('agreement')): [15466],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('initial letter')): [15466],
#  (rdflib.term.Literal('lorie.hernandez@enron.com'),
#   rdflib.term.Literal('attach'),
#   rdflib.term.Literal('description item')): [15466],
#  (rdflib.term.Literal('mark.greenberg@enron.com'),
#   rdflib.term.Literal('delete'),
#   rdflib.term.Literal('Paragraph')): [15471],
#  (rdflib.term.Literal('mary.cook@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('provision')): [15473],
#  (rdflib.term.Literal('sarah.dietrich@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('annex template')): [15474],
#  (rdflib.term.Literal('Marie'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('template')): [15474],
#  (rdflib.term.Literal('sarah.dietrich@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('template')): [15474],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('assignment')): [15480],
#  (rdflib.term.Literal('Reed'),
#   rdflib.term.Literal('look'),
#   rdflib.term.Literal('update')): [15480],
#  (rdflib.term.Literal('tana.jones@enron.com'),
#   rdflib.term.Literal('give'),
#   rdflib.term.Literal('ring')): [15480],
#  (rdflib.term.Literal('samantha.boyd@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('documentation')): [15482],
#  (rdflib.term.Literal('diane.anderson@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('request')): [15485],
#  (rdflib.term.Literal('Sales'),
#   rdflib.term.Literal('trade'),
#   rdflib.term.Literal('lpg')): [15487],
#  (rdflib.term.Literal('someone'),
#   rdflib.term.Literal('call'),
#   rdflib.term.Literal('Redd')): [15487],
#  (rdflib.term.Literal('someone'),
#   rdflib.term.Literal('call'),
#   rdflib.term.Literal('start process')): [15487],
#  (rdflib.term.Literal('holly.keiser@enron.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('exception time')): [15488],
#  (rdflib.term.Literal('amber.ebow@enron.com'),
#   rdflib.term.Literal('wait'),
#   rdflib.term.Literal('confirmation')): [15491],
#  (rdflib.term.Literal('amber.ebow@enron.com'),
#   rdflib.term.Literal('verify'),
#   rdflib.term.Literal('information')): [15491],
#  (rdflib.term.Literal('amber.ebow@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('amendment')): [15491],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('give'),
#   rdflib.term.Literal('lot')): [15492],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('give'),
#   rdflib.term.Literal('day')): [15492],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('part')): [15492],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('foundation')): [15492],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('waive'),
#   rdflib.term.Literal('right')): [15492],
#  (rdflib.term.Literal('chairman.ken@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('payment')): [15492],
#  (rdflib.term.Literal('Stephanie'),
#   rdflib.term.Literal('update'),
#   rdflib.term.Literal('Notes')): [15496],
#  (rdflib.term.Literal('keegan.farrell@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('call')): [15497],
#  (rdflib.term.Literal('Haedicke'),
#   rdflib.term.Literal('office'),
#   rdflib.term.Literal('building')): [15498],
#  (rdflib.term.Literal('Global'),
#   rdflib.term.Literal('address'),
#   rdflib.term.Literal('meeting')): [15499],
#  (rdflib.term.Literal('karen.lambert@enron.com'),
#   rdflib.term.Literal('meet'),
#   rdflib.term.Literal('a.m.')): [15499]}

# %%
msg_key_idx_reverse
# Out:
# {15000: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('prefer'),
#    rdflib.term.Literal('use document')),
#   (rdflib.term.Literal('Tana'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('company'))],
#  15008: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('authorization')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('database'))],
#  15009: [(rdflib.term.Literal('He'),
#    rdflib.term.Literal('return'),
#    rdflib.term.Literal('work'))],
#  15010: [(rdflib.term.Literal('Dupont'),
#    rdflib.term.Literal('go'),
#    rdflib.term.Literal('call'))],
#  15012: [(rdflib.term.Literal('angela.davis@enron.com'),
#    rdflib.term.Literal('redact'),
#    rdflib.term.Literal('copy'))],
#  15015: [(rdflib.term.Literal('amber.ebow@enron.com'),
#    rdflib.term.Literal('confirm'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('amber.ebow@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('spreadsheet'))],
#  15016: [(rdflib.term.Literal('stephanie.sever@enron.com'),
#    rdflib.term.Literal('inactivate'),
#    rdflib.term.Literal('counterparty'))],
#  15018: [(rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('B')),
#   (rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('confirm')),
#   (rdflib.term.Literal('we'),
#    rdflib.term.Literal('reference'),
#    rdflib.term.Literal('deal number')),
#   (rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('miss'),
#    rdflib.term.Literal('part'))],
#  15019: [(rdflib.term.Literal('sheri.luong@enron.com'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('model')),
#   (rdflib.term.Literal('I'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('agreement'))],
#  15022: [(rdflib.term.Literal('patrick.mulvany@enron.com'),
#    rdflib.term.Literal('follow'),
#    rdflib.term.Literal('trade'))],
#  15026: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('consultant'))],
#  15028: [(rdflib.term.Literal('leslie.hansen@enron.com'),
#    rdflib.term.Literal('trade'),
#    rdflib.term.Literal('power')),
#   (rdflib.term.Literal('leslie.hansen@enron.com'),
#    rdflib.term.Literal('trade'),
#    rdflib.term.Literal('East')),
#   (rdflib.term.Literal('leslie.hansen@enron.com'),
#    rdflib.term.Literal('trade'),
#    rdflib.term.Literal('agreement'))],
#  15030: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('assignment'))],
#  15032: [(rdflib.term.Literal('Marketing'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('Enron')),
#   (rdflib.term.Literal('Marketing'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('letter')),
#   (rdflib.term.Literal('tom.moran@enron.com'),
#    rdflib.term.Literal('open'),
#    rdflib.term.Literal('access')),
#   (rdflib.term.Literal('tom.moran@enron.com'),
#    rdflib.term.Literal('enter'),
#    rdflib.term.Literal('calendar month')),
#   (rdflib.term.Literal('tom.moran@enron.com'),
#    rdflib.term.Literal('enter'),
#    rdflib.term.Literal('calendar month')),
#   (rdflib.term.Literal('tom.moran@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('credit change'))],
#  15033: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15036: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Amendment'))],
#  15037: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('contract number'))],
#  15046: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('kim.detiveaux@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('address')),
#   (rdflib.term.Literal('kim.detiveaux@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('item'))],
#  15047: [(rdflib.term.Literal('marc.eichmann@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('document'))],
#  15054: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15057: [(rdflib.term.Literal('susan.bailey@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15058: [(rdflib.term.Literal('BASF'),
#    rdflib.term.Literal('show'),
#    rdflib.term.Literal('reviewing'))],
#  15061: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15062: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('contract number'))],
#  15073: [(rdflib.term.Literal('Lebrocq'),
#    rdflib.term.Literal('approve'),
#    rdflib.term.Literal('copy profile'))],
#  15075: [(rdflib.term.Literal('craig.chaney@enron.com'),
#    rdflib.term.Literal('follow'),
#    rdflib.term.Literal('procedure'))],
#  15080: [(rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('call')),
#   (rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('assignment agreement')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('give'),
#    rdflib.term.Literal('call')),
#   (rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('listen'),
#    rdflib.term.Literal('messege'))],
#  15082: [(rdflib.term.Literal('Companies'),
#    rdflib.term.Literal('execute'),
#    rdflib.term.Literal('power trade'))],
#  15083: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Amendment'))],
#  15084: [(rdflib.term.Literal('Ryder'),
#    rdflib.term.Literal('put'),
#    rdflib.term.Literal('deal')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('issue')),
#   (rdflib.term.Literal('patrick.mulvany@enron.com'),
#    rdflib.term.Literal('change'),
#    rdflib.term.Literal('status'))],
#  15092: [(rdflib.term.Literal('annette.rosario@db.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('c'))],
#  15094: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('problem'))],
#  15095: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('chance'))],
#  15098: [(rdflib.term.Literal('geordie_hochbaum@transalta.com'),
#    rdflib.term.Literal('follow'),
#    rdflib.term.Literal('issue')),
#   (rdflib.term.Literal('TransAlta'),
#    rdflib.term.Literal('sleeve'),
#    rdflib.term.Literal('deal'))],
#  15100: [(rdflib.term.Literal('kabarrie@hotmail.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('issue')),
#   (rdflib.term.Literal('kabarrie@hotmail.com'),
#    rdflib.term.Literal('return'),
#    rdflib.term.Literal('favor'))],
#  15102: [(rdflib.term.Literal('bob.shults@enron.com'),
#    rdflib.term.Literal('copy'),
#    rdflib.term.Literal('guy'))],
#  15107: [(rdflib.term.Literal('greeniem@houston.rr.com'),
#    rdflib.term.Literal('advise'),
#    rdflib.term.Literal('Tana')),
#   (rdflib.term.Literal('greeniem@houston.rr.com'),
#    rdflib.term.Literal('advise'),
#    rdflib.term.Literal('initial document'))],
#  15112: [(rdflib.term.Literal('Tana'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('NDA'))],
#  15120: [(rdflib.term.Literal('sheetal.patel@enron.com'),
#    rdflib.term.Literal('complete'),
#    rdflib.term.Literal('transaction'))],
#  15121: [(rdflib.term.Literal('Robert'),
#    rdflib.term.Literal('approve'),
#    rdflib.term.Literal('Description')),
#   (rdflib.term.Literal('Transaction'),
#    rdflib.term.Literal('purchase'),
#    rdflib.term.Literal('quantity'))],
#  15126: [(rdflib.term.Literal('hkjii@erols.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('Emails'))],
#  15128: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('modify'),
#    rdflib.term.Literal('EnronOnline'))],
#  15129: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15130: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('modification')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('document')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('understand'),
#    rdflib.term.Literal('business purpose')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('make document')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('implement'),
#    rdflib.term.Literal('language'))],
#  15131: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15133: [(rdflib.term.Literal('Mark'),
#    rdflib.term.Literal('request'),
#    rdflib.term.Literal('change')),
#   (rdflib.term.Literal('Gulf'),
#    rdflib.term.Literal('request'),
#    rdflib.term.Literal('change'))],
#  15134: [(rdflib.term.Literal('marc.eichmann@enron.com'),
#    rdflib.term.Literal('agree'),
#    rdflib.term.Literal('text')),
#   (rdflib.term.Literal('marc.eichmann@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('release datum')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('this'),
#    rdflib.term.Literal('free'),
#    rdflib.term.Literal('cash'))],
#  15135: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('matter'))],
#  15137: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('contract number'))],
#  15138: [(rdflib.term.Literal('KY'),
#    rdflib.term.Literal('re'),
#    rdflib.term.Literal('transaction'))],
#  15143: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('chance'))],
#  15146: [(rdflib.term.Literal('Bradford'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('behalf'))],
#  15154: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('expect'),
#    rdflib.term.Literal('receive document'))],
#  15155: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('wait'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('set'),
#    rdflib.term.Literal('contract number'))],
#  15158: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('one'))],
#  15161: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('copy')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought'))],
#  15171: [(rdflib.term.Literal('BP'),
#    rdflib.term.Literal('execute'),
#    rdflib.term.Literal('amendment')),
#   (rdflib.term.Literal('sharon.crawford@enron.com'),
#    rdflib.term.Literal('go'),
#    rdflib.term.Literal('fax guarantee'))],
#  15173: [(rdflib.term.Literal('stacy.fitzgerald@enron.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('file'))],
#  15174: [(rdflib.term.Literal('john.allario@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('NDA')),
#   (rdflib.term.Literal('john.allario@enron.com'),
#    rdflib.term.Literal('target'),
#    rdflib.term.Literal('company'))],
#  15175: [(rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('termination letter')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('original'))],
#  15177: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('copy'))],
#  15190: [(rdflib.term.Literal('tara.sweitzer@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('call')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('give'),
#    rdflib.term.Literal('call'))],
#  15191: [(rdflib.term.Literal('john.allario@enron.com'),
#    rdflib.term.Literal('enjoy'),
#    rdflib.term.Literal('year'))],
#  15193: [(rdflib.term.Literal('patrick.mulvany@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('deal'))],
#  15195: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('office')),
#   (rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('appointment')),
#   (rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('office')),
#   (rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('time')),
#   (rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('travel'),
#    rdflib.term.Literal('funeral'))],
#  15196: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('list')),
#   (rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('own'),
#    rdflib.term.Literal('%'))],
#  15198: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('agreement'))],
#  15200: [(rdflib.term.Literal('Johnston'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('list'))],
#  15201: [(rdflib.term.Literal('legal <.taylor@enron.com>'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('have lot'))],
#  15202: [(rdflib.term.Literal('greg.johnston@enron.com'),
#    rdflib.term.Literal('delete'),
#    rdflib.term.Literal('reference'))],
#  15204: [(rdflib.term.Literal('morris.clark@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('form'))],
#  15206: [(rdflib.term.Literal('susan.bailey@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15207: [(rdflib.term.Literal('Jay'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('name'))],
#  15209: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('contract number'))],
#  15210: [(rdflib.term.Literal('georgi.landau@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('contract number'))],
#  15211: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('copy'))],
#  15212: [(rdflib.term.Literal('credit <.williams@enron.com>'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('name')),
#   (rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('pull contract'))],
#  15214: [(rdflib.term.Literal('Tana'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('comment'))],
#  15215: [(rdflib.term.Literal('akurzer@tfsbrokers.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('BETA'))],
#  15219: [(rdflib.term.Literal('carol.st.@enron.com'),
#    rdflib.term.Literal('approach'),
#    rdflib.term.Literal('group'))],
#  15225: [(rdflib.term.Literal('trader'),
#    rdflib.term.Literal('govern'),
#    rdflib.term.Literal('trade'))],
#  15226: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('check'),
#    rdflib.term.Literal('file'))],
#  15229: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('circulate'),
#    rdflib.term.Literal('list'))],
#  15231: [(rdflib.term.Literal('rick.antonoff@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('call'))],
#  15234: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15237: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('prepare'),
#    rdflib.term.Literal('letter agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('prepare'),
#    rdflib.term.Literal('form')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought'))],
#  15238: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('party'))],
#  15239: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15240: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('form'))],
#  15243: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('one'))],
#  15245: [(rdflib.term.Literal('Elaine'),
#    rdflib.term.Literal('respond'),
#    rdflib.term.Literal('question')),
#   (rdflib.term.Literal('elaine.overturf@enron.com'),
#    rdflib.term.Literal('respond'),
#    rdflib.term.Literal('question'))],
#  15250: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('change'),
#    rdflib.term.Literal('mind'))],
#  15251: [(rdflib.term.Literal('Exchange'),
#    rdflib.term.Literal('charge'),
#    rdflib.term.Literal('transaction')),
#   (rdflib.term.Literal('Exchange'),
#    rdflib.term.Literal('attempt'),
#    rdflib.term.Literal('make statement'))],
#  15252: [(rdflib.term.Literal('travis.mccullough@enron.com'),
#    rdflib.term.Literal('try'),
#    rdflib.term.Literal('locate file'))],
#  15253: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement')),
#   (rdflib.term.Literal('Agreement'),
#    rdflib.term.Literal('amend'),
#    rdflib.term.Literal('notice provision'))],
#  15255: [(rdflib.term.Literal('NDA'),
#    rdflib.term.Literal('cover'),
#    rdflib.term.Literal('matter')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('call'),
#    rdflib.term.Literal('Bonner')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('outline'),
#    rdflib.term.Literal('work')),
#   (rdflib.term.Literal('SunGard'),
#    rdflib.term.Literal('perform'),
#    rdflib.term.Literal('onset')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('go'),
#    rdflib.term.Literal('day'))],
#  15256: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('correction'))],
#  15259: [(rdflib.term.Literal('jeannine.ford@experian.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('change')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('incorporate'),
#    rdflib.term.Literal('portion')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('original'))],
#  15262: [(rdflib.term.Literal("you'all"),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('time')),
#   (rdflib.term.Literal('becky.spencer@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('copy'))],
#  15263: [(rdflib.term.Literal('deb.korkmas@enron.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('copy'))],
#  15264: [(rdflib.term.Literal('Allario'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('comment')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('agree'),
#    rdflib.term.Literal('revision')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('state'),
#    rdflib.term.Literal('Project')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('incorporate'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('incorporate'),
#    rdflib.term.Literal('comment'))],
#  15267: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('change'))],
#  15268: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('include'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('distribute'),
#    rdflib.term.Literal('process memo'))],
#  15269: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('update')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('original')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('address'))],
#  15270: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('NDA')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('comment')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('event')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('version'))],
#  15271: [(rdflib.term.Literal('Cheryl'),
#    rdflib.term.Literal('feel'),
#    rdflib.term.Literal('weather')),
#   (rdflib.term.Literal('kayla.heitmeyer@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('assistance'))],
#  15276: [(rdflib.term.Literal('x37541'),
#    rdflib.term.Literal('thank'),
#    rdflib.term.Literal('assistance'))],
#  15277: [(rdflib.term.Literal('ross.mesquita@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('get draft')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('email'),
#    rdflib.term.Literal('nda')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('email'),
#    rdflib.term.Literal('company')),
#   (rdflib.term.Literal('ross.mesquita@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('take approach')),
#   (rdflib.term.Literal('ross.mesquita@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('info')),
#   (rdflib.term.Literal('ross.mesquita@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('stage')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('information'))],
#  15278: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('extraction'))],
#  15279: [(rdflib.term.Literal('sheri.luong@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('homepage')),
#   (rdflib.term.Literal('l..denton@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('one')),
#   (rdflib.term.Literal('l..denton@enron.com'),
#    rdflib.term.Literal('consider'),
#    rdflib.term.Literal('disclaimer'))],
#  15282: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement')),
#   (rdflib.term.Literal('Bank'),
#    rdflib.term.Literal('succeed'),
#    rdflib.term.Literal('right'))],
#  15283: [(rdflib.term.Literal('NDA'),
#    rdflib.term.Literal('relate'),
#    rdflib.term.Literal('sale')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('NDA'))],
#  15284: [(rdflib.term.Literal('WATERWAYS'),
#    rdflib.term.Literal('return'),
#    rdflib.term.Literal('route')),
#   (rdflib.term.Literal('WATERWAYS'),
#    rdflib.term.Literal('return'),
#    rdflib.term.Literal('operation'))],
#  15292: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('address'),
#    rdflib.term.Literal('time'))],
#  15293: [(rdflib.term.Literal('rick.antonoff@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('counterparty contact')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('gather'),
#    rdflib.term.Literal('fact'))],
#  15294: [(rdflib.term.Literal('rick.antonoff@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('morning')),
#   (rdflib.term.Literal('Gray'),
#    rdflib.term.Literal('coordinate'),
#    rdflib.term.Literal('release')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('execute'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('agreement'))],
#  15295: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought'))],
#  15296: [(rdflib.term.Literal('carol.st.@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('copy')),
#   (rdflib.term.Literal('carol.st.@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('default notice'))],
#  15297: [(rdflib.term.Literal('lance.jameson@enron.com'),
#    rdflib.term.Literal('let'),
#    rdflib.term.Literal('bit'))],
#  15299: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('remove'),
#    rdflib.term.Literal('Brewer')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('remove'),
#    rdflib.term.Literal('list'))],
#  15305: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('finalize'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('execution original')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('attention'))],
#  15306: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('chance'))],
#  15309: [(rdflib.term.Literal('steve.van@enron.com'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('draft')),
#   (rdflib.term.Literal('change'),
#    rdflib.term.Literal('reinsert'),
#    rdflib.term.Literal('schedule c'))],
#  15310: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('contact'),
#    rdflib.term.Literal('counterpartie'))],
#  15313: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('am'),
#    rdflib.term.Literal('sorry'))],
#  15314: [(rdflib.term.Literal('Marcus'),
#    rdflib.term.Literal('proceed'),
#    rdflib.term.Literal('document')),
#   (rdflib.term.Literal('Korkmas'),
#    rdflib.term.Literal('pursue'),
#    rdflib.term.Literal('obtaining')),
#   (rdflib.term.Literal('steve.van@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('answer'))],
#  15316: [(rdflib.term.Literal('steve.van@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('review')),
#   (rdflib.term.Literal('t..hodge@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('chance'))],
#  15317: [(rdflib.term.Literal('steve.van@enron.com'),
#    rdflib.term.Literal('revise'),
#    rdflib.term.Literal('input')),
#   (rdflib.term.Literal('Jeff'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('sample'))],
#  15318: [(rdflib.term.Literal('keegan.farrell@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('phone number'))],
#  15320: [(rdflib.term.Literal('Bob'),
#    rdflib.term.Literal('ask'),
#    rdflib.term.Literal('forward amendment')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('consider'),
#    rdflib.term.Literal('access'))],
#  15321: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('see draft'))],
#  15325: [(rdflib.term.Literal('c..koehler@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('change'))],
#  15326: [(rdflib.term.Literal('peter.keohane@enron.com'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('Agreement')),
#   (rdflib.term.Literal('peter.keohane@enron.com'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('eye')),
#   (rdflib.term.Literal('somebody'),
#    rdflib.term.Literal('go'),
#    rdflib.term.Literal('provide list'))],
#  15327: [(rdflib.term.Literal('c..koehler@enron.com'),
#    rdflib.term.Literal('draft'),
#    rdflib.term.Literal('paragraph'))],
#  15331: [(rdflib.term.Literal('steve.van@enron.com'),
#    rdflib.term.Literal('appreciate'),
#    rdflib.term.Literal('hear thought'))],
#  15332: [(rdflib.term.Literal('counterparty'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('guarantee'))],
#  15333: [(rdflib.term.Literal('susan.bailey@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('difficulty')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('lunch meeting'))],
#  15334: [(rdflib.term.Literal('t..hodge@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('problem'))],
#  15336: [(rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('arrive'),
#    rdflib.term.Literal('package'))],
#  15337: [(rdflib.term.Literal('r..brackett@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('answer question'))],
#  15338: [(rdflib.term.Literal('becky.spencer@enron.com'),
#    rdflib.term.Literal('help'),
#    rdflib.term.Literal('work table'))],
#  15340: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('list'))],
#  15344: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('company')),
#   (rdflib.term.Literal('kevin.montagne@enron.com'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('side')),
#   (rdflib.term.Literal('kevin.montagne@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('resurrect agreement')),
#   (rdflib.term.Literal('kevin.montagne@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('care'))],
#  15348: [(rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('enter'),
#    rdflib.term.Literal('ISDA')),
#   (rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('enter'),
#    rdflib.term.Literal('database')),
#   (rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('include'),
#    rdflib.term.Literal('example')),
#   (rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('include'),
#    rdflib.term.Literal('provision'))],
#  15356: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('plan'),
#    rdflib.term.Literal('address request'))],
#  15357: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('talk'),
#    rdflib.term.Literal('group'))],
#  15358: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('email')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('monitor'),
#    rdflib.term.Literal('progress')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('purchase'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Number')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('order'),
#    rdflib.term.Literal('item'))],
#  15359: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('ask'),
#    rdflib.term.Literal('attorney')),
#   (rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('ask'),
#    rdflib.term.Literal('forward draft')),
#   (rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('copy')),
#   (rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('state'))],
#  15360: [(rdflib.term.Literal('Lech'),
#    rdflib.term.Literal('prepare'),
#    rdflib.term.Literal('statement filing'))],
#  15367: [(rdflib.term.Literal('Heard'),
#    rdflib.term.Literal('deliver'),
#    rdflib.term.Literal('draft'))],
#  15372: [(rdflib.term.Literal('alan.aronowitz@enron.com'),
#    rdflib.term.Literal('act'),
#    rdflib.term.Literal('resource')),
#   (rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('list'))],
#  15374: [(rdflib.term.Literal('anyone'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('file'))],
#  15377: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('change')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('put'),
#    rdflib.term.Literal('user note')),
#   (rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('put'),
#    rdflib.term.Literal('document'))],
#  15379: [(rdflib.term.Literal('Peter'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('morning')),
#   (rdflib.term.Literal('you'),
#    rdflib.term.Literal('show'),
#    rdflib.term.Literal('desk')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('error'))],
#  15382: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('error'))],
#  15383: [(rdflib.term.Literal('Peyer'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('email address'))],
#  15386: [(rdflib.term.Literal('This'),
#    rdflib.term.Literal('elevate'),
#    rdflib.term.Literal('default')),
#   (rdflib.term.Literal('athena.alexander@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('kill limitation')),
#   (rdflib.term.Literal('athena.alexander@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('language')),
#   (rdflib.term.Literal('athena.alexander@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('doc'))],
#  15387: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15398: [(rdflib.term.Literal('holly.keiser@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('book'))],
#  15400: [(rdflib.term.Literal('chinn@millercanfield.com'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('document'))],
#  15409: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15410: [(rdflib.term.Literal('Joanne'),
#    rdflib.term.Literal('prepare'),
#    rdflib.term.Literal('file')),
#   (rdflib.term.Literal('Joanne'),
#    rdflib.term.Literal('prepare'),
#    rdflib.term.Literal('copy'))],
#  15413: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('confidentiality agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('track')),
#   (rdflib.term.Literal('ross.mesquita@enron.com'),
#    rdflib.term.Literal('request'),
#    rdflib.term.Literal('letter'))],
#  15414: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('finalize'),
#    rdflib.term.Literal('letter')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('original'))],
#  15416: [(rdflib.term.Literal('date'),
#    rdflib.term.Literal('own'),
#    rdflib.term.Literal('seat')),
#   (rdflib.term.Literal('members'),
#    rdflib.term.Literal('lease'),
#    rdflib.term.Literal('seat')),
#   (rdflib.term.Literal('who'),
#    rdflib.term.Literal('clear'),
#    rdflib.term.Literal('firm trade')),
#   (rdflib.term.Literal('who'),
#    rdflib.term.Literal('execute'),
#    rdflib.term.Literal('trade'))],
#  15419: [(rdflib.term.Literal('lisa.scully@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('name')),
#   (rdflib.term.Literal('I'),
#    rdflib.term.Literal('develop'),
#    rdflib.term.Literal('database')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('approve'),
#    rdflib.term.Literal('access')),
#   (rdflib.term.Literal('Clark'),
#    rdflib.term.Literal('request'),
#    rdflib.term.Literal('access'))],
#  15420: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('error'))],
#  15421: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('assist'),
#    rdflib.term.Literal('status'))],
#  15422: [(rdflib.term.Literal('susan.bailey@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('assistance'))],
#  15423: [(rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('hold'),
#    rdflib.term.Literal('discussion')),
#   (rdflib.term.Literal('NYSE'),
#    rdflib.term.Literal('suspend'),
#    rdflib.term.Literal('trading')),
#   (rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('share'),
#    rdflib.term.Literal('time'))],
#  15427: [(rdflib.term.Literal('susan.bailey@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('pm')),
#   (rdflib.term.Literal('susan.bailey@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('morning'))],
#  15428: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('provision')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought'))],
#  15430: [(rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('pricing')),
#   (rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('comment')),
#   (rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('phone')),
#   (rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('letter')),
#   (rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('establish'),
#    rdflib.term.Literal('rapport'))],
#  15432: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('copy')),
#   (rdflib.term.Literal('Agreement'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('attention')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('communication')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('error'))],
#  15433: [(rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('release'),
#    rdflib.term.Literal('information'))],
#  15436: [(rdflib.term.Literal('craigvasquezjones@hotmail.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('arrival time'))],
#  15437: [(rdflib.term.Literal('User'),
#    rdflib.term.Literal('read'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('portal')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('log'),
#    rdflib.term.Literal('portal')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('log'),
#    rdflib.term.Literal('password')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('portal')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('past')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('click'),
#    rdflib.term.Literal('logout link')),
#   (rdflib.term.Literal('renee.alfaro@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('provide feedback'))],
#  15439: [(rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('put'),
#    rdflib.term.Literal('database isda')),
#   (rdflib.term.Literal('anna.fox@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('one'))],
#  15441: [(rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('point'))],
#  15443: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('form')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('retain'),
#    rdflib.term.Literal('concept')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('retain'),
#    rdflib.term.Literal('term')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('retain'),
#    rdflib.term.Literal('termination')),
#   (rdflib.term.Literal('Williams'),
#    rdflib.term.Literal('evaluate'),
#    rdflib.term.Literal('product')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('reach'),
#    rdflib.term.Literal('resolution'))],
#  15445: [(rdflib.term.Literal('legal <.taylor@enron.com>'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('change'))],
#  15448: [(rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('Program')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('take vacation'))],
#  15450: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('draft')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('product description')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('finalize'),
#    rdflib.term.Literal('LOI'))],
#  15452: [(rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('announce'),
#    rdflib.term.Literal('plan'))],
#  15453: [(rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('stay'),
#    rdflib.term.Literal('touch'))],
#  15456: [(rdflib.term.Literal('us'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('letter'))],
#  15457: [(rdflib.term.Literal('rep'),
#    rdflib.term.Literal('help'),
#    rdflib.term.Literal('cadwalader')),
#   (rdflib.term.Literal('rep'),
#    rdflib.term.Literal('help'),
#    rdflib.term.Literal('process'))],
#  15459: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15460: [(rdflib.term.Literal('marie.heard@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('Agreement'))],
#  15461: [(rdflib.term.Literal('Caminus'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('reference')),
#   (rdflib.term.Literal('john.allario@enron.com'),
#    rdflib.term.Literal('accommodate'),
#    rdflib.term.Literal('wish'))],
#  15462: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('matter')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('thought'))],
#  15463: [(rdflib.term.Literal('Haedicke'),
#    rdflib.term.Literal('hold'),
#    rdflib.term.Literal('floor meeting')),
#   (rdflib.term.Literal('Haedicke'),
#    rdflib.term.Literal('hold'),
#    rdflib.term.Literal('p.m.'))],
#  15466: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('agreement')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('initial letter')),
#   (rdflib.term.Literal('lorie.hernandez@enron.com'),
#    rdflib.term.Literal('attach'),
#    rdflib.term.Literal('description item'))],
#  15471: [(rdflib.term.Literal('mark.greenberg@enron.com'),
#    rdflib.term.Literal('delete'),
#    rdflib.term.Literal('Paragraph'))],
#  15473: [(rdflib.term.Literal('mary.cook@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('provision'))],
#  15474: [(rdflib.term.Literal('sarah.dietrich@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('annex template')),
#   (rdflib.term.Literal('Marie'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('template')),
#   (rdflib.term.Literal('sarah.dietrich@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('template'))],
#  15478: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15480: [(rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('assignment')),
#   (rdflib.term.Literal('Reed'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('update')),
#   (rdflib.term.Literal('tana.jones@enron.com'),
#    rdflib.term.Literal('give'),
#    rdflib.term.Literal('ring'))],
#  15481: [(rdflib.term.Literal('stephanie.panus@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('master agreement'))],
#  15482: [(rdflib.term.Literal('samantha.boyd@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('documentation'))],
#  15485: [(rdflib.term.Literal('diane.anderson@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('request'))],
#  15487: [(rdflib.term.Literal('Sales'),
#    rdflib.term.Literal('trade'),
#    rdflib.term.Literal('lpg')),
#   (rdflib.term.Literal('someone'),
#    rdflib.term.Literal('call'),
#    rdflib.term.Literal('Redd')),
#   (rdflib.term.Literal('someone'),
#    rdflib.term.Literal('call'),
#    rdflib.term.Literal('start process'))],
#  15488: [(rdflib.term.Literal('holly.keiser@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('exception time'))],
#  15491: [(rdflib.term.Literal('amber.ebow@enron.com'),
#    rdflib.term.Literal('wait'),
#    rdflib.term.Literal('confirmation')),
#   (rdflib.term.Literal('amber.ebow@enron.com'),
#    rdflib.term.Literal('verify'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('amber.ebow@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('amendment'))],
#  15492: [(rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('give'),
#    rdflib.term.Literal('lot')),
#   (rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('give'),
#    rdflib.term.Literal('day')),
#   (rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('part')),
#   (rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('foundation')),
#   (rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('waive'),
#    rdflib.term.Literal('right')),
#   (rdflib.term.Literal('chairman.ken@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('payment'))],
#  15496: [(rdflib.term.Literal('Stephanie'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('Notes'))],
#  15497: [(rdflib.term.Literal('keegan.farrell@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('call')),
#   (rdflib.term.Literal('kayla.heitmeyer@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('assistance'))],
#  15498: [(rdflib.term.Literal('Haedicke'),
#    rdflib.term.Literal('office'),
#    rdflib.term.Literal('building'))],
#  15499: [(rdflib.term.Literal('Global'),
#    rdflib.term.Literal('address'),
#    rdflib.term.Literal('meeting')),
#   (rdflib.term.Literal('karen.lambert@enron.com'),
#    rdflib.term.Literal('meet'),
#    rdflib.term.Literal('a.m.'))]}

# %%
def query_relationships(predicate, g, msg_key_idx, msg_key_idx_reverse):
    doc = nlp(predicate)
    p = Literal(doc[0].lemma_)
    qres = g.query('SELECT ?s ?o WHERE { ?s ?p ?o . }', initBindings = {'p' : p})

    for row in qres:
        r = (row[0], p, row[1])
        print("%s\t*%s*\t%s -- msg_keys: %s" % (row[0], p, row[1], msg_key_idx[r]))

# %%
def create_graph_from_email_relationships(mbox):
    g = Graph('Sleepycat', identifier='enron_relationships') # needs python lib bsddb3
    #installing bsddb3 has issues
    g.open('enron_relationships.rdf', create = True)
    msg_key_idx = {}
    msg_key_idx_reverse = {}
    
    i = 0
    msgs = mbox.keys()
    msg_count = len(msgs)
    for msg_key in msgs: # no limit now, do all messages
        i += 1
        if i % 10000 == 0:
            print("Message %d of %d" % (i, msg_count))
    
        # find relationships
        rels = extract_email_relationships(mbox, msg_key)
        
        # for each relationship
        for (s, p, o) in rels:
            
            r = (Literal(s), Literal(p), Literal(o))
            
            # add relationship to the graph
            g.add(r)
            
            # remember which message(s) had this relationship
            if r in msg_key_idx:
                msg_key_idx[r].append(msg_key)
            else:
                msg_key_idx[r] = [msg_key]
                
            # remember the relationships this message had
            if msg_key in msg_key_idx_reverse:
                msg_key_idx_reverse[msg_key].append(r)
            else:
                msg_key_idx_reverse[msg_key] = [r]
                
    return (g, msg_key_idx, msg_key_idx_reverse)

(g, msg_key_idx, msg_key_idx_reverse) = create_graph_from_email_relationships(mbox)

query_relationships("removed", g, msg_key_idx, msg_key_idx_reverse)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-c52a2bd34a49> in <module>
#      39     return (g, msg_key_idx, msg_key_idx_reverse)
#      40
# ---> 41 (g, msg_key_idx, msg_key_idx_reverse) = create_graph_from_email_relationships(mbox)
#      42
#      43 query_relationships("removed", g, msg_key_idx, msg_key_idx_reverse)
#
# <ipython-input-45-c52a2bd34a49> in create_graph_from_email_relationships(mbox)
#       1 def create_graph_from_email_relationships(mbox):
# ----> 2     g = Graph('Sleepycat', identifier='enron_relationships') # needs python lib bsddb3
#       3     #installing bsddb3 has issues
#       4     g.open('enron_relationships.rdf', create = True)
#       5     msg_key_idx = {}
#
# C:\Anaconda3\lib\site-packages\rdflib\graph.py in __init__(self, store, identifier, namespace_manager, base)
#     304         if not isinstance(store, Store):
#     305             # TODO: error handling
# --> 306             self.__store = store = plugin.get(store, Store)()
#     307         else:
#     308             self.__store = store
#
# C:\Anaconda3\lib\site-packages\rdflib\plugins\sleepycat.py in __init__(self, configuration, identifier)
#      51         if not has_bsddb:
#      52             raise ImportError(
# ---> 53                 "Unable to import bsddb/bsddb3, store is unusable.")
#      54         self.__open = False
#      55         self.__identifier = identifier
#
# ImportError: Unable to import bsddb/bsddb3, store is unusable.
