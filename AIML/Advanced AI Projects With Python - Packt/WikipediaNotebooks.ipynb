# %%
import wikipedia

# %%
ny = wikipedia.page("New York City")

# %%
ny.content[:1000]
# Out:
# "New York City, often called simply New York and abbreviated as NYC, is the most populous city in the United States. With an estimated 2019 population of 8,336,817 distributed over about 302.6 square miles (784 km2), New York City is also the most densely populated major city in the United States. Located at the southern tip of the U.S. state of New York, the city is the center of the New York metropolitan area, the largest metropolitan area in the world by urban landmass. With almost 20 million people in its metropolitan statistical area and approximately 23 million in its combined statistical area, it is one of the world's most populous megacities. New York City has been described as the cultural, financial, and media capital of the world, significantly influencing commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports. Home to the headquarters of the United Nations, New York is an important center for international diplomacy.Situated on "

# %%
import spacy

# %%
nlp = spacy.load('en')

# %%
nynlp = nlp(ny.content[:10000])

# %%
for chunk in nynlp.noun_chunks:
    print(chunk.text,chunk.root.text,chunk.root.dep_,chunk.root.head.text, sep = " / ")
# Out:
# New York City / City / nsubj / called
# NYC / NYC / pobj / as
# the most populous city / city / attr / is
# the United States / States / pobj / in
# an estimated 2019 population / population / nsubj / distributed
# about 302.6 square miles / miles / pobj / over
# 784 km2 / km2 / appos / miles
# New York City / City / nsubj / is
# the most densely populated major city / city / attr / is
# the United States / States / pobj / in
# the southern tip / tip / pobj / at
# the U.S. state / state / pobj / of
# New York / York / pobj / of
# the city / city / nsubj / is
# the center / center / attr / is
# the New York metropolitan area / area / pobj / of
# the largest metropolitan area / area / appos / center
# the world / world / pobj / in
# urban landmass / landmass / pobj / by
# almost 20 million people / people / pobj / With
# its metropolitan statistical area / area / pobj / in
# its combined statistical area / area / pobj / in
# it / it / nsubj / is
# the world's most populous megacities / megacities / pobj / of
# New York City / City / nsubjpass / described
# the cultural, financial, and media capital / capital / pobj / as
# the world / world / pobj / of
# commerce / commerce / dobj / influencing
# entertainment / entertainment / conj / commerce
# research / research / conj / entertainment
# technology / technology / conj / research
# education / education / conj / technology
# politics / politics / conj / education
# tourism / tourism / conj / politics
# art / art / conj / tourism
# fashion / fashion / conj / art
# sports / sports / conj / fashion
# the headquarters / headquarters / pobj / to
# the United Nations / Nations / pobj / of
# New York / York / nsubj / is
# an important center / center / attr / is
# international diplomacy / diplomacy / pobj / for
# the world's largest natural harbors / harbors / pobj / of
# New York City / City / nsubjpass / composed
# five boroughs / boroughs / pobj / of
# a county / county / attr / is
# the State / State / pobj / of
# New York / York / pobj / of
# The five boroughs / boroughs / nsubjpass / consolidated
# Brooklyn / Brooklyn / appos / boroughs
# Queens / Queens / conj / Brooklyn
# Manhattan / Manhattan / conj / Queens
# the Bronx / Bronx / conj / Manhattan
# Staten Island / Island / conj / Bronx
# a single city / city / pobj / into
# The city / city / nsubj / constitute
# its metropolitan area / area / conj / city
# the premier / premier / dobj / constitute
# gateway / gateway / dobj / constitute
# legal immigration / immigration / pobj / for
# the United States / States / pobj / to
# As many as 800 languages / languages / nsubjpass / spoken
# New York / York / pobj / in
# it / it / nsubj / city
# the world / world / pobj / in
# New York / York / nsubj / is
# home / home / attr / is
# more than 3.2 million residents / residents / pobj / to
# the United States / States / pobj / outside
# the largest foreign-born population / population / appos / residents
# any city / city / pobj / of
# the world / world / pobj / in
# the New York metropolitan area / area / nsubjpass / estimated
# a gross metropolitan product / product / dobj / produce
# (GMP / GMP / appos / product
# the New York metropolitan area / area / nsubj / were
# a sovereign state / state / attr / were
# it / it / nsubj / have
# the eighth-largest economy / economy / dobj / have
# the world / world / pobj / in
# New York / York / nsubj / is
# home / home / attr / is
# the highest number / number / pobj / to
# billionaires / billionaires / pobj / of
# any city / city / pobj / of
# the world / world / pobj / in
# New York City / City / nsubj / traces
# its origins / origins / dobj / traces
# a trading post / post / pobj / to
# colonists / colonists / pobj / by
# the Dutch Republic / Republic / pobj / from
# Lower Manhattan / Manhattan / pobj / on
# the post / post / nsubjpass / named
# The city / city / nsubj / came
# its surroundings / surroundings / conj / city
# English control / control / pobj / under
# King Charles II / II / nsubj / granted
# England / England / pobj / of
# the lands / lands / dobj / granted
# his brother / brother / pobj / to
# the Duke / Duke / appos / brother
# York / York / pobj / of
# The city / city / nsubj / was
# the capital / capital / attr / was
# the United States / States / pobj / of
# the largest U.S. city / city / attr / been
# The Statue / Statue / nsubj / greeted
# Liberty / Liberty / pobj / of
# millions / millions / dobj / greeted
# immigrants / immigrants / pobj / of
# they / they / nsubj / came
# the U.S. / U.S. / pobj / to
# ship / ship / pobj / by
# the late 19th and early 20th centuries / centuries / pobj / in
# a symbol / symbol / attr / is
# the U.S. / U.S. / pobj / of
# its ideals / ideals / conj / symbol
# liberty / liberty / pobj / of
# peace / peace / conj / liberty
# the 21st century / century / pobj / In
# New York / York / nsubj / emerged
# a global node / node / pobj / as
# creativity / creativity / pobj / of
# entrepreneurship / entrepreneurship / conj / creativity
# environmental sustainability / sustainability / conj / entrepreneurship
# a symbol / symbol / pobj / as
# freedom / freedom / pobj / of
# cultural diversity / diversity / conj / freedom
# New York / York / nsubjpass / voted
# the world / world / pobj / in
# a survey / survey / pobj / per
# over 30,000 people / people / pobj / of
# 48 cities / cities / pobj / from
# its cultural diversity / diversity / dobj / citing
# Many districts / districts / nsubjpass / known
# landmarks / landmarks / conj / districts
# New York City / City / pobj / in
# the world's ten most visited tourist attractions / attractions / pobj / of
# A record 62.8 million tourists / tourists / nsubj / visited
# New York City / City / dobj / visited
# Times Square / Square / nsubj / is
# the brightly illuminated hub / hub / attr / is
# the Broadway Theater District / District / pobj / of
# the world's busiest pedestrian intersections / intersections / pobj / of
# a major center / center / conj / one
# the world's entertainment industry / industry / pobj / of
# the city's landmarks / landmarks / pobj / of
# skyscrapers / skyscrapers / conj / landmarks
# parks / parks / conj / skyscrapers
# the world / world / pobj / around
# Manhattan's real estate market / market / nsubj / is
# the world / world / pobj / in
# New York / York / nsubj / is
# home / home / attr / is
# the largest ethnic Chinese population / population / pobj / to
# Asia / Asia / pobj / of
# multiple distinct Chinatowns / Chinatowns / pobj / with
# the city / city / pobj / across
# continuous 24/7 service / service / dobj / Providing
# the nickname / nickname / pobj / to
# The City / City / appos / nickname
# the New York City Subway / Subway / nsubj / is
# the largest single-operator rapid transit system / system / attr / is
# 472 rail stations / stations / pobj / with
# The city / city / nsubj / has
# over 120 colleges / colleges / dobj / has
# universities / universities / conj / colleges
# Columbia University / University / pobj / including
# New York University / University / conj / University
# Rockefeller University / University / conj / University
# the City University / University / conj / University
# New York system / system / pobj / of
# the largest urban public university system / system / attr / is
# the United States / States / pobj / in
# Wall Street / Street / pobj / by
# the Financial District / District / pobj / in
# Lower Manhattan / Manhattan / pobj / of
# New York City / City / nsubjpass / called
# the world / world / pobj / in
# home / home / attr / is
# the world's two largest stock exchanges / exchanges / pobj / to
# total market capitalization / capitalization / pobj / by
# the New York Stock Exchange / Exchange / conj / is
# NASDAQ / NASDAQ / conj / Exchange
# the city / city / nsubjpass / named
# honor / honor / pobj / in
# the Duke / Duke / pobj / of
# York / York / pobj / of
# who / who / nsubj / become
# King James II / II / attr / become
# England / England / pobj / of
# James's older brother / brother / nsubj / appointed
# King Charles II / II / appos / brother
# the Duke proprietor / proprietor / dobj / appointed
# the former territory / territory / pobj / of
# New Netherland / Netherland / pobj / of
# the city / city / pobj / including
# New Amsterdam / Amsterdam / pobj / of
# England / England / nsubj / seized
# it / it / dobj / seized
# the Dutch / Dutch / pobj / from
# Early history / history / ROOT / history
# the precolonial era / era / pobj / In
# the area / area / nsubjpass / inhabited
# present-day New York City / City / pobj / of
# Algonquian Native Americans / Americans / pobj / by
# the Lenape / Lenape / pobj / including
# Their homeland / homeland / nsubj / included
# Lenapehoking / Lenapehoking / pobj / as
# Staten Island / Island / dobj / included
# Manhattan / Manhattan / appos / Island
# the Bronx / Bronx / conj / Manhattan
# the western portion / portion / conj / Bronx
# Long Island / Island / pobj / of
# the areas / areas / pobj / including
# the boroughs / boroughs / attr / become
# Brooklyn / Brooklyn / pobj / of
# Queens / Queens / conj / Brooklyn
# the Lower Hudson Valley / Valley / conj / Island
# The first documented visit / visit / nsubj / was
# New York Harbor / Harbor / pobj / into
# a European / European / pobj / by
# Giovanni da Verrazzano / Verrazzano / pobj / by
# a Florentine explorer / explorer / appos / Verrazzano
# the service / service / pobj / in
# the French crown / crown / pobj / of
# He / He / nsubj / claimed
# the area / area / dobj / claimed
# France / France / pobj / for
# it / it / dobj / named
# New Angoulême / Angoulême / appos / Angoulême
# A Spanish expedition / expedition / nsubj / arrived
# the Portuguese captain Estêvão Gomes / Gomes / pobj / by
# Emperor Charles V / V / pobj / for
# New York Harbor / Harbor / pobj / in
# January / January / pobj / in
# the mouth / mouth / dobj / charted
# the Hudson River / River / pobj / of
# he / he / nsubj / named
# (Saint Anthony's River / River / ROOT / River
# The Padrón Real / Real / nsubjpass / informed
# the first scientific map / map / appos / Real
# the East Coast / Coast / dobj / show
# North America / America / pobj / of
# Gomes' expedition / expedition / pobj / by
# the northeastern United States / States / dobj / labeled
# Tierra de Esteban Gómez / Gómez / pobj / as
# his honor / honor / pobj / in
# the English explorer / explorer / nsubj / rediscovered
# Henry Hudson / Hudson / appos / explorer
# New York Harbor / Harbor / dobj / rediscovered
# the Northwest Passage / Passage / pobj / for
# the Orient / Orient / pobj / to
# the Dutch East India Company / Company / pobj / for
# He / He / nsubj / proceeded
# what / what / dobj / name
# the Dutch / Dutch / nsubj / name
# the North River / River / dobj / name
# now the Hudson River / River / appos / River
# Hudson / Hudson / pobj / by
# the Mauritius / Mauritius / pobj / as
# Maurice / Maurice / pobj / after
# Prince / Prince / appos / Maurice
# Orange / Orange / pobj / of
# Hudson's first mate / mate / nsubj / described
# the harbor / harbor / dobj / described
# a very good Harbour / Harbour / pobj / as
# all windes / windes / pobj / for
# the river / river / conj / Harbour
# fish / fish / pobj / of
# Hudson / Hudson / nsubj / sailed
# roughly 150 miles / miles / dobj / sailed
# 240 km / km / appos / miles
# the site / site / pobj / past
# the present-day New York State capital city / city / pobj / of
# Albany / Albany / pobj / of
# the belief / belief / pobj / in
# it / it / nsubj / be
# an oceanic tributary / tributary / attr / be
# the river / river / nsubj / became
# He / He / nsubj / made
# a ten-day exploration / exploration / dobj / made
# the area / area / pobj / of
# the region / region / dobj / claimed
# the Dutch East India Company / Company / pobj / for
# the area / area / nsubjpass / claimed
# Cape Cod / Cod / pobj / between
# Delaware Bay / Bay / conj / Cod
# the Netherlands / Netherlands / pobj / by
# New Netherland / Netherland / appos / Nederland
# The first non-Native American inhabitant / inhabitant / nsubj / was
# what / what / nsubj / become
# New York City / City / attr / become
# Juan Rodriguez / Rodriguez / attr / was
# Dutch / Dutch / pobj / to
# Jan Rodrigues / Rodrigues / pobj / as
# a merchant / merchant / appos / Rodriguez
# Santo Domingo / Domingo / pobj / from
# Santo Domingo / Domingo / pobj / in
# Portuguese and African descent / descent / pobj / of
# he / he / nsubj / arrived
# Manhattan / Manhattan / pobj / in
# the winter / winter / pobj / during
# pelts / pelts / pobj / for
# the local population / population / pobj / with
# a representative / representative / pobj / as
# the Dutch / Dutch / pobj / of
# Broadway / Broadway / nsubjpass / named
# 159th Street / Street / pobj / from
# Street / Street / dobj / 218th
# Upper Manhattan / Manhattan / pobj / in
# his honor / honor / pobj / in
# Dutch rule / rule / ROOT / rule
# A permanent European presence / presence / nsubj / began
# New York Harbor / Harbor / pobj / near
# 1624—making New York / York / pobj / in
# the 12th / 12th / nsubj / occupied
# European-established settlement / settlement / dobj / occupied
# the continental United States / States / pobj / in
# the founding / founding / pobj / with
# a Dutch fur trading settlement / settlement / pobj / of
# Governors Island / Island / pobj / on
# construction / construction / nsubjpass / started
# a citadel / citadel / pobj / on
# Fort Amsterdam / Amsterdam / conj / citadel
# New Amsterdam / Amsterdam / appos / Amsterdam
# present-day Manhattan Island / Island / pobj / on
# The colony / colony / nsubjpass / centered
# New Amsterdam / Amsterdam / pobj / of
# what / what / nsubjpass / known
# Lower Manhattan / Manhattan / pobj / as
# It / It / nsubj / extended
# the lower tip / tip / pobj / from
# Manhattan / Manhattan / pobj / of
# modern day / day / pobj / to
# Wall Street / Street / dobj / extended
# a 12-foot wooden stockade / stockade / nsubjpass / built
# Native American and British raids / raids / pobj / against
# the Dutch colonial Director-General Peter Minuit / Minuit / nsubj / purchased
# the Dutch West India Company / Company / pobj / by
# the island / island / dobj / purchased
# Manhattan / Manhattan / pobj / of
# the Canarsie / Canarsie / pobj / from
# a small Lenape band / band / appos / Canarsie
# the value / value / pobj / for
# 60 guilders / guilders / pobj / of
# A disproved legend / legend / nsubj / claims
# Manhattan / Manhattan / nsubjpass / purchased
# $24 worth / worth / pobj / for
# glass beads / beads / pobj / of
# the purchase / purchase / pobj / Following
# New Amsterdam / Amsterdam / nsubj / grew
# settlers / settlers / dobj / attract
# the Dutch / Dutch / nsubj / instituted
# the patroon system / system / dobj / instituted
# wealthy Dutchmen / Dutchmen / nsubjpass / awarded
# patroons / patroons / conj / Dutchmen
# patrons / patrons / conj / patroons
# who / who / nsubj / brought
# 50 colonists / colonists / dobj / brought
# New Netherland / Netherland / pobj / to
# swaths / swaths / dobj / awarded
# land / land / pobj / of
# local political autonomy / autonomy / pobj / with
# rights / rights / conj / autonomy
# the lucrative fur trade / trade / pobj / in
# This program / program / nsubj / had
# little success / success / dobj / had
# the Dutch West India Company / Company / nsubj / operated
# a monopoly / monopoly / pobj / as
# New Netherland / Netherland / pobj / in
# authority / authority / pobj / on
# the Dutch States General / General / pobj / by
# an effort / effort / pobj / in
# economic growth / growth / dobj / bolster
# the Dutch West India Company / Company / nsubj / relinquished
# its monopoly / monopoly / dobj / relinquished
# the fur trade / trade / pobj / over
# growth / growth / pobj / to
# the production / production / pobj / in
# trade / trade / conj / production
# food / food / pobj / of
# timber / timber / conj / food
# tobacco / tobacco / conj / timber
# slaves / slaves / conj / tobacco
# the Dutch West / West / pobj / with
# Indies).In / Indies).In / appos / West
# Peter Stuyvesant / Stuyvesant / nsubj / began
# his tenure / tenure / dobj / began
# the last Director-General / General / pobj / as
# New Netherland / Netherland / pobj / of
# his tenure / tenure / pobj / During
# the population / population / nsubj / grew
# New Netherland / Netherland / pobj / of
# Stuyvesant / Stuyvesant / nsubjpass / credited
# law / law / dobj / improving
# order / order / conj / law
# the colony / colony / pobj / in
# he / he / nsubj / earned
# a reputation / reputation / dobj / earned
# a despotic leader / leader / pobj / as
# He / He / nsubj / instituted
# regulations / regulations / dobj / instituted
# liquor sales / sales / pobj / on
# control / control / dobj / assert
# the Dutch Reformed Church / Church / pobj / over
# other religious groups / groups / dobj / blocked
# Quakers / Quakers / pobj / including
# Jews / Jews / conj / Quakers
# Lutherans / Lutherans / conj / Jews
# houses / houses / dobj / establishing
# worship / worship / pobj / of
# The Dutch West India Company / Company / nsubj / attempt
# tensions / tensions / dobj / ease
# Stuyvesant / Stuyvesant / pobj / between
# residents / residents / conj / Stuyvesant
# New Amsterdam / Amsterdam / pobj / of
# English rule / rule / ROOT / rule
# any significant resistance / resistance / dobj / summon
# Stuyvesant / Stuyvesant / nsubj / surrendered
# New Amsterdam / Amsterdam / dobj / surrendered
# English troops / troops / pobj / to
# Colonel Richard Nicolls / Nicolls / pobj / by
# bloodshed / bloodshed / pobj / without
# The terms / terms / nsubj / permitted
# the surrender / surrender / pobj / of
# Dutch residents / residents / dobj / permitted
# the colony / colony / pobj / in
# religious freedom / freedom / pobj / for
# The English / English / nsubj / renamed
# the fledgling city "New York / York / dobj / renamed
# the Duke / Duke / pobj / after
# York / York / pobj / of
# the future King James II / II / appos / Duke
# England / England / pobj / of

# %%
for ent in nynlp.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_,sep = " / ")
# Out:
# New York City / 0 / 13 / GPE
# New York / 35 / 43 / GPE
# NYC / 63 / 66 / ORG
# the United States / 97 / 114 / GPE
# an estimated 2019 / 121 / 138 / CARDINAL
# 8,336,817 / 153 / 162 / CARDINAL
# about 302.6 square miles / 180 / 204 / QUANTITY
# 784 km2 / 206 / 213 / MONEY
# New York City / 216 / 229 / GPE
# the United States / 279 / 296 / GPE
# U.S. / 333 / 337 / GPE
# New York / 347 / 355 / GPE
# New York / 387 / 395 / GPE
# almost 20 million / 482 / 499 / CARDINAL
# approximately 23 million / 548 / 572 / CARDINAL
# New York City / 658 / 671 / GPE
# the United Nations / 908 / 926 / ORG
# New York / 928 / 936 / GPE
# New York City / 1044 / 1057 / GPE
# five / 1073 / 1077 / CARDINAL
# the State of New York / 1117 / 1138 / GPE
# five / 1144 / 1148 / CARDINAL
# Brooklyn / 1158 / 1166 / GPE
# Queens / 1168 / 1174 / GPE
# Manhattan / 1176 / 1185 / GPE
# Bronx / 1191 / 1196 / GPE
# Staten Island / 1202 / 1215 / GPE
# 1898 / 1256 / 1260 / DATE
# the United States / 1353 / 1370 / GPE
# As many as 800 / 1372 / 1386 / CARDINAL
# New York / 1411 / 1419 / GPE
# New York / 1482 / 1490 / GPE
# more than 3.2 million / 1502 / 1523 / CARDINAL
# the United States / 1547 / 1564 / GPE
# 2016 / 1633 / 1637 / DATE
# 2019 / 1645 / 1649 / DATE
# New York / 1655 / 1663 / GPE
# GMP / 1736 / 1739 / ORG
# $2.0 trillion / 1744 / 1757 / MONEY
# New York / 1766 / 1774 / GPE
# eighth / 1835 / 1841 / ORDINAL
# New York / 1872 / 1880 / GPE
# New York City / 1952 / 1965 / GPE
# the Dutch Republic / 2029 / 2047 / GPE
# 1624 / 2051 / 2055 / DATE
# Lower Manhattan / 2059 / 2074 / ORG
# New Amsterdam / 2095 / 2108 / GPE
# 1626 / 2112 / 2116 / DATE
# English / 2159 / 2166 / NORP
# 1664 / 2178 / 2182 / DATE
# New York / 2200 / 2208 / GPE
# Charles II / 2220 / 2230 / PERSON
# England / 2234 / 2241 / GPE
# York / 2288 / 2292 / GPE
# the United States / 2322 / 2339 / GPE
# 1785 / 2345 / 2349 / DATE
# 1790 / 2356 / 2360 / DATE
# U.S. / 2387 / 2391 / GPE
# 1790 / 2403 / 2407 / DATE
# The Statue of Liberty / 2409 / 2430 / FAC
# millions / 2439 / 2447 / CARDINAL
# U.S. / 2482 / 2486 / GPE
# the late 19th and early 20th centuries / 2498 / 2536 / DATE
# U.S. / 2561 / 2565 / GPE
# the 21st century / 2606 / 2622 / DATE
# New York / 2624 / 2632 / GPE
# 2019 / 2783 / 2787 / DATE
# New York / 2789 / 2797 / GPE
# 30,000 / 2860 / 2866 / CARDINAL
# 48 / 2879 / 2881 / CARDINAL
# New York City / 2962 / 2975 / GPE
# three / 3002 / 3007 / CARDINAL
# ten / 3023 / 3026 / CARDINAL
# 2013 / 3063 / 3067 / DATE
# 62.8 million / 3078 / 3090 / CARDINAL
# New York City / 3108 / 3121 / GPE
# 2017 / 3125 / 3129 / DATE
# Times Square / 3131 / 3143 / FAC
# the Broadway Theater District / 3179 / 3208 / FAC
# one / 3210 / 3213 / CARDINAL
# Manhattan / 3402 / 3411 / GPE
# New York / 3475 / 3483 / GPE
# Chinese / 3514 / 3521 / NORP
# Asia / 3544 / 3548 / LOC
# 24/7 / 3622 / 3626 / CARDINAL
# The City that Never Sleeps / 3668 / 3694 / GPE
# the New York City Subway / 3696 / 3720 / ORG
# 472 / 3789 / 3792 / CARDINAL
# 120 / 3826 / 3829 / CARDINAL
# Columbia University / 3867 / 3886 / ORG
# New York University / 3888 / 3907 / ORG
# Rockefeller University / 3909 / 3931 / ORG
# the City University of New York / 3937 / 3968 / ORG
# the United States / 4032 / 4049 / GPE
# the Financial District / 4078 / 4100 / LOC
# Manhattan / 4110 / 4119 / GPE
# New York City / 4121 / 4134 / GPE
# two / 4273 / 4276 / CARDINAL
# the New York Stock Exchange / 4333 / 4360 / ORG
# NASDAQ / 4365 / 4371 / ORG
# 1664 / 4394 / 4398 / DATE
# the Duke of York / 4431 / 4447 / GPE
# King James II / 4466 / 4479 / PERSON
# England / 4483 / 4490 / GPE
# James / 4492 / 4497 / PERSON
# King Charles II / 4515 / 4530 / PERSON
# New Netherland / 4589 / 4603 / GPE
# New Amsterdam / 4627 / 4640 / GPE
# England / 4647 / 4654 / GPE
# Dutch / 4674 / 4679 / NORP
# present-day / 4757 / 4768 / DATE
# New York City / 4769 / 4782 / GPE
# Native Americans / 4811 / 4827 / PERSON
# Lenape / 4843 / 4849 / PERSON
# Lenapehoking / 4876 / 4888 / GPE
# Staten Island / 4899 / 4912 / GPE
# Manhattan / 4914 / 4923 / GPE
# Bronx / 4929 / 4934 / GPE
# Long Island / 4959 / 4970 / GPE
# Brooklyn / 5032 / 5040 / GPE
# Queens / 5045 / 5051 / GPE
# the Lower Hudson Valley / 5058 / 5081 / LOC
# first / 5086 / 5091 / ORDINAL
# New York Harbor / 5114 / 5129 / LOC
# European / 5135 / 5143 / NORP
# 1524 / 5151 / 5155 / DATE
# Giovanni da Verrazzano / 5159 / 5181 / PERSON
# Florentine / 5185 / 5195 / NORP
# French / 5227 / 5233 / NORP
# France / 5265 / 5271 / GPE
# Nouvelle Angoulême / 5285 / 5303 / PERSON
# Spanish / 5323 / 5330 / NORP
# Portuguese / 5354 / 5364 / NORP
# Estêvão Gomes / 5373 / 5386 / PERSON
# Charles V / 5407 / 5416 / PERSON
# New York Harbor / 5429 / 5444 / LOC
# January 1525 / 5448 / 5460 / DATE
# the Hudson River / 5486 / 5502 / LOC
# Río de San Antonio / 5519 / 5537 / PERSON
# Saint Anthony's River / 5539 / 5560 / PERSON
# 1527 / 5582 / 5586 / DATE
# first / 5592 / 5597 / ORDINAL
# the East Coast of North America / 5621 / 5652 / LOC
# Gomes / 5683 / 5688 / ORG
# United States / 5730 / 5743 / GPE
# Tierra de Esteban Gómez / 5747 / 5770 / ORG
# 1609 / 5787 / 5791 / DATE
# English / 5797 / 5804 / LANGUAGE
# Henry Hudson / 5814 / 5826 / PERSON
# New York Harbor / 5840 / 5855 / LOC
# the Northwest Passage / 5876 / 5897 / ORG
# Orient / 5905 / 5911 / LOC
# the Dutch East India Company / 5916 / 5944 / ORG
# Dutch / 5979 / 5984 / NORP
# the North River / 5996 / 6011 / LOC
# the Hudson River / 6017 / 6033 / LOC
# first / 6042 / 6047 / ORDINAL
# Hudson / 6051 / 6057 / PERSON
# Mauritius / 6065 / 6074 / ORG
# Maurice / 6081 / 6088 / GPE
# Hudson / 6108 / 6114 / ORG
# first / 6117 / 6122 / ORDINAL
# a mile / 6207 / 6213 / QUANTITY
# Hudson / 6241 / 6247 / PERSON
# roughly 150 miles / 6255 / 6272 / QUANTITY
# 240 km / 6274 / 6280 / QUANTITY
# the present-day / 6306 / 6321 / DATE
# New York State / 6322 / 6336 / GPE
# Albany / 6353 / 6359 / GPE
# ten-day / 6472 / 6479 / DATE
# the Dutch East India Company / 6531 / 6559 / ORG
# 1614 / 6564 / 6568 / DATE
# Cape Cod / 6587 / 6595 / GPE
# Delaware Bay / 6600 / 6612 / LOC
# Netherlands / 6632 / 6643 / GPE
# Nieuw-Nederland / 6655 / 6670 / PRODUCT
# first / 6693 / 6698 / ORDINAL
# Native American / 6703 / 6718 / NORP
# New York City / 6762 / 6775 / GPE
# Juan Rodriguez / 6780 / 6794 / PERSON
# Dutch / 6814 / 6819 / NORP
# Jan Rodrigues / 6823 / 6836 / PERSON
# Santo Domingo / 6855 / 6868 / PERSON
# Santo Domingo / 6878 / 6891 / PERSON
# Portuguese / 6895 / 6905 / NORP
# African / 6910 / 6917 / NORP
# Manhattan / 6941 / 6950 / GPE
# the winter of 1613–14 / 6958 / 6979 / DATE
# Dutch / 7065 / 7070 / NORP
# Broadway / 7072 / 7080 / FAC
# 159th Street / 7087 / 7099 / FAC
# 218th Street / 7103 / 7115 / FAC
# Upper Manhattan / 7119 / 7134 / GPE
# Juan Rodriguez / 7145 / 7159 / PERSON
# Dutch / 7184 / 7189 / NORP
# European / 7211 / 7219 / NORP
# New York Harbor / 7234 / 7249 / LOC
# New York / 7271 / 7279 / GPE
# 12th / 7284 / 7288 / ORDINAL
# European / 7318 / 7326 / NORP
# United States / 7369 / 7382 / GPE
# Dutch / 7406 / 7411 / NORP
# Governors Island / 7438 / 7454 / GPE
# 1625 / 7459 / 7463 / DATE
# Fort Amsterdam / 7507 / 7521 / PERSON
# Nieuw Amsterdam / 7536 / 7551 / LOC
# New Amsterdam / 7553 / 7566 / GPE
# present-day / 7572 / 7583 / DATE
# Manhattan / 7584 / 7593 / GPE
# New Amsterdam / 7616 / 7629 / GPE
# Lower Manhattan / 7675 / 7690 / ORG
# Manhattan / 7726 / 7735 / GPE
# 12-foot / 7771 / 7778 / QUANTITY
# 1653 / 7808 / 7812 / DATE
# Native American / 7832 / 7847 / NORP
# British / 7852 / 7859 / NORP
# 1626 / 7870 / 7874 / DATE
# Dutch / 7880 / 7885 / NORP
# Peter Minuit / 7912 / 7924 / PERSON
# the Dutch West India Company / 7947 / 7975 / ORG
# Manhattan / 8001 / 8010 / GPE
# Canarsie / 8020 / 8028 / LOC
# Lenape / 8038 / 8044 / PERSON
# 60 guilders / 8069 / 8080 / MONEY
# about $900 / 8083 / 8093 / MONEY
# 2018 / 8097 / 8101 / DATE
# Manhattan / 8135 / 8144 / GPE
# 24 / 8164 / 8166 / MONEY
# New Amsterdam / 8212 / 8225 / ORG
# Dutch / 8264 / 8269 / NORP
# 1628 / 8303 / 8307 / DATE
# Dutchmen / 8325 / 8333 / GPE
# 50 / 8369 / 8371 / CARDINAL
# New Netherland / 8385 / 8399 / GPE
# 1621 / 8561 / 8565 / DATE
# the Dutch West India Company / 8567 / 8595 / ORG
# New Netherland / 8626 / 8640 / GPE
# the Dutch States / 8666 / 8682 / GPE
# 1639–1640 / 8695 / 8704 / CARDINAL
# the Dutch West India Company / 8747 / 8775 / ORG
# the Dutch West / 8924 / 8938 / LOC
# 1647 / 8950 / 8954 / DATE
# Peter Stuyvesant / 8956 / 8972 / PERSON
# New Netherland / 9075 / 9089 / ORG
# 2,000 / 9100 / 9105 / CARDINAL
# 8,000 / 9109 / 9114 / CARDINAL
# Stuyvesant / 9116 / 9126 / ORG
# the Dutch Reformed Church / 9324 / 9349 / ORG
# Quakers / 9397 / 9404 / NORP
# Jews / 9406 / 9410 / NORP
# Lutherans / 9416 / 9425 / NORP
# The Dutch West India Company / 9464 / 9492 / ORG
# Stuyvesant / 9543 / 9553 / ORG
# New Amsterdam / 9571 / 9584 / GPE
# English / 9592 / 9599 / LANGUAGE
# 1664 / 9612 / 9616 / DATE
# Stuyvesant / 9663 / 9673 / ORG
# New Amsterdam / 9686 / 9699 / GPE
# English / 9703 / 9710 / LANGUAGE
# Richard Nicolls / 9734 / 9749 / PERSON
# Dutch / 9807 / 9812 / NORP
# English / 9886 / 9893 / LANGUAGE
# New York / 9931 / 9939 / GPE
# the Duke of York / 9947 / 9963 / GPE
# James II / 9981 / 9989 / PERSON
# England / 9993 / 10000 / GPE

# %%
for token in nlp("The Statue of Liberty greeted millions of immigrants who came to the Americas by ship in the 1980s"):
    print(token.text,token.pos_,token.tag_,token.is_alpha,token.is_stop,sep = " / ")
# Out:
# The / DET / DT / True / True
# Statue / PROPN / NNP / True / False
# of / ADP / IN / True / True
# Liberty / PROPN / NNP / True / False
# greeted / VERB / VBD / True / False
# millions / NOUN / NNS / True / False
# of / ADP / IN / True / True
# immigrants / NOUN / NNS / True / False
# who / PRON / WP / True / True
# came / VERB / VBD / True / False
# to / ADP / IN / True / True
# the / DET / DT / True / True
# Americas / PROPN / NNPS / True / False
# by / ADP / IN / True / True
# ship / NOUN / NN / True / False
# in / ADP / IN / True / True
# the / DET / DT / True / True
# 1980s / NUM / CD / False / False

# %%
from spacy.matcher import Matcher

# %%
from spacy import displacy

# %%
matcher = Matcher(nlp.vocab)
matched_sents = []
matched_phrases = []

def collect_sents(matcher,doc,i,matches):
    match_id,start,end = matches[i]
    span = doc[start:end]
    sent = span.sent
    match_ents = [{'start':span.start_char - sent.start_char,
               'end': span.end_char - sent.start_char,
               'label': 'MATCH'}]
    matched_sents.append({'text': sent.text, 'ents': match_ents})
    matched_phrases.append(span.text)

# %%
pattern = [{'POS': 'NOUN'},{'POS':'NOUN'}]

# %%
matcher.add('nounphrase', collect_sents, pattern)

# %%
matches = matcher(nynlp)

# %%
matches
# Out:
# [(8429085606845659861, 138, 140),
#  (8429085606845659861, 253, 255),
#  (8429085606845659861, 390, 392),
#  (8429085606845659861, 595, 597),
#  (8429085606845659861, 642, 644),
#  (8429085606845659861, 665, 667),
#  (8429085606845659861, 725, 727),
#  (8429085606845659861, 731, 733),
#  (8429085606845659861, 769, 771),
#  (8429085606845659861, 820, 822),
#  (8429085606845659861, 824, 826),
#  (8429085606845659861, 1239, 1241),
#  (8429085606845659861, 1268, 1270),
#  (8429085606845659861, 1445, 1447),
#  (8429085606845659861, 1446, 1448),
#  (8429085606845659861, 1584, 1586),
#  (8429085606845659861, 1595, 1597),
#  (8429085606845659861, 1615, 1617),
#  (8429085606845659861, 1655, 1657),
#  (8429085606845659861, 1711, 1713),
#  (8429085606845659861, 1799, 1801),
#  (8429085606845659861, 1912, 1914)]

# %%
matched_sents
# Out:
# [{'text': 'New York City has been described as the cultural, financial, and media capital of the world, significantly influencing commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports.',
#   'ents': [{'start': 65, 'end': 78, 'label': 'MATCH'}]},
#  {'text': 'The city and its metropolitan area constitute the premier gateway for legal immigration to the United States.',
#   'ents': [{'start': 50, 'end': 65, 'label': 'MATCH'}]},
#  {'text': 'New York City traces its origins to a trading post founded by colonists from the Dutch Republic in 1624 on Lower Manhattan; the post was named New Amsterdam in 1626.',
#   'ents': [{'start': 38, 'end': 50, 'label': 'MATCH'}]},
#  {'text': "Many districts and landmarks in New York City are well known, including three of the world's ten most visited tourist attractions in 2013.",
#   'ents': [{'start': 110, 'end': 129, 'label': 'MATCH'}]},
#  {'text': "Times Square is the brightly illuminated hub of the Broadway Theater District, one of the world's busiest pedestrian intersections, and a major center of the world's entertainment industry.",
#   'ents': [{'start': 166, 'end': 188, 'label': 'MATCH'}]},
#  {'text': "Manhattan's real estate market is among the most expensive in the world.",
#   'ents': [{'start': 17, 'end': 30, 'label': 'MATCH'}]},
#  {'text': 'Providing continuous 24/7 service and contributing to the nickname The City that Never Sleeps, the New York City Subway is the largest single-operator rapid transit system worldwide, with 472 rail stations.',
#   'ents': [{'start': 157, 'end': 171, 'label': 'MATCH'}]},
#  {'text': 'Providing continuous 24/7 service and contributing to the nickname The City that Never Sleeps, the New York City Subway is the largest single-operator rapid transit system worldwide, with 472 rail stations.',
#   'ents': [{'start': 192, 'end': 205, 'label': 'MATCH'}]},
#  {'text': 'The city has over 120 colleges and universities, including Columbia University, New York University, Rockefeller University, and the City University of New York system, which is the largest urban public university system in the United States.',
#   'ents': [{'start': 203, 'end': 220, 'label': 'MATCH'}]},
#  {'text': "Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the world's leading financial center and the most financially powerful city in the world, and is home to the world's two largest stock exchanges by total market capitalization, the New York Stock Exchange and NASDAQ.\n\n\n",
#   'ents': [{'start': 234, 'end': 249, 'label': 'MATCH'}]},
#  {'text': "Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the world's leading financial center and the most financially powerful city in the world, and is home to the world's two largest stock exchanges by total market capitalization, the New York Stock Exchange and NASDAQ.\n\n\n",
#   'ents': [{'start': 259, 'end': 280, 'label': 'MATCH'}]},
#  {'text': 'Hudson sailed roughly 150 miles (240 km) north, past the site of the present-day New York State capital city of Albany, in the belief that it might be an oceanic tributary before the river became too shallow to continue.',
#   'ents': [{'start': 96, 'end': 108, 'label': 'MATCH'}]},
#  {'text': 'He made a ten-day exploration of the area and claimed the region for the Dutch East India Company.',
#   'ents': [{'start': 14, 'end': 29, 'label': 'MATCH'}]},
#  {'text': 'A permanent European presence near New York Harbor began in 1624—making New York the 12th oldest continuously occupied European-established settlement in the continental United States—with the founding of a Dutch fur trading settlement on Governors Island.',
#   'ents': [{'start': 213, 'end': 224, 'label': 'MATCH'}]},
#  {'text': 'A permanent European presence near New York Harbor began in 1624—making New York the 12th oldest continuously occupied European-established settlement in the continental United States—with the founding of a Dutch fur trading settlement on Governors Island.',
#   'ents': [{'start': 217, 'end': 235, 'label': 'MATCH'}]},
#  {'text': 'A disproved legend claims that Manhattan was purchased for $24 worth of glass beads.',
#   'ents': [{'start': 12, 'end': 25, 'label': 'MATCH'}]},
#  {'text': 'A disproved legend claims that Manhattan was purchased for $24 worth of glass beads.',
#   'ents': [{'start': 72, 'end': 83, 'label': 'MATCH'}]},
#  {'text': 'To attract settlers, the Dutch instituted the patroon system in 1628, whereby wealthy Dutchmen (patroons, or patrons) who brought 50 colonists to New Netherland would be awarded swaths of land, along with local political autonomy and rights to participate in the lucrative fur trade.',
#   'ents': [{'start': 46, 'end': 60, 'label': 'MATCH'}]},
#  {'text': 'To attract settlers, the Dutch instituted the patroon system in 1628, whereby wealthy Dutchmen (patroons, or patrons) who brought 50 colonists to New Netherland would be awarded swaths of land, along with local political autonomy and rights to participate in the lucrative fur trade.',
#   'ents': [{'start': 273, 'end': 282, 'label': 'MATCH'}]},
#  {'text': 'In 1639–1640, in an effort to bolster economic growth, the Dutch West India Company relinquished its monopoly over the fur trade, leading to growth in the production and trade of food, timber, tobacco, and slaves (particularly with the Dutch West Indies).In 1647, Peter Stuyvesant began his tenure as the last Director-General of New Netherland.',
#   'ents': [{'start': 119, 'end': 128, 'label': 'MATCH'}]},
#  {'text': 'He instituted regulations on liquor sales, attempted to assert control over the Dutch Reformed Church, and blocked other religious groups (including Quakers, Jews, and Lutherans) from establishing houses of worship.',
#   'ents': [{'start': 29, 'end': 41, 'label': 'MATCH'}]},
#  {'text': 'The English promptly renamed the fledgling city "New York" after the Duke of York (the future King James II of England',
#   'ents': [{'start': 33, 'end': 47, 'label': 'MATCH'}]}]

# %%
displacy.render(matched_sents, style = 'ent', manual=True, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">New York City has been described as the cultural, financial, and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     media capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of the world, significantly influencing commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The city and its metropolitan area constitute the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     premier gateway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  for legal immigration to the United States.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">New York City traces its origins to a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     trading post
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  founded by colonists from the Dutch Republic in 1624 on Lower Manhattan; the post was named New Amsterdam in 1626.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Many districts and landmarks in New York City are well known, including three of the world's ten most visited
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tourist attractions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  in 2013.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Times Square is the brightly illuminated hub of the Broadway Theater District, one of the world's busiest pedestrian intersections, and a major center of the world's
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     entertainment industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Manhattan's real
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     estate market
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  is among the most expensive in the world.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Providing continuous 24/7 service and contributing to the nickname The City that Never Sleeps, the New York City Subway is the largest single-operator rapid
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     transit system
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  worldwide, with 472 rail stations.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Providing continuous 24/7 service and contributing to the nickname The City that Never Sleeps, the New York City Subway is the largest single-operator rapid transit system worldwide, with 472
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rail stations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The city has over 120 colleges and universities, including Columbia University, New York University, Rockefeller University, and the City University of New York system, which is the largest urban public
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     university system
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  in the United States.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the world's leading financial center and the most financially powerful city in the world, and is home to the world's two largest
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stock exchanges
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  by total market capitalization, the New York Stock Exchange and NASDAQ.
#
#
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the world's leading financial center and the most financially powerful city in the world, and is home to the world's two largest stock exchanges by total
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     market capitalization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# , the New York Stock Exchange and NASDAQ.
#
#
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hudson sailed roughly 150 miles (240 km) north, past the site of the present-day New York State
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     capital city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of Albany, in the belief that it might be an oceanic tributary before the river became too shallow to continue.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">He made a ten-
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     day exploration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of the area and claimed the region for the Dutch East India Company.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A permanent European presence near New York Harbor began in 1624—making New York the 12th oldest continuously occupied European-established settlement in the continental United States—with the founding of a Dutch
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-heigh

# %%
patterns =[[{'POS':'NOUN','IS_ALPHA':True,'IS_STOP':False,'OP':'+'}]]
matcher = Matcher(nlp.vocab)
matched_sents = []
matched_phrases = []
for pattern in patterns:
    matcher.add('keyword', collect_sents,pattern)

# %%
matches = matcher(nynlp)

# %%
sorted(matched_phrases)
# Out:
# ['Chinatowns',
#  'Dutchmen',
#  'Etymology',
#  'Gomes',
#  'Harbour',
#  'History',
#  'Street',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'areas',
#  'art',
#  'attractions',
#  'authority',
#  'autonomy',
#  'band',
#  'beads',
#  'belief',
#  'billionaires',
#  'bloodshed',
#  'boroughs',
#  'boroughs',
#  'boroughs',
#  'brother',
#  'brother',
#  'capital',
#  'capital',
#  'capital',
#  'capital city',
#  'capitalization',
#  'captain',
#  'center',
#  'center',
#  'center',
#  'center',
#  'centuries',
#  'century',
#  'citadel',
#  'cities',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'claims',
#  'colleges',
#  'colonial',
#  'colonists',
#  'colonists',
#  'colony',
#  'colony',
#  'colony',
#  'commerce',
#  'construction',
#  'control',
#  'control',
#  'county',
#  'creativity',
#  'crown',
#  'day',
#  'day',
#  'day',
#  'day',
#  'day',
#  'day exploration',
#  'descent',
#  'diplomacy',
#  'districts',
#  'diversity',
#  'diversity',
#  'economy',
#  'education',
#  'effort',
#  'entertainment',
#  'entertainment',
#  'entertainment industry',
#  'entrepreneurship',
#  'era',
#  'estate',
#  'estate market',
#  'exchanges',
#  'expedition',
#  'expedition',
#  'exploration',
#  'explorer',
#  'explorer',
#  'fashion',
#  'fish',
#  'fledgling',
#  'fledgling city',
#  'food',
#  'foreign',
#  'founding',
#  'freedom',
#  'freedom',
#  'fur',
#  'fur',
#  'fur',
#  'fur trade',
#  'fur trade',
#  'fur trading',
#  'fur trading settlement',
#  'gateway',
#  'glass',
#  'glass beads',
#  'groups',
#  'growth',
#  'growth',
#  'guilders',
#  'harbor',
#  'harbors',
#  'headquarters',
#  'history',
#  'home',
#  'home',
#  'home',
#  'home',
#  'homeland',
#  'honor',
#  'honor',
#  'honor',
#  'houses',
#  'hub',
#  'ideals',
#  'immigrants',
#  'immigration',
#  'industry',
#  'inhabitant',
#  'intersections',
#  'island',
#  'km',
#  'land',
#  'landmarks',
#  'landmarks',
#  'landmass',
#  'lands',
#  'languages',
#  'law',
#  'leader',
#  'legend',
#  'legend claims',
#  'liberty',
#  'liquor',
#  'liquor sales',
#  'map',
#  'market',
#  'market',
#  'market capitalization',
#  'mate',
#  'media',
#  'media capital',
#  'megacities',
#  'merchant',
#  'mile',
#  'miles',
#  'miles',
#  'millions',
#  'monopoly',
#  'monopoly',
#  'mouth',
#  'nickname',
#  'node',
#  'number',
#  'operator',
#  'order',
#  'origins',
#  'parks',
#  'patrons',
#  'patroon',
#  'patroon system',
#  'patroons',
#  'peace',
#  'pelts',
#  'people',
#  'people',
#  'politics',
#  'population',
#  'population',
#  'population',
#  'population',
#  'population',
#  'portion',
#  'post',
#  'post',
#  'premier',
#  'premier gateway',
#  'presence',
#  'product',
#  'production',
#  'program',
#  'proprietor',
#  'purchase',
#  'raids',
#  'rail',
#  'rail stations',
#  'record',
#  'region',
#  'regulations',
#  'representative',
#  'reputation',
#  'research',
#  'residents',
#  'residents',
#  'residents',
#  'resistance',
#  'rights',
#  'river',
#  'river',
#  'rule',
#  'rule',
#  'sales',
#  'service',
#  'service',
#  'settlement',
#  'settlement',
#  'settlers',
#  'ship',
#  'site',
#  'skyscrapers',
#  'slaves',
#  'sports',
#  'state',
#  'state',
#  'stations',
#  'stock',
#  'stock exchanges',
#  'stockade',
#  'success',
#  'surrender',
#  'surroundings',
#  'survey',
#  'sustainability',
#  'swaths',
#  'symbol',
#  'symbol',
#  'system',
#  'system',
#  'system',
#  'system',
#  'technology',
#  'tensions',
#  'tenure',
#  'tenure',
#  'terms',
#  'territory',
#  'timber',
#  'tip',
#  'tip',
#  'tobacco',
#  'tourism',
#  'tourist',
#  'tourist attractions',
#  'tourists',
#  'trade',
#  'trade',
#  'trade',
#  'trading',
#  'trading',
#  'trading',
#  'trading post',
#  'trading settlement',
#  'transit',
#  'transit system',
#  'tributary',
#  'troops',
#  'universities',
#  'university',
#  'university system',
#  'value',
#  'visit',
#  'windes',
#  'winter',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'worship',
#  'worth']

# %%
from collections import Counter
keywords = dict(Counter(matched_phrases))

# %%
keywords
# Out:
# {'city': 20,
#  'population': 5,
#  'miles': 2,
#  'tip': 2,
#  'state': 2,
#  'center': 4,
#  'area': 11,
#  'world': 17,
#  'landmass': 1,
#  'people': 2,
#  'megacities': 1,
#  'media': 1,
#  'media capital': 1,
#  'capital': 3,
#  'commerce': 1,
#  'entertainment': 2,
#  'research': 1,
#  'technology': 1,
#  'education': 1,
#  'politics': 1,
#  'tourism': 1,
#  'art': 1,
#  'fashion': 1,
#  'sports': 1,
#  'headquarters': 1,
#  'diplomacy': 1,
#  'harbors': 1,
#  'boroughs': 3,
#  'county': 1,
#  'premier': 1,
#  'premier gateway': 1,
#  'gateway': 1,
#  'immigration': 1,
#  'languages': 1,
#  'home': 4,
#  'residents': 3,
#  'foreign': 1,
#  'product': 1,
#  'economy': 1,
#  'number': 1,
#  'billionaires': 1,
#  'origins': 1,
#  'trading': 3,
#  'trading post': 1,
#  'post': 2,
#  'colonists': 2,
#  'surroundings': 1,
#  'control': 2,
#  'lands': 1,
#  'brother': 2,
#  'millions': 1,
#  'immigrants': 1,
#  'ship': 1,
#  'centuries': 1,
#  'symbol': 2,
#  'ideals': 1,
#  'liberty': 1,
#  'peace': 1,
#  'century': 1,
#  'node': 1,
#  'creativity': 1,
#  'entrepreneurship': 1,
#  'sustainability': 1,
#  'freedom': 2,
#  'diversity': 2,
#  'survey': 1,
#  'cities': 1,
#  'districts': 1,
#  'landmarks': 2,
#  'tourist': 1,
#  'tourist attractions': 1,
#  'attractions': 1,
#  'record': 1,
#  'tourists': 1,
#  'hub': 1,
#  'intersections': 1,
#  'entertainment industry': 1,
#  'industry': 1,
#  'skyscrapers': 1,
#  'parks': 1,
#  'estate': 1,
#  'estate market': 1,
#  'market': 2,
#  'Chinatowns': 1,
#  'service': 2,
#  'nickname': 1,
#  'operator': 1,
#  'transit': 1,
#  'transit system': 1,
#  'system': 4,
#  'rail': 1,
#  'rail stations': 1,
#  'stations': 1,
#  'colleges': 1,
#  'universities': 1,
#  'university': 1,
#  'university system': 1,
#  'stock': 1,
#  'stock exchanges': 1,
#  'exchanges': 1,
#  'market capitalization': 1,
#  'capitalization': 1,
#  'Etymology': 1,
#  'honor': 3,
#  'proprietor': 1,
#  'territory': 1,
#  'History': 1,
#  'history': 1,
#  'era': 1,
#  'day': 5,
#  'homeland': 1,
#  'portion': 1,
#  'areas': 1,
#  'visit': 1,
#  'explorer': 2,
#  'crown': 1,
#  'expedition': 2,
#  'captain': 1,
#  'mouth': 1,
#  'map': 1,
#  'Gomes': 1,
#  'mate': 1,
#  'harbor': 1,
#  'Harbour': 1,
#  'windes': 1,
#  'river': 2,
#  'mile': 1,
#  'fish': 1,
#  'km': 1,
#  'site': 1,
#  'capital city': 1,
#  'belief': 1,
#  'tributary': 1,
#  'day exploration': 1,
#  'exploration': 1,
#  'region': 1,
#  'inhabitant': 1,
#  'merchant': 1,
#  'descent': 1,
#  'winter': 1,
#  'pelts': 1,
#  'representative': 1,
#  'Street': 1,
#  'rule': 2,
#  'presence': 1,
#  'settlement': 2,
#  'founding': 1,
#  'fur': 3,
#  'fur trading': 1,
#  'fur trading settlement': 1,
#  'trading settlement': 1,
#  'construction': 1,
#  'citadel': 1,
#  'colony': 3,
#  'stockade': 1,
#  'raids': 1,
#  'colonial': 1,
#  'island': 1,
#  'band': 1,
#  'value': 1,
#  'guilders': 1,
#  'legend': 1,
#  'legend claims': 1,
#  'claims': 1,
#  'worth': 1,
#  'glass': 1,
#  'glass beads': 1,
#  'beads': 1,
#  'purchase': 1,
#  'settlers': 1,
#  'patroon': 1,
#  'patroon system': 1,
#  'Dutchmen': 1,
#  'patroons': 1,
#  'patrons': 1,
#  'swaths': 1,
#  'land': 1,
#  'autonomy': 1,
#  'rights': 1,
#  'fur trade': 2,
#  'trade': 3,
#  'program': 1,
#  'success': 1,
#  'monopoly': 2,
#  'authority': 1,
#  'effort': 1,
#  'growth': 2,
#  'production': 1,
#  'food': 1,
#  'timber': 1,
#  'tobacco': 1,
#  'slaves': 1,
#  'tenure': 2,
#  'law': 1,
#  'order': 1,
#  'reputation': 1,
#  'leader': 1,
#  'regulations': 1,
#  'liquor': 1,
#  'liquor sales': 1,
#  'sales': 1,
#  'groups': 1,
#  'houses': 1,
#  'worship': 1,
#  'tensions': 1,
#  'resistance': 1,
#  'troops': 1,
#  'bloodshed': 1,
#  'terms': 1,
#  'surrender': 1,
#  'fledgling': 1,
#  'fledgling city': 1}

# %%
import math
import re
keywords_cvalues={}
for keyword in sorted(keywords.keys()):
    parent_terms = list(filter(lambda t:t!=keyword and re.match('\\b%s\\b' % keyword, t),keywords.keys()))
    keywords_cvalues[keyword] =keywords[keyword]
    print("TERM",keyword,"PARENT TERMS:", parent_terms)
    for pt in parent_terms:
        keywords_cvalues[keyword] -= float(keywords[pt])/float(len(parent_terms))
    keywords_cvalues[keyword] *= math.log(len(keyword.split()),2)
# Out:
# TERM Chinatowns PARENT TERMS: []
# TERM Dutchmen PARENT TERMS: []
# TERM Etymology PARENT TERMS: []
# TERM Gomes PARENT TERMS: []
# TERM Harbour PARENT TERMS: []
# TERM History PARENT TERMS: []
# TERM Street PARENT TERMS: []
# TERM area PARENT TERMS: []
# TERM areas PARENT TERMS: []
# TERM art PARENT TERMS: []
# TERM attractions PARENT TERMS: []
# TERM authority PARENT TERMS: []
# TERM autonomy PARENT TERMS: []
# TERM band PARENT TERMS: []
# TERM beads PARENT TERMS: []
# TERM belief PARENT TERMS: []
# TERM billionaires PARENT TERMS: []
# TERM bloodshed PARENT TERMS: []
# TERM boroughs PARENT TERMS: []
# TERM brother PARENT TERMS: []
# TERM capital PARENT TERMS: ['capital city']
# TERM capital city PARENT TERMS: []
# TERM capitalization PARENT TERMS: []
# TERM captain PARENT TERMS: []
# TERM center PARENT TERMS: []
# TERM centuries PARENT TERMS: []
# TERM century PARENT TERMS: []
# TERM citadel PARENT TERMS: []
# TERM cities PARENT TERMS: []
# TERM city PARENT TERMS: []
# TERM claims PARENT TERMS: []
# TERM colleges PARENT TERMS: []
# TERM colonial PARENT TERMS: []
# TERM colonists PARENT TERMS: []
# TERM colony PARENT TERMS: []
# TERM commerce PARENT TERMS: []
# TERM construction PARENT TERMS: []
# TERM control PARENT TERMS: []
# TERM county PARENT TERMS: []
# TERM creativity PARENT TERMS: []
# TERM crown PARENT TERMS: []
# TERM day PARENT TERMS: ['day exploration']
# TERM day exploration PARENT TERMS: []
# TERM descent PARENT TERMS: []
# TERM diplomacy PARENT TERMS: []
# TERM districts PARENT TERMS: []
# TERM diversity PARENT TERMS: []
# TERM economy PARENT TERMS: []
# TERM education PARENT TERMS: []
# TERM effort PARENT TERMS: []
# TERM entertainment PARENT TERMS: ['entertainment industry']
# TERM entertainment industry PARENT TERMS: []
# TERM entrepreneurship PARENT TERMS: []
# TERM era PARENT TERMS: []
# TERM estate PARENT TERMS: ['estate market']
# TERM estate market PARENT TERMS: []
# TERM exchanges PARENT TERMS: []
# TERM expedition PARENT TERMS: []
# TERM exploration PARENT TERMS: []
# TERM explorer PARENT TERMS: []
# TERM fashion PARENT TERMS: []
# TERM fish PARENT TERMS: []
# TERM fledgling PARENT TERMS: ['fledgling city']
# TERM fledgling city PARENT TERMS: []
# TERM food PARENT TERMS: []
# TERM foreign PARENT TERMS: []
# TERM founding PARENT TERMS: []
# TERM freedom PARENT TERMS: []
# TERM fur PARENT TERMS: ['fur trading', 'fur trading settlement', 'fur trade']
# TERM fur trade PARENT TERMS: []
# TERM fur trading PARENT TERMS: ['fur trading settlement']
# TERM fur trading settlement PARENT TERMS: []
# TERM gateway PARENT TERMS: []
# TERM glass PARENT TERMS: ['glass beads']
# TERM glass beads PARENT TERMS: []
# TERM groups PARENT TERMS: []
# TERM growth PARENT TERMS: []
# TERM guilders PARENT TERMS: []
# TERM harbor PARENT TERMS: []
# TERM harbors PARENT TERMS: []
# TERM headquarters PARENT TERMS: []
# TERM history PARENT TERMS: []
# TERM home PARENT TERMS: []
# TERM homeland PARENT TERMS: []
# TERM honor PARENT TERMS: []
# TERM houses PARENT TERMS: []
# TERM hub PARENT TERMS: []
# TERM ideals PARENT TERMS: []
# TERM immigrants PARENT TERMS: []
# TERM immigration PARENT TERMS: []
# TERM industry PARENT TERMS: []
# TERM inhabitant PARENT TERMS: []
# TERM intersections PARENT TERMS: []
# TERM island PARENT TERMS: []
# TERM km PARENT TERMS: []
# TERM land PARENT TERMS: []
# TERM landmarks PARENT TERMS: []
# TERM landmass PARENT TERMS: []
# TERM lands PARENT TERMS: []
# TERM languages PARENT TERMS: []
# TERM law PARENT TERMS: []
# TERM leader PARENT TERMS: []
# TERM legend PARENT TERMS: ['legend claims']
# TERM legend claims PARENT TERMS: []
# TERM liberty PARENT TERMS: []
# TERM liquor PARENT TERMS: ['liquor sales']
# TERM liquor sales PARENT TERMS: []
# TERM map PARENT TERMS: []
# TERM market PARENT TERMS: ['market capitalization']
# TERM market capitalization PARENT TERMS: []
# TERM mate PARENT TERMS: []
# TERM media PARENT TERMS: ['media capital']
# TERM media capital PARENT TERMS: []
# TERM megacities PARENT TERMS: []
# TERM merchant PARENT TERMS: []
# TERM mile PARENT TERMS: []
# TERM miles PARENT TERMS: []
# TERM millions PARENT TERMS: []
# TERM monopoly PARENT TERMS: []
# TERM mouth PARENT TERMS: []
# TERM nickname PARENT TERMS: []
# TERM node PARENT TERMS: []
# TERM number PARENT TERMS: []
# TERM operator PARENT TERMS: []
# TERM order PARENT TERMS: []
# TERM origins PARENT TERMS: []
# TERM parks PARENT TERMS: []
# TERM patrons PARENT TERMS: []
# TERM patroon PARENT TERMS: ['patroon system']
# TERM patroon system PARENT TERMS: []
# TERM patroons PARENT TERMS: []
# TERM peace PARENT TERMS: []
# TERM pelts PARENT TERMS: []
# TERM people PARENT TERMS: []
# TERM politics PARENT TERMS: []
# TERM population PARENT TERMS: []
# TERM portion PARENT TERMS: []
# TERM post PARENT TERMS: []
# TERM premier PARENT TERMS: ['premier gateway']
# TERM premier gateway PARENT TERMS: []
# TERM presence PARENT TERMS: []
# TERM product PARENT TERMS: []
# TERM production PARENT TERMS: []
# TERM program PARENT TERMS: []
# TERM proprietor PARENT TERMS: []
# TERM purchase PARENT TERMS: []
# TERM raids PARENT TERMS: []
# TERM rail PARENT TERMS: ['rail stations']
# TERM rail stations PARENT TERMS: []
# TERM record PARENT TERMS: []
# TERM region PARENT TERMS: []
# TERM regulations PARENT TERMS: []
# TERM representative PARENT TERMS: []
# TERM reputation PARENT TERMS: []
# TERM research PARENT TERMS: []
# TERM residents PARENT TERMS: []
# TERM resistance PARENT TERMS: []
# TERM rights PARENT TERMS: []
# TERM river PARENT TERMS: []
# TERM rule PARENT TERMS: []
# TERM sales PARENT TERMS: []
# TERM service PARENT TERMS: []
# TERM settlement PARENT TERMS: []
# TERM settlers PARENT TERMS: []
# TERM ship PARENT TERMS: []
# TERM site PARENT TERMS: []
# TERM skyscrapers PARENT TERMS: []
# TERM slaves PARENT TERMS: []
# TERM sports PARENT TERMS: []
# TERM state PARENT TERMS: []
# TERM stations PARENT TERMS: []
# TERM stock PARENT TERMS: ['stock exchanges']
# TERM stock exchanges PARENT TERMS: []
# TERM stockade PARENT TERMS: []
# TERM success PARENT TERMS: []
# TERM surrender PARENT TERMS: []
# TERM surroundings PARENT TERMS: []
# TERM survey PARENT TERMS: []
# TERM sustainability PARENT TERMS: []
# TERM swaths PARENT TERMS: []
# TERM symbol PARENT TERMS: []
# TERM system PARENT TERMS: []
# TERM technology PARENT TERMS: []
# TERM tensions PARENT TERMS: []
# TERM tenure PARENT TERMS: []
# TERM terms PARENT TERMS: []
# TERM territory PARENT TERMS: []
# TERM timber PARENT TERMS: []
# TERM tip PARENT TERMS: []
# TERM tobacco PARENT TERMS: []
# TERM tourism PARENT TERMS: []
# TERM tourist PARENT TERMS: ['tourist attractions']
# TERM tourist attractions PARENT TERMS: []
# TERM tourists PARENT TERMS: []
# TERM trade PARENT TERMS: []
# TERM trading PARENT TERMS: ['trading post', 'trading settlement']
# TERM trading post PARENT TERMS: []
# TERM trading settlement PARENT TERMS: []
# TERM transit PARENT TERMS: ['transit system']
# TERM transit system PARENT TERMS: []
# TERM tributary PARENT TERMS: []
# TERM troops PARENT TERMS: []
# TERM universities PARENT TERMS: []
# TERM university PARENT TERMS: ['university system']
# TERM university system PARENT TERMS: []
# TERM value PARENT TERMS: []
# TERM visit PARENT TERMS: []
# TERM windes PARENT TERMS: []
# TERM winter PARENT TERMS: []
# TERM world PARENT TERMS: []
# TERM worship PARENT TERMS: []
# TERM worth PARENT TERMS: []

# %%
keywords_cvalues
# Out:
# {'Chinatowns': 0.0,
#  'Dutchmen': 0.0,
#  'Etymology': 0.0,
#  'Gomes': 0.0,
#  'Harbour': 0.0,
#  'History': 0.0,
#  'Street': 0.0,
#  'area': 0.0,
#  'areas': 0.0,
#  'art': 0.0,
#  'attractions': 0.0,
#  'authority': 0.0,
#  'autonomy': 0.0,
#  'band': 0.0,
#  'beads': 0.0,
#  'belief': 0.0,
#  'billionaires': 0.0,
#  'bloodshed': 0.0,
#  'boroughs': 0.0,
#  'brother': 0.0,
#  'capital': 0.0,
#  'capital city': 1.0,
#  'capitalization': 0.0,
#  'captain': 0.0,
#  'center': 0.0,
#  'centuries': 0.0,
#  'century': 0.0,
#  'citadel': 0.0,
#  'cities': 0.0,
#  'city': 0.0,
#  'claims': 0.0,
#  'colleges': 0.0,
#  'colonial': 0.0,
#  'colonists': 0.0,
#  'colony': 0.0,
#  'commerce': 0.0,
#  'construction': 0.0,
#  'control': 0.0,
#  'county': 0.0,
#  'creativity': 0.0,
#  'crown': 0.0,
#  'day': 0.0,
#  'day exploration': 1.0,
#  'descent': 0.0,
#  'diplomacy': 0.0,
#  'districts': 0.0,
#  'diversity': 0.0,
#  'economy': 0.0,
#  'education': 0.0,
#  'effort': 0.0,
#  'entertainment': 0.0,
#  'entertainment industry': 1.0,
#  'entrepreneurship': 0.0,
#  'era': 0.0,
#  'estate': 0.0,
#  'estate market': 1.0,
#  'exchanges': 0.0,
#  'expedition': 0.0,
#  'exploration': 0.0,
#  'explorer': 0.0,
#  'fashion': 0.0,
#  'fish': 0.0,
#  'fledgling': 0.0,
#  'fledgling city': 1.0,
#  'food': 0.0,
#  'foreign': 0.0,
#  'founding': 0.0,
#  'freedom': 0.0,
#  'fur': 0.0,
#  'fur trade': 2.0,
#  'fur trading': 0.0,
#  'fur trading settlement': 1.5849625007211563,
#  'gateway': 0.0,
#  'glass': 0.0,
#  'glass beads': 1.0,
#  'groups': 0.0,
#  'growth': 0.0,
#  'guilders': 0.0,
#  'harbor': 0.0,
#  'harbors': 0.0,
#  'headquarters': 0.0,
#  'history': 0.0,
#  'home': 0.0,
#  'homeland': 0.0,
#  'honor': 0.0,
#  'houses': 0.0,
#  'hub': 0.0,
#  'ideals': 0.0,
#  'immigrants': 0.0,
#  'immigration': 0.0,
#  'industry': 0.0,
#  'inhabitant': 0.0,
#  'intersections': 0.0,
#  'island': 0.0,
#  'km': 0.0,
#  'land': 0.0,
#  'landmarks': 0.0,
#  'landmass': 0.0,
#  'lands': 0.0,
#  'languages': 0.0,
#  'law': 0.0,
#  'leader': 0.0,
#  'legend': 0.0,
#  'legend claims': 1.0,
#  'liberty': 0.0,
#  'liquor': 0.0,
#  'liquor sales': 1.0,
#  'map': 0.0,
#  'market': 0.0,
#  'market capitalization': 1.0,
#  'mate': 0.0,
#  'media': 0.0,
#  'media capital': 1.0,
#  'megacities': 0.0,
#  'merchant': 0.0,
#  'mile': 0.0,
#  'miles': 0.0,
#  'millions': 0.0,
#  'monopoly': 0.0,
#  'mouth': 0.0,
#  'nickname': 0.0,
#  'node': 0.0,
#  'number': 0.0,
#  'operator': 0.0,
#  'order': 0.0,
#  'origins': 0.0,
#  'parks': 0.0,
#  'patrons': 0.0,
#  'patroon': 0.0,
#  'patroon system': 1.0,
#  'patroons': 0.0,
#  'peace': 0.0,
#  'pelts': 0.0,
#  'people': 0.0,
#  'politics': 0.0,
#  'population': 0.0,
#  'portion': 0.0,
#  'post': 0.0,
#  'premier': 0.0,
#  'premier gateway': 1.0,
#  'presence': 0.0,
#  'product': 0.0,
#  'production': 0.0,
#  'program': 0.0,
#  'proprietor': 0.0,
#  'purchase': 0.0,
#  'raids': 0.0,
#  'rail': 0.0,
#  'rail stations': 1.0,
#  'record': 0.0,
#  'region': 0.0,
#  'regulations': 0.0,
#  'representative': 0.0,
#  'reputation': 0.0,
#  'research': 0.0,
#  'residents': 0.0,
#  'resistance': 0.0,
#  'rights': 0.0,
#  'river': 0.0,
#  'rule': 0.0,
#  'sales': 0.0,
#  'service': 0.0,
#  'settlement': 0.0,
#  'settlers': 0.0,
#  'ship': 0.0,
#  'site': 0.0,
#  'skyscrapers': 0.0,
#  'slaves': 0.0,
#  'sports': 0.0,
#  'state': 0.0,
#  'stations': 0.0,
#  'stock': 0.0,
#  'stock exchanges': 1.0,
#  'stockade': 0.0,
#  'success': 0.0,
#  'surrender': 0.0,
#  'surroundings': 0.0,
#  'survey': 0.0,
#  'sustainability': 0.0,
#  'swaths': 0.0,
#  'symbol': 0.0,
#  'system': 0.0,
#  'technology': 0.0,
#  'tensions': 0.0,
#  'tenure': 0.0,
#  'terms': 0.0,
#  'territory': 0.0,
#  'timber': 0.0,
#  'tip': 0.0,
#  'tobacco': 0.0,
#  'tourism': 0.0,
#  'tourist': 0.0,
#  'tourist attractions': 1.0,
#  'tourists': 0.0,
#  'trade': 0.0,
#  'trading': 0.0,
#  'trading post': 1.0,
#  'trading settlement': 1.0,
#  'transit': 0.0,
#  'transit system': 1.0,
#  'tributary': 0.0,
#  'troops': 0.0,
#  'universities': 0.0,
#  'university': 0.0,
#  'university system': 1.0,
#  'value': 0.0,
#  'visit': 0.0,
#  'windes': 0.0,
#  'winter': 0.0,
#  'world': 0.0,
#  'worship': 0.0,
#  'worth': 0.0}

# %%
best_keywords = []
for keyword in sorted(keywords_cvalues, key  = keywords_cvalues.get,reverse = True)[:10]:
    best_keywords.append([keyword,keywords_cvalues[keyword]])

# %%
best_keywords
# Out:
# [['fur trade', 2.0],
#  ['fur trading settlement', 1.5849625007211563],
#  ['capital city', 1.0],
#  ['day exploration', 1.0],
#  ['entertainment industry', 1.0],
#  ['estate market', 1.0],
#  ['fledgling city', 1.0],
#  ['glass beads', 1.0],
#  ['legend claims', 1.0],
#  ['liquor sales', 1.0]]

# %%
import wikipedia,spacy,math,re
from spacy.matcher import Matcher
from collections import Counter

nlp =spacy.load('en', disable=['parser','ner','textcat'])
matched_phrases = []
def collect_sents(matcher, doc, i, matches):
    match_id,start, end = matches[i]
    span = doc[start:end]
    matched_phrases.append(span.lemma_)
    
patterns=[[{'POS':'NOUN','IS_ALPHA':True,'IS_STOP':False,'OP':'+'}]]
matcher=Matcher(nlp.vocab)
for pattern in patterns:
    matcher.add('keyword',collect_sents,pattern)
    
def extract_keywords_wikipedia(pagename, num_keywords):
    global matched_phrases
    page = wikipedia.page(pagename)
    pagenlp = nlp(page.content)
    matched_phrases = []
    matches = matcher(pagenlp)
    keywords = dict(Counter(matched_phrases).most_common(100))
    keywords_cvalues = {}
    for keyword in sorted(keywords.keys()):
        parent_terms = list(filter(lambda t:t!=keyword and re.match('\\b%s\\b' % keyword, t),keywords.keys()))
        keywords_cvalues[keyword] =keywords[keyword]
        for pt in parent_terms:
            keywords_cvalues[keyword] -= float(keywords[pt])/float(len(parent_terms))
        keywords_cvalues[keyword] *= math.log(len(keyword.split()),2)
    best_keywords = []
    for keyword in sorted(keywords_cvalues, key  = keywords_cvalues.get,reverse = True)[:10]:
        best_keywords.append([keyword,keywords_cvalues[keyword]])
        
    return best_keywords

# %%
extract_keywords_wikipedia("New York City",10)
# Out:
# [['transit system', 7.0],
#  ['acre', 0.0],
#  ['air', 0.0],
#  ['airport', 0.0],
#  ['area', 0.0],
#  ['art', 0.0],
#  ['borough', 0.0],
#  ['bridge', 0.0],
#  ['building', 0.0],
#  ['business', 0.0]]

# %%
extract_keywords_wikipedia("AI",10)

# %%
extract_keywords_wikipedia("Python",10)

# %%
extract_keywords_wikipedia("Python (programming language)",10)
